# %% [markdown]
# # Madrid house price prediction

# %% [markdown]
# ## 1. Contexto
#
#
# ## 2. Datos
# Los datos se refieren a las viviendas de la ciudad de Madrid a lo largo de sus 21 distritosun

# %% [markdown]
# ### 2.1 Carga de datos

# %%
import pandas as pd
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# Importing ML libraries and metrics
from math import sqrt
from tqdm import tqdm
import lightgbm as lgb
import xgboost as xgb
from lightgbm import early_stopping, log_evaluation
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import r2_score

# %%
# Ajusta las opciones de visualización
pd.set_option('display.max_rows', None)  # Muestra todas las filas
pd.set_option('display.max_columns', None)  # Muestra todas las columnas
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df= pd.read_csv('./data/dfEDA_final.csv',index_col=False)
#dfb= pd.read_csv('./dfEDA_final.csv',index_col=False)
# Out:
# C:\Users\extas\AppData\Local\Temp\ipykernel_10372\4230695949.py:1: DtypeWarning: Columns (94) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv('./data/dfEDA_final.csv',index_col=False)

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'url',
#  'm2_constr',
#  'distrito',
#  'cod_distrito',
#  'barrio',
#  'cod_barrio',
#  'letra_ce',
#  'amueblado',
#  'planta',
#  'dormitorios',
#  'banos',
#  'balcon',
#  'terraza',
#  'trastero',
#  'ascensor',
#  'tipo_inmueble',
#  'tiene_armario',
#  'cancha_tenis',
#  'chimenea',
#  'exterior',
#  'interior',
#  'porton_electrico',
#  'videoportero',
#  'acceso_discapacidad',
#  'precio',
#  'web',
#  'armarios',
#  'codigo_postal',
#  'm2_utiles',
#  'certificado_energetico',
#  'puerta_seguridad',
#  'gastos_comunidad',
#  'agua_caliente',
#  'portero',
#  'orientacion_este',
#  'orientacion_oeste',
#  'orientacion_sur',
#  'clasificacion_aire',
#  'orientacion_norte',
#  'letra_emisiones',
#  'tipo_calefaccion',
#  'energia_calefaccion',
#  'instalacion_calefaccion',
#  'num_personas',
#  'num_personas_hombres',
#  'num_personas_mujeres',
#  'total_transacciones',
#  'viv_nuevas_transacciones',
#  'viv_usadas_transacciones',
#  'lineas_metro',
#  'num_lineas_buses',
#  'renta neta media por persona',
#  'renta neta media por hogar',
#  'mediana de la renta por unidad de consumo',
#  'renta bruta media por persona',
#  'renta bruta media por hogar',
#  'habitantes',
#  'hogares',
#  'tamaño medio del hogar',
#  'tamaño del hogar (nº de personas en la vivienda)',
#  'hog_con_1',
#  'hog_con_2',
#  'hog_con_3',
#  'hog_con_4',
#  'hog_con_5',
#  'hog_con_6',
#  'hog_con_7',
#  'hog_con_8',
#  'hog_con_9',
#  'hog_con_10',
#  'hog_con_11',
#  'hog_con_12',
#  'hog_con_13',
#  'hog_con_14',
#  'hog_con_15 y más',
#  'comercio_serviciosminoristas',
#  'hosteleria_restauracion',
#  'salud_bienestar_educacion',
#  'servicios_profesionales',
#  'cultura_entretenimiento',
#  'porc',
#  'tipologia_agr_Atico',
#  'tipologia_agr_Chalet',
#  'tipologia_agr_Duplex',
#  'tipologia_agr_Estudio',
#  'tipologia_agr_Piso',
#  'eficiencia_carpinteria',
#  'estado_Buen estado',
#  'estado_Desconocido',
#  'estado_Obra nueva',
#  'estado_Para reformar',
#  'estado_Reformado',
#  'num_garajes',
#  'tipo_garaje',
#  'antiguedad_Entre 10 y  15 Años',
#  'antiguedad_Entre 10 y 30 años',
#  'antiguedad_Entre 30 y 50 años',
#  'antiguedad_Entre 5 y 10 años',
#  'antiguedad_Menos de 5 años',
#  'antiguedad_Más de 50 años',
#  'antiguedad_nan',
#  'jardin_n',
#  'piscina_n',
#  'cocina_sin_informacion',
#  'cocina_reformada',
#  'cocina_sinreformada',
#  'cocina_amueblada',
#  'cocina_sin_amueblar',
#  'cocina_equipada',
#  'cocina_independiente',
#  'cocina_abierta',
#  'tipo_suelo_Baldosas_Terrazo',
#  'tipo_suelo_Desconocido',
#  'tipo_suelo_Gres_Ceramica',
#  'tipo_suelo_Marmol',
#  'tipo_suelo_Otros_Materiales',
#  'tipo_suelo_Parquet_Tarimas',
#  'tipo_fachada_ Cemento',
#  'tipo_fachada_ Ladrillo',
#  'tipo_fachada_ Mono Capa',
#  'tipo_fachada_ Otros materiales',
#  'tipo_fachada_ Piedra',
#  'tipo_fachada_Desconocido',
#  'euros_m2',
#  'precio_medio_barrio',
#  'total_estaciones']

# %%
df=df.drop(columns='Unnamed: 0')
# Renombrar una columna
df.rename(columns={'tamaño del hogar (nº de personas en la vivienda)': 'tamano_hogar'}, inplace=True)

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
#quitamos la variable euros_m2, no se puede usar
df=df.drop(columns='euros_m2')

# %%
# Basic dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10009 entries, 0 to 10008
# Columns: 125 entries, url to total_estaciones
# dtypes: float64(26), int64(86), object(13)
# memory usage: 9.5+ MB

# %%
# Identifying the unique number of values in the dfset
df.nunique()
# Out:
# url                                          10009
# m2_constr                                      551
# distrito                                        21
# cod_distrito                                    21
# barrio                                         131
# cod_barrio                                     131
# letra_ce                                         8
# amueblado                                        4
# planta                                          29
# dormitorios                                     17
# banos                                           13
# balcon                                           2
# terraza                                          2
# trastero                                         2
# ascensor                                         2
# tipo_inmueble                                    5
# tiene_armario                                    2
# cancha_tenis                                     2
# chimenea                                         2
# exterior                                         2
# interior                                         2
# porton_electrico                                 2
# videoportero                                     2
# acceso_discapacidad                              2
# precio                                        1591
# web                                              4
# armarios                                         9
# codigo_postal                                   49
# m2_utiles                                      752
# certificado_energetico                           2
# puerta_seguridad                                 2
# gastos_comunidad                               209
# agua_caliente                                    7
# portero                                          3
# orientacion_este                                 2
# orientacion_oeste                                2
# orientacion_sur                                  2
# clasificacion_aire                               4
# orientacion_norte                                2
# letra_emisiones                                  8
# tipo_calefaccion                                 3
# energia_calefaccion                              6
# instalacion_calefaccion                          5
# num_personas                                   131
# num_personas_hombres                           131
# num_personas_mujeres                           131
# total_transacciones                            122
# viv_nuevas_transacciones                        58
# viv_usadas_transacciones                       114
# lineas_metro                                     8
# num_lineas_buses                                 4
# renta_neta_media_por_persona                    21
# renta_neta_media_por_hogar                      21
# mediana_de_la_renta_por_unidad_de_consumo       15
# renta_bruta_media_por_persona                   21
# renta_bruta_media_por_hogar                     21
# habitantes                                      21
# hogares                                         21
# tamaño_medio_del_hogar                          18
# tamano_hogar                                    21
# hog_con_1                                       21
# hog_con_2                                       21
# hog_con_3                                       21
# hog_con_4                                       21
# hog_con_5                                       21
# hog_con_6                                       21
# hog_con_7                                       21
# hog_con_8                                       21
# hog_con_9                                       21
# hog_con_10                                      21
# hog_con_11                                      16
# hog_con_12                                      17
# hog_con_13                                      14
# hog_con_14                                      17
# hog_con_15_y_más                                17
# comercio_serviciosminoristas                    21
# hosteleria_restauracion                         21
# salud_bienestar_educacion                       21
# servicios_profesionales                         21
# cultura_entretenimiento                         21
# porc                                           958
# tipologia_agr_Atico                              2
# tipologia_agr_Chalet                             2
# tipologia_agr_Duplex                             2
# tipologia_agr_Estudio                            2
# tipologia_agr_Piso                               2
# eficiencia_carpinteria                           9
# estado_Buen_estado                               2
# estado_Desconocido                               2
# estado_Obra_nueva                                2
# estado_Para_reformar                             2
# estado_Reformado                                 2
# num_garajes                                     10
# tipo_garaje                                      2
# antiguedad_Entre_10_y__15_Años                   2
# antiguedad_Entre_10_y_30_años                    2
# antiguedad_Entre_30_y_50_años                    2
# antiguedad_Entre_5_y_10_años                     2
# antiguedad_Menos_de_5_años                       2
# antiguedad_Más_de_50_años                        2
# antiguedad_nan                                   2
# jardin_n                                         3
# piscina_n                                        3
# cocina_sin_informacion                           2
# cocina_reformada                                 2
# cocina_sinreformada                              2
# cocina_amueblada                                 2
# cocina_sin_amueblar                              2
# cocina_equipada                                  2
# cocina_independiente                             2
# cocina_abierta                                   2
# tipo_suelo_Baldosas_Terrazo                      2
# tipo_suelo_Desconocido                           2
# tipo_suelo_Gres_Ceramica                         2
# tipo_suelo_Marmol                                2
# tipo_suelo_Otros_Materiales                      2
# tipo_suelo_Parquet_Tarimas                       2
# tipo_fachada__Cemento                            2
# tipo_fachada__Ladrillo                           2
# tipo_fachada__Mono_Capa                          2
# tipo_fachada__Otros_materiales                   2
# tipo_fachada__Piedra                             2
# tipo_fachada_Desconocido                         2
# precio_medio_barrio                            131
# total_estaciones                                21
# dtype: int64

# %% [markdown]
# ### 2.2 Análisis de datos

# %%
# View the distribution of the target variable (price)
plt.figure(figsize=(10, 6))
sns.histplot(df['precio'], kde=True, palette='Set1')
plt.title('Distribution of House Sales Prices')
plt.xlabel('Sale price')
plt.ylabel('Frequency')
plt.grid(False)
plt.show()
# Out:
# C:\Users\extas\AppData\Local\Temp\ipykernel_10372\3746159673.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df['precio'], kde=True, palette='Set1')

# %%
# Check for missing values
df.isnull().sum()
# Out:
# url                                             0
# m2_constr                                       0
# distrito                                        0
# cod_distrito                                    0
# barrio                                          0
# cod_barrio                                      0
# letra_ce                                        0
# amueblado                                       0
# planta                                          0
# dormitorios                                     0
# banos                                           0
# balcon                                          0
# terraza                                         0
# trastero                                        0
# ascensor                                        0
# tipo_inmueble                                   0
# tiene_armario                                   0
# cancha_tenis                                    0
# chimenea                                        0
# exterior                                        0
# interior                                        0
# porton_electrico                                0
# videoportero                                    0
# acceso_discapacidad                             0
# precio                                          0
# web                                             0
# armarios                                        0
# codigo_postal                                   0
# m2_utiles                                       0
# certificado_energetico                          0
# puerta_seguridad                                0
# gastos_comunidad                                0
# agua_caliente                                   0
# portero                                         0
# orientacion_este                                0
# orientacion_oeste                               0
# orientacion_sur                                 0
# clasificacion_aire                              0
# orientacion_norte                               0
# letra_emisiones                                 0
# tipo_calefaccion                                0
# energia_calefaccion                             0
# instalacion_calefaccion                         0
# num_personas                                    0
# num_personas_hombres                            0
# num_personas_mujeres                            0
# total_transacciones                             0
# viv_nuevas_transacciones                        0
# viv_usadas_transacciones                        0
# lineas_metro                                    0
# num_lineas_buses                                0
# renta_neta_media_por_persona                    0
# renta_neta_media_por_hogar                      0
# mediana_de_la_renta_por_unidad_de_consumo       0
# renta_bruta_media_por_persona                   0
# renta_bruta_media_por_hogar                     0
# habitantes                                      0
# hogares                                         0
# tamaño_medio_del_hogar                          0
# tamano_hogar                                    0
# hog_con_1                                       0
# hog_con_2                                       0
# hog_con_3                                       0
# hog_con_4                                       0
# hog_con_5                                       0
# hog_con_6                                       0
# hog_con_7                                       0
# hog_con_8                                       0
# hog_con_9                                       0
# hog_con_10                                      0
# hog_con_11                                      0
# hog_con_12                                      0
# hog_con_13                                      0
# hog_con_14                                      0
# hog_con_15_y_más                                0
# comercio_serviciosminoristas                    0
# hosteleria_restauracion                         0
# salud_bienestar_educacion                       0
# servicios_profesionales                         0
# cultura_entretenimiento                         0
# porc                                            0
# tipologia_agr_Atico                             0
# tipologia_agr_Chalet                            0
# tipologia_agr_Duplex                            0
# tipologia_agr_Estudio                           0
# tipologia_agr_Piso                              0
# eficiencia_carpinteria                          0
# estado_Buen_estado                              0
# estado_Desconocido                              0
# estado_Obra_nueva                               0
# estado_Para_reformar                            0
# estado_Reformado                                0
# num_garajes                                     0
# tipo_garaje                                  9711
# antiguedad_Entre_10_y__15_Años                  0
# antiguedad_Entre_10_y_30_años                   0
# antiguedad_Entre_30_y_50_años                   0
# antiguedad_Entre_5_y_10_años                    0
# antiguedad_Menos_de_5_años                      0
# antiguedad_Más_de_50_años                       0
# antiguedad_nan                                  0
# jardin_n                                        0
# piscina_n                                       0
# cocina_sin_informacion                          0
# cocina_reformada                                0
# cocina_sinreformada                             0
# cocina_amueblada                                0
# cocina_sin_amueblar                             0
# cocina_equipada                                 0
# cocina_independiente                            0
# cocina_abierta                                  0
# tipo_suelo_Baldosas_Terrazo                     0
# tipo_suelo_Desconocido                          0
# tipo_suelo_Gres_Ceramica                        0
# tipo_suelo_Marmol                               0
# tipo_suelo_Otros_Materiales                     0
# tipo_suelo_Parquet_Tarimas                      0
# tipo_fachada__Cemento                           0
# tipo_fachada__Ladrillo                          0
# tipo_fachada__Mono_Capa                         0
# tipo_fachada__Otros_materiales                  0
# tipo_fachada__Piedra                            0
# tipo_fachada_Desconocido                        0
# precio_medio_barrio                             0
# total_estaciones                                0
# dtype: int64

# %%
# Viewing the df statistics
df.describe().T
# Out:
#                                              count      mean        std  \
# m2_constr                                 10009.00    138.61     152.04
# cod_distrito                              10009.00      7.77       5.75
# cod_barrio                                10009.00     81.40      57.63
# letra_ce                                  10009.00      0.65       1.40
# amueblado                                 10009.00      0.08       0.28
# planta                                    10009.00      2.95       2.31
# dormitorios                               10009.00      2.81       1.43
# banos                                     10009.00      2.03       1.29
# balcon                                    10009.00      0.08       0.28
# terraza                                   10009.00      0.19       0.39
# trastero                                  10009.00      0.13       0.34
# ascensor                                  10009.00      0.42       0.49
# tiene_armario                             10009.00      0.19       0.39
# cancha_tenis                              10009.00      0.00       0.01
# chimenea                                  10009.00      0.00       0.07
# exterior                                  10009.00      0.26       0.44
# interior                                  10009.00      0.00       0.05
# porton_electrico                          10009.00      0.00       0.03
# videoportero                              10009.00      0.03       0.18
# acceso_discapacidad                       10009.00      0.01       0.08
# precio                                    10009.00 890233.84 1160033.59
# armarios                                  10009.00      0.22       0.75
# codigo_postal                             10009.00  28021.14      15.08
# m2_utiles                                 10009.00    112.40     122.46
# certificado_energetico                    10009.00      0.19       0.39
# puerta_seguridad                          10009.00      0.01       0.10
# gastos_comunidad                          10009.00      9.06      65.26
# portero                                   10009.00      0.02       0.15
# orientacion_este                          10009.00      0.06       0.24
# orientacion_oeste                         10009.00      0.05       0.22
# orientacion_sur                           10009.00      0.08       0.27
# orientacion_norte                         10009.00      0.03       0.18
# num_personas                              10009.00     27.84      14.17
# num_personas_hombres                      10009.00     16.99      59.75
# num_personas_mujeres                      10009.00     19.08      63.70
# total_transacciones                       10009.00    324.06     189.81
# viv_nuevas_transacciones                  10009.00     36.25      67.60
# viv_usadas_transacciones                  10009.00    287.90     166.49
# lineas_metro                              10009.00      4.95       2.34
# num_lineas_buses                          10009.00    176.63     310.33
# renta_neta_media_por_persona              10009.00     21.06       5.97
# renta_neta_media_por_hogar                10009.00     49.80      13.61
# mediana_de_la_renta_por_unidad_de_consumo 10009.00     24.74       6.15
# renta_bruta_media_por_persona             10009.00     27.74       9.15
# renta_bruta_media_por_hogar               10009.00     65.48      21.02
# habitantes                                10009.00    164.89      47.17
# hogares                                   10009.00     68.81      16.41
# tamano_hogar                              10009.00     24.35       6.94
# hog_con_1                                 10009.00     19.10       4.68
# hog_con_2                                 10009.00     11.24       3.64
# hog_con_3                                 10009.00      8.29       3.30
# hog_con_4                                 10009.00      3.21       1.21
# hog_con_5                                 10009.00    281.57     377.09
# hog_con_6                                 10009.00    425.68     244.16
# hog_con_7                                 10009.00    293.82     191.84
# hog_con_8                                 10009.00    161.98     105.74
# hog_con_9                                 10009.00     81.81      52.27
# hog_con_10                                10009.00     47.03      35.74
# hog_con_11                                10009.00     27.50      17.23
# hog_con_12                                10009.00     17.19      11.53
# hog_con_13                                10009.00      9.32       5.17
# hog_con_14                                10009.00     37.17      13.50
# hog_con_15_y_más                          10009.00     37.17      13.50
# comercio_serviciosminoristas              10009.00   1209.96     707.42
# hosteleria_restauracion                   10009.00    631.32     385.96
# salud_bienestar_educacion                 10009.00    390.03     322.22
# servicios_profesionales                   10009.00    938.37     735.28
# cultura_entretenimiento                   10009.00    435.75     288.47
# porc                                      10009.00      0.44      11.48
# tipologia_agr_Atico                       10009.00      0.04       0.20
# tipologia_agr_Chalet                      10009.00      0.06       0.23
# tipologia_agr_Duplex                      10009.00      0.02       0.13
# tipologia_agr_Estudio                     10009.00      0.01       0.10
# tipologia_agr_Piso                        10009.00      0.87       0.33
# eficiencia_carpinteria                    10009.00      0.23       1.15
# estado_Buen_estado                        10009.00      0.34       0.47
# estado_Desconocido                        10009.00      0.48       0.50
# estado_Obra_nueva                         10009.00      0.05       0.21
# estado_Para_reformar                      10009.00      0.07       0.25
# estado_Reformado                          10009.00      0.06       0.23
# num_garajes                               10009.00      0.15       0.45
# antiguedad_Entre_10_y__15_Años            10009.00      0.00       0.01
# antiguedad_Entre_10_y_30_años             10009.00      0.04       0.19
# antiguedad_Entre_30_y_50_años             10009.00      0.05       0.22
# antiguedad_Entre_5_y_10_años              10009.00      0.00       0.05
# antiguedad_Menos_de_5_años                10009.00      0.01       0.08
# antiguedad_Más_de_50_años                 10009.00      0.24       0.43
# antiguedad_nan                            10009.00      0.66       0.47
# jardin_n                                  10009.00      0.06       0.32
# piscina_n                                 10009.00      0.03       0.21
# cocina_sin_informacion                    10009.00      0.90       0.30
# cocina_reformada                          10009.00      0.00       0.01
# cocina_sinreformada                       10009.00      0.00       0.01
# cocina_amueblada                          10009.00      0.03       0.16
# cocina_sin_amueblar                       10009.00      0.00       0.01
# cocina_equipada                           10009.00      0.01       0.10
# cocina_independiente                      10009.00      0.05       0.21
# cocina_abierta                            10009.00      0.02       0.14
# tipo_suelo_Baldosas_Terrazo               10009.00      0.00       0.03
# tipo_suelo_Desconocido                    10009.00      0.92       0.28
# tipo_suelo_Gres_Ceramica                  10009.00      0.01       0.10
# tipo_suelo_Marmol                         10009.00      0.00       0.05
# tipo_suelo_Otros_Materiales               10009.00      0.00       0.02
# tipo_suelo_Parquet_Tarimas                10009.00      0.07       0.25
# tipo_fachada__Cemento                     10009.00      0.00       0.05
# tipo_fachada__Ladrillo                    10009.00      0.01       0.11
# tipo_fachada__Mono_Capa                   10009.00      0.00       0.05
# tipo_fachada__Otros_materiales            10009.00      0.00       0.01
# tipo_fachada__Piedra                      10009.00      0.00       0.02
# tipo_fachada_Desconocido                  10009.00      0.98       0.14
# precio_medio_barrio                       10009.00 890233.84  690227.98
# total_estaciones                          10009.00    246.37      77.22
#
#                                                 min       25%       50%  \
# m2_constr                                     10.00     68.00     98.00
# cod_distrito                                   1.00      4.00      6.00
# cod_barrio                                    11.00     41.00     65.00
# letra_ce                                       0.00      0.00      0.00
# amueblado                                      0.00      0.00      0.00
# planta                                        -1.00      2.00      3.00
# dormitorios                                    0.00      2.00      3.00
# banos                                          1.00      1.00      2.00
# balcon                                         0.00      0.00      0.00
# terraza                                        0.00      0.00      0.00
# trastero                                       0.00      0.00      0.00
# ascensor                                       0.00      0.00      0.00
# tiene_armario                                  0.00      0.00      0.00
# cancha_tenis                                   0.00      0.00      0.00
# chimenea                                       0.00      0.00      0.00
# exterior                                       0.00      0.00      0.00
# interior                                       0.00      0.00      0.00
# porton_electrico                               0.00      0.00      0.00
# videoportero                                   0.00      0.00      0.00
# acceso_discapacidad                            0.00      0.00      0.00
# precio                                     54000.00 239900.00 480000.00
# armarios                                       0.00      0.00      0.00
# codigo_postal                              28001.00  28009.00  28017.00
# m2_utiles                                      8.00     56.00     80.00
# certificado_energetico                         0.00      0.00      0.00
# puerta_seguridad                               0.00      0.00      0.00
# gastos_comunidad                               0.00      0.00      0.00
# portero                                        0.00      0.00      0.00
# orientacion_este                               0.00      0.00      0.00
# orientacion_oeste                              0.00      0.00      0.00
# orientacion_sur                                0.00      0.00      0.00
# orientacion_norte                              0.00      0.00      0.00
# num_personas                                   1.62     17.47     24.62
# num_personas_hombres                           1.41      8.49     11.56
# num_personas_mujeres                           1.63      9.50     13.47
# total_transacciones                            1.08    186.00    310.00
# viv_nuevas_transacciones                       0.00      3.00     10.00
# viv_usadas_transacciones                       5.00    178.00    257.00
# lineas_metro                                   1.00      3.00      6.00
# num_lineas_buses                               0.00      0.00      0.00
# renta_neta_media_por_persona                  11.43     15.90     20.59
# renta_neta_media_por_hogar                    30.34     41.06     43.74
# mediana_de_la_renta_por_unidad_de_consumo     15.05     19.95     22.05
# renta_bruta_media_por_persona                 13.35     19.77     27.03
# renta_bruta_media_por_hogar                   35.38     51.56     55.11
# habitantes                                    48.65    139.69    145.70
# hogares                                       18.52     61.37     66.49
# tamano_hogar                                   4.69     20.43     24.74
# hog_con_1                                      5.05     16.51     18.86
# hog_con_2                                      3.83      8.61      9.58
# hog_con_3                                      3.44      6.37      7.15
# hog_con_4                                      1.00      2.35      3.03
# hog_con_5                                      1.13      1.41      1.99
# hog_con_6                                      1.05    351.00    406.00
# hog_con_7                                     44.00    162.00    211.00
# hog_con_8                                     39.00     98.00    109.00
# hog_con_9                                     12.00     41.00     71.00
# hog_con_10                                     3.00     21.00     43.00
# hog_con_11                                     3.00     10.00     32.00
# hog_con_12                                     0.00      8.00     14.00
# hog_con_13                                     0.00      4.00      9.00
# hog_con_14                                     7.00     28.00     39.00
# hog_con_15_y_más                               7.00     28.00     39.00
# comercio_serviciosminoristas                   0.00    693.00   1208.00
# hosteleria_restauracion                        0.00    274.00    589.00
# salud_bienestar_educacion                      0.00    137.00    267.00
# servicios_profesionales                        0.00    505.00    628.00
# cultura_entretenimiento                        0.00    220.00    454.00
# porc                                           0.00      0.00      0.00
# tipologia_agr_Atico                            0.00      0.00      0.00
# tipologia_agr_Chalet                           0.00      0.00      0.00
# tipologia_agr_Duplex                           0.00      0.00      0.00
# tipologia_agr_Estudio                          0.00      0.00      0.00
# tipologia_agr_Piso                             0.00      1.00      1.00
# eficiencia_carpinteria                         0.00      0.00      0.00
# estado_Buen_estado                             0.00      0.00      0.00
# estado_Desconocido                             0.00      0.00      0.00
# estado_Obra_nueva                              0.00      0.00      0.00
# estado_Para_reformar                           0.00      0.00      0.00
# estado_Reformado                               0.00      0.00      0.00
# num_garajes                                    0.00      0.00      0.00
# antiguedad_Entre_10_y__15_Años                 0.00      0.00      0.00
# antiguedad_Entre_10_y_30_años                  0.00      0.00      0.00
# antiguedad_Entre_30_y_50_años                  0.00      0.00      0.00
# antiguedad_Entre_5_y_10_años                   0.00      0.00      0.00
# antiguedad_Menos_de_5_años                     0.00      0.00      0.00
# antiguedad_Más_de_50_años                      0.00      0.00      0.00
# antiguedad_nan                                 0.00      0.00      1.00
# jardin_n                                       0.00      0.00      0.00
# piscina_n                                      0.00      0.00      0.00
# cocina_sin_informacion                         0.00      1.00      1.00
# cocina_reformada                               0.00      0.00      0.00
# cocina_sinreformada                            0.00      0.00      0.00
# cocina_amueblada                               0.00      0.00      0.00
# cocina_sin_amueblar                            0.00      0.00      0.00
# cocina_equipada                                0.00      0.00      0.00
# cocina_independiente                           0.00      0.00      0.00
# cocina_abierta                                 0.00      0.00      0.00
# tipo_suelo_Baldosas_Terrazo                    0.00      0.00      0.00
# tipo_suelo_Desconocido                         0.00      1.00      1.00
# tipo_suelo_Gres_Ceramica                       0.00      0.00      0.00
# tipo_suelo_Marmol                              0.00      0.00      0.00
# tipo_suelo_Otros_Materiales                    0.00      0.00      0.00
# tipo_suelo_Parquet_Tarimas                     0.00      0.00      0.00
# tipo_fachada__Cemento                          0.00      0.00      0.00
# tipo_fachada__Ladrillo                         0.00      0.00      0.00
# tipo_fachada__Mono_Capa                        0.00      0.00      0.00
# tipo_fachada__Otros_materiales                 0.00      0.00      0.00
# tipo_fachada__Piedra                           0.00      0.00      0.00
# tipo_fachada_Desconocido                       0.00      1.00      1.00
# precio_medio_barrio                       111940.91 304073.66 769546.75
# total_estaciones                             143.00    202.00    210.00
#
#                                                  75%         max
# m2_constr                                     150.00     4574.00
# cod_distrito                                   12.00       21.00
# cod_barrio                                    124.00      215.00
# letra_ce                                        0.00        7.00
# amueblado                                       0.00        1.00
# planta                                          4.00       28.00
# dormitorios                                     3.00       24.00
# banos                                           3.00       13.00
# balcon                                          0.00        1.00
# terraza                                         0.00        1.00
# trastero                                        0.00        1.00
# ascensor                                        1.00        1.00
# tiene_armario                                   0.00        1.00
# cancha_tenis                                    0.00        1.00
# chimenea                                        0.00        1.00
# exterior                                        1.00        1.00
# interior                                        0.00        1.00
# porton_electrico                                0.00        1.00
# videoportero                                    0.00        1.00
# acceso_discapacidad                             0.00        1.00
# precio                                    1090000.00 19950000.00
# armarios                                        0.00        8.00
# codigo_postal                               28032.00    28055.00
# m2_utiles                                     120.80     3659.20
# certificado_energetico                          0.00        1.00
# puerta_seguridad                                0.00        1.00
# gastos_comunidad                                0.00     2242.00
# portero                                         0.00        1.00
# orientacion_este                                0.00        1.00
# orientacion_oeste                               0.00        1.00
# orientacion_sur                                 0.00        1.00
# orientacion_norte                               0.00        1.00
# num_personas                                   35.52       69.18
# num_personas_hombres                           16.62      965.00
# num_personas_mujeres                           19.22      992.00
# total_transacciones                           427.00      774.00
# viv_nuevas_transacciones                       36.00      506.00
# viv_usadas_transacciones                      381.00      743.00
# lineas_metro                                    7.00        9.00
# num_lineas_buses                                0.00      756.00
# renta_neta_media_por_persona                   27.08       30.51
# renta_neta_media_por_hogar                     64.92       74.84
# mediana_de_la_renta_por_unidad_de_consumo      31.15       34.65
# renta_bruta_media_por_persona                  36.93       42.68
# renta_bruta_media_por_hogar                    89.41      104.71
# habitantes                                    198.39      262.34
# hogares                                        74.74       98.59
# tamano_hogar                                   28.85       34.16
# hog_con_1                                      20.14       29.05
# hog_con_2                                      14.86       18.30
# hog_con_3                                      11.25       15.88
# hog_con_4                                       4.30        5.85
# hog_con_5                                     750.00      922.00
# hog_con_6                                     536.00      926.00
# hog_con_7                                     365.00      749.00
# hog_con_8                                     202.00      439.00
# hog_con_9                                      93.00      218.00
# hog_con_10                                     62.00      139.00
# hog_con_11                                     36.00       64.00
# hog_con_12                                     21.00       50.00
# hog_con_13                                     11.00       22.00
# hog_con_14                                     48.00       59.00
# hog_con_15_y_más                               48.00       59.00
# comercio_serviciosminoristas                 1495.00     2470.00
# hosteleria_restauracion                      1051.00     1116.00
# salud_bienestar_educacion                     494.00     1039.00
# servicios_profesionales                      1502.00     2315.00
# cultura_entretenimiento                       556.00      917.00
# porc                                            0.00     1000.00
# tipologia_agr_Atico                             0.00        1.00
# tipologia_agr_Chalet                            0.00        1.00
# tipologia_agr_Duplex                            0.00        1.00
# tipologia_agr_Estudio                           0.00        1.00
# tipologia_agr_Piso                              1.00        1.00
# eficiencia_carpinteria                          0.00        8.00
# estado_Buen_estado                              1.00        1.00
# estado_Desconocido                              1.00        1.00
# estado_Obra_nueva                               0.00        1.00
# estado_Para_reformar                            0.00        1.00
# estado_Reformado                                0.00        1.00
# num_garajes                                     0.00       10.00
# antiguedad_Entre_10_y__15_Años                  0.00        1.00
# antiguedad_Entre_10_y_30_años                   0.00        1.00
# antiguedad_Entre_30_y_50_años                   0.00        1.00
# antiguedad_Entre_5_y_10_años                    0.00        1.00
# antiguedad_Menos_de_5_años                      0.00        1.00
# antiguedad_Más_de_50_años                       0.00        1.00
# antiguedad_nan                                  1.00        1.00
# jardin_n                                        0.00        2.00
# piscina_n                                       0.00        2.00
# cocina_sin_informacion                          1.00        1.00
# cocina_reformada                                0.00        1.00
# cocina_sinreformada                             0.00        1.00
# cocina_amueblada                                0.00        1.00
# cocina_sin_amueblar                             0.00        1.00
# cocina_equipada                                 0.00        1.00
# cocina_independiente                            0.00        1.00
# cocina_abierta                                  0.00        1.00
# tipo_suelo_Baldosas_Terrazo                     0.00        1.00
# tipo_suelo_Desconocido                          1.00        1.00
# tipo_suelo_Gres_Ceramica                        0.00        1.00
# tipo_suelo_Marmol                               0.00        1.00
# tipo_suelo_Otros_Materiales                     0.00        1.00
# tipo_suelo_Parquet_Tarimas                      0.00        1.00
# tipo_fachada__Cemento                           0.00        1.00
# tipo_fachada__Ladrillo                          0.00        1.00
# tipo_fachada__Mono_Capa                         0.00        1.00
# tipo_fachada__Otros_materiales                  0.00        1.00
# tipo_fachada__Piedra                            0.00        1.00
# tipo_fachada_Desconocido                        1.00        1.00
# precio_medio_barrio                       1356561.40  3109250.00
# total_estaciones                              305.00      469.00

# %% [markdown]
# ### 2.3 Partición en train / test

# %%
# Guardamos la  variable target en una variable "target"
target = 'precio'
df[target].head()
# Out:
# 0    2000000
# 1     650000
# 2     650000
# 3     599999
# 4     625000
# Name: precio, dtype: int64

# %%
# Dividir las columnas objetivo y características, preservando nombres de columnas
dfn = df.select_dtypes(include=['number'])
dfn["url"] = df["url"]
dfmodel=dfn
y = dfmodel[target].values
X = dfmodel.drop(columns=[target, 'url'])

df_ids = dfmodel[['url']]

# Primera clasificación entre train y test
X_train, X_test, y_train, y_test, ids_train, ids_test = train_test_split(X, y, df_ids, test_size=0.3, random_state=42)

# Número de registros del dataset de train y de test
print("Número de observaciones")
print("- Train: ", X_train.shape[0])
print("- Test:  ", X_test.shape[0])
#print("- Val:  ", X_val.shape[0])

dftrain = X_train.reset_index(drop=True)
dftest = X_test.reset_index(drop=True)
#dfval = X_val.reset_index(drop=True)
# Out:
# Número de observaciones
# - Train:  7006
# - Test:   3003

# %%
# Instantiate SimpleImputer
#imputer = SimpleImputer(strategy='mean')

# Fit the imputer on X_train
#imputer.fit(X_train)

# Transform both X_train and X_test
#X_train_imputed = imputer.transform(X_train)

#
#X_test_imputed = imputer.transform(X_test)

X_train_imputed =X_train
X_test_imputed = X_test

# %% [markdown]
# Aplicamos ocho modelos de aprendizaje automático para la tarea de regresión.
# Los modelos incluidos son: Regresión Lineal, Árbol de Decisión, Bosque Aleatorio, Regresor KNN, Gradient Boosting, XGBoost, AdaBoost y LightGBM Regressor.
# Cada modelo se entrena y evalua utilizando técnicas de validación cruzada para garantizar una evaluación sólida de su rendimiento.
# Se consideran diversas métricas para evaluar la calidad de las predicciones de cada modelo, incluyendo el coeficiente de determinación (R²), el error cuadrático medio (RMSE), entre otros.

# %%
# Imprimir todos los nombres de las características
print("Nombres de características antes del entrenamiento:")
print(X_train_imputed.columns)

# Verificar si hay caracteres especiales en los nombres
for feature in X_train_imputed.columns:
    if not feature.isidentifier():
        print(f"Nombre problemático encontrado: {feature}")
# Out:
# Nombres de características antes del entrenamiento:
# Index(['m2_constr', 'cod_distrito', 'cod_barrio', 'letra_ce', 'amueblado',
#        'planta', 'dormitorios', 'banos', 'balcon', 'terraza',
#        ...
#        'tipo_suelo_Otros_Materiales', 'tipo_suelo_Parquet_Tarimas',
#        'tipo_fachada__Cemento', 'tipo_fachada__Ladrillo',
#        'tipo_fachada__Mono_Capa', 'tipo_fachada__Otros_materiales',
#        'tipo_fachada__Piedra', 'tipo_fachada_Desconocido',
#        'precio_medio_barrio', 'total_estaciones'],
#       dtype='object', length=111)

# %%
params = {
    'boosting_type': 'gbdt',  # Tipo de boosting
    'objective': 'regression',  # Tipo de tarefa: regressão
    'metric': 'rmse',  # Métrica de avaliação: Root Mean Squared Error
    'device': 'gpu',  # Usar GPU
    'gpu_platform_id': 0,  # ID da plataforma GPU (ajuste se necessário)
    'gpu_device_id': 0,  # ID do dispositivo GPU (ajuste se necessário)
    'num_leaves': 31,  # Número de folhas na árvore
    'learning_rate': 0.05,  # Tasa de aprendizaje
    'n_estimators': 1000,  # Número de estimadores (estimadores)
    'max_depth': -1,  # Profundidade máxima das estimadores (-1 para sem limite)
    'min_child_samples': 20,  # Número mínimo de amostras em um nó filho
    'subsample': 0.8,  # Proporção de amostras para subsampling
    'colsample_bytree': 0.8,  # Proporção de colunas para subsampling
    'reg_alpha': 0.1,  # Regularizaçion L1
    'reg_lambda': 0.1,  # Regularizaçion L2
    'verbose': -1  # Nível de verbosidade (-1 para silenciar)
}
# Creating a list to store the models
models = {"Linear Regression": LinearRegression(),
          "Decision Tree": DecisionTreeRegressor(),
          "Random Forest": RandomForestRegressor(),
          "KNN Regressor": KNeighborsRegressor(),
          "Gradient": GradientBoostingRegressor(),
          "AdaBoost": AdaBoostRegressor(),
          "XGBoost": XGBRegressor(),
          "LGBM Regressor": lgb.LGBMRegressor(**params)
         }

# Loop to create, preprocess, train, and evaluate models
for name, model in tqdm(models.items()):
    
    # Train with imputed data
    model.fit(X_train_imputed, y_train)
    
    # Predict with imputed test data
    predictions = model.predict(X_test_imputed)
    
    # Calculate r2
    r2 = r2_score(y_test, predictions)
    print(f"Model: {name} - R2 Score: {r2}")
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
#  25%|██▌       | 2/8 [00:00<00:00,  6.02it/s]
# Model: Linear Regression - R2 Score: 0.6260354132266843
# Model: Decision Tree - R2 Score: 0.6054720019953277
#  50%|█████     | 4/8 [00:09<00:10,  2.74s/it]
# Model: Random Forest - R2 Score: 0.8169215922009669
# Model: KNN Regressor - R2 Score: 0.7502794488961415
#  62%|██████▎   | 5/8 [00:12<00:07,  2.49s/it]
# Model: Gradient - R2 Score: 0.7852156053990452
#  75%|███████▌  | 6/8 [00:13<00:04,  2.01s/it]
# Model: AdaBoost - R2 Score: -0.04352646262194737
#  88%|████████▊ | 7/8 [00:13<00:01,  1.45s/it]
# Model: XGBoost - R2 Score: 0.7888450026512146
# 100%|██████████| 8/8 [00:30<00:00,  3.86s/it]
# Model: LGBM Regressor - R2 Score: 0.8106407324030614

# %%
from scipy.stats import randint, uniform
import lightgbm as lgb

regressors = {
     'LinearRegression': {
        'model': LinearRegression(),
        'hyperparameters': {}  # No hyperparameters for basic Linear Regression
    },
    
    'Lasso': {
        'model': Lasso(),
        'hyperparameters': {
            'alpha': uniform(0.01, 10)  # Explore alpha values for L1 regularization
        }
    },
    'XGBoost': {
        'model': XGBRegressor(objective='reg:squarederror', n_jobs=-1),
        'hyperparameters': {
            'max_depth': randint(3, 12),  # Increased max_depth range
            'n_estimators': randint(100, 500),  # Increased n_estimators range
            'learning_rate': [0.001, 0.01, 0.1, 0.2], # Wider range, including smaller values
            'subsample': uniform(0.5, 0.5),  # Changed to uniform distribution, focused on 0.5-1.0
            'colsample_bytree': uniform(0.5, 0.5), # Added colsample_bytree for feature subsampling
            'reg_alpha': [0, 0.1, 1],  # Added L1 regularization
            'reg_lambda': [0, 0.1, 1]  # Added L2 regularization
        }
    },
    'DecisionTree': {
        'model': DecisionTreeRegressor(),
        'hyperparameters': {
            'criterion': ["squared_error", "friedman_mse", "absolute_error", "poisson"], # Added criteria
            'max_depth': randint(5, 15),  # Increased max_depth range
            'min_samples_leaf': randint(2, 10),  # Increased min_samples_leaf range
            'min_samples_split': randint(2, 10) # Added min_samples_split for splitting control
        }
    },
    'RandomForest': {
        'model': RandomForestRegressor(n_jobs=-1),
        'hyperparameters': {
            'max_depth': randint(5,15),  # Increased max_depth range
            'min_samples_leaf': randint(2, 10),  # Increased min_samples_leaf range
            'n_estimators': randint(50, 200),  # Increased n_estimators range
            'max_features': ['auto', 'sqrt', 'log2'] # Added max_features for feature selection
        }
    },
    'GradientBoosting': {
        'model': GradientBoostingRegressor(),
        'hyperparameters': {
            'max_depth': randint(3, 15),  # Increased max_depth range
            'min_samples_leaf': randint(2, 10),  # Increased min_samples_leaf range
            'learning_rate': [0.001, 0.01, 0.1], # Adjusted learning rates
            'n_estimators': randint(50, 200),  # Increased n_estimators range
            'subsample': uniform(0.5, 0.5) # Added subsample for row subsampling
        }
    },
    'LGMRegressor': {
        'model': LGBMRegressor(),
        'hyperparameters': {
            'boosting_type': 'gbdt',  # Tipo de boosting
            'objective': 'regression',  # Tipo de tarefa: regressão
            'metric': 'rmse',  # Métrica de avaliação: Root Mean Squared Error
            'device': 'gpu',  # Usar GPU
            'gpu_platform_id': 0,  # ID da plataforma GPU (ajuste se necessário)
            'gpu_device_id': 0,  # ID do dispositivo GPU (ajuste se necessário)
            'num_leaves': 31,  # Número de folhas na árvore
            'learning_rate': 0.05,  # Tasa de aprendizaje
            'n_estimators': 1000,  # Número de estimadores (estimadores)
            'max_depth': -1,  # Profundidade máxima das estimadores (-1 para sem limite)
            'min_child_samples': 20,  # Número mínimo de amostras em um nó filho
            'subsample': 0.8,  # Proporção de amostras para subsampling
            'colsample_bytree': 0.8,  # Proporção de colunas para subsampling
            'reg_alpha': 0.1,  # Regularizaçion L1
            'reg_lambda': 0.1,  # Regularizaçion L2
            'verbose': -1,  # Nível de verbosidade (-1 para silenciar)
            'depth': randint(4, 12),  # Increased depth range
            'learning_rate': [0.001, 0.01, 0.1], # Adjusted learning rates
            'iterations': randint(50, 200),  # Increased iterations range
            'l2_leaf_reg': [1, 3, 5, 7, 9] # Added l2_leaf_reg for regularization
        }
    }

}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[134], line 11
#       1 from scipy.stats import randint, uniform
#       2 import lightgbm as lgb
#       4 regressors = {
#       5      'LinearRegression': {
#       6         'model': LinearRegression(),
#       7         'hyperparameters': {}  # No hyperparameters for basic Linear Regression
#       8     },
#       9
#      10     'Lasso': {
# ---> 11         'model': Lasso(),
#      12         'hyperparameters': {
#      13             'alpha': uniform(0.01, 10)  # Explore alpha values for L1 regularization
#      14         }
#      15     },
#      16     'XGBoost': {
#      17         'model': XGBRegressor(objective='reg:squarederror', n_jobs=-1),
#      18         'hyperparameters': {
#      19             'max_depth': randint(3, 12),  # Increased max_depth range
#      20             'n_estimators': randint(100, 500),  # Increased n_estimators range
#      21             'learning_rate': [0.001, 0.01, 0.1, 0.2], # Wider range, including smaller values
#      22             'subsample': uniform(0.5, 0.5),  # Changed to uniform distribution, focused on 0.5-1.0
#      23             'colsample_bytree': uniform(0.5, 0.5), # Added colsample_bytree for feature subsampling
#      24             'reg_alpha': [0, 0.1, 1],  # Added L1 regularization
#      25             'reg_lambda': [0, 0.1, 1]  # Added L2 regularization
#      26         }
#      27     },
#      28     'DecisionTree': {
#      29         'model': DecisionTreeRegressor(),
#      30         'hyperparameters': {
#      31             'criterion': ["squared_error", "friedman_mse", "absolute_error", "poisson"], # Added criteria
#      32             'max_depth': randint(5, 15),  # Increased max_depth range
#      33             'min_samples_leaf': randint(2, 10),  # Increased min_samples_leaf range
#      34             'min_samples_split': randint(2, 10) # Added min_samples_split for splitting control
#      35         }
#      36     },
#      37     'RandomForest': {
#      38         'model': RandomForestRegressor(n_jobs=-1),
#      39         'hyperparameters': {
#      40             'max_depth': randint(5,15),  # Increased max_depth range
#      41             'min_samples_leaf': randint(2, 10),  # Increased min_samples_leaf range
#      42             'n_estimators': randint(50, 200),  # Increased n_estimators range
#      43             'max_features': ['auto', 'sqrt', 'log2'] # Added max_features for feature selection
#      44         }
#      45     },
#      46     'GradientBoosting': {
#      47         'model': GradientBoostingRegressor(),
#      48         'hyperparameters': {
#      49             'max_depth': randint(3, 15),  # Increased max_depth range
#      50             'min_samples_leaf': randint(2, 10),  # Increased min_samples_leaf range
#      51             'learning_rate': [0.001, 0.01, 0.1], # Adjusted learning rates
#      52             'n_estimators': randint(50, 200),  # Increased n_estimators range
#      53             'subsample': uniform(0.5, 0.5) # Added subsample for row subsampling
#      54         }
#      55     },
#      56     'LGMRegressor': {
#      57         'model': LGBMRegressor(),
#      58         'hyperparameters': {
#      59             'boosting_type': 'gbdt',  # Tipo de boosting
#      60             'objective': 'regression',  # Tipo de tarefa: regressão
#      61             'metric': 'rmse',  # Métrica de avaliação: Root Mean Squared Error
#      62             'device': 'gpu',  # Usar GPU
#      63             'gpu_platform_id': 0,  # ID da plataforma GPU (ajuste se necessário)
#      64             'gpu_device_id': 0,  # ID do dispositivo GPU (ajuste se necessário)
#      65             'num_leaves': 31,  # Número de folhas na árvore
#      66             'learning_rate': 0.05,  # Tasa de aprendizaje
#      67             'n_estimators': 1000,  # Número de estimadores (estimadores)
#      68             'max_depth': -1,  # Profundidade máxima das estimadores (-1 para sem limite)
#      69             'min_child_samples': 20,  # Número mínimo de amostras em um nó filho
#      70             'subsample': 0.8,  # Proporção de amostras para subsampling
#      71             'colsample_bytree': 0.8,  # Proporção de colunas para subsampling
#      72             'reg_alpha': 0.1,  # Regularizaçion L1
#      73             'reg_lambda': 0.1,  # Regularizaçion L2
#      74             'verbose': -1,  # Nível de verbosidade (-1 para silenciar)
#      75             'depth': randint(4, 12),  # Increased depth range
#      76             'learning_rate': [0.001, 0.01, 0.1], # Adjusted learning rates
#      77             'iterations': randint(50, 200),  # Increased iterations range
#      78             'l2_leaf_reg': [1, 3, 5, 7, 9] # Added l2_leaf_reg for regularization
#      79         }
#      80     }
#      81
#      82 }
#
# NameError: name 'Lasso' is not defined

# %%
random_search_output = list()
best_estimators = {}

for reg_name, reg_info in regressors.items():
    print(reg_name)

    reg_random_search = RandomizedSearchCV(
        estimator=reg_info['model'],
        param_distributions=reg_info['hyperparameters'],
        n_iter=20,
        cv=5,
        scoring="neg_mean_squared_error",  # Métrico adecuado para regresión
        return_train_score=True,
        refit=True,
        n_jobs=-1,
        verbose=1,
        error_score='raise'
    )
    reg_random_search.fit(X_train, y_train)

    # Resultados del Random Search
    df_output = pd.DataFrame(reg_random_search.cv_results_)
    df_output['regressor'] = reg_name
    random_search_output.append(df_output)

    # Modelo re-entrenado con los hiperparámetros óptimos
    best_estimators[reg_name] = reg_random_search.best_estimator_

# %% [markdown]
# Los resultados indican que el modelo con mejor desempeño es xxxxxxx, logrando un R² de xxxxx%.
# A continuación, el xxxxxxx obtuvo un R² del xxxxx%.
# Estos resultados reflejan la capacidad de estos modelos para capturar y predecir patrones en los datos de manera efectiva.

# %% [markdown]
# 8. Features importantes

# %% [markdown]
# Analizamos las variables o atributos que tienen un impacto significativo en la predicción o explicación de un resultado específico en un modelo estadístico o de aprendizaje automático. Estas características se seleccionan en función de su capacidad para influir en la variable objetivo y aportar información útil al modelo.
#
# Existen varias técnicas para determinar qué características son más importantes en un modelo, entre ellas:
#
# 1. **Análisis de correlación**: Evalúa la relación entre cada característica y la variable objetivo.
#
# 2. **Importancia de variables en modelos basados en árboles**: Modelos como Random Forest, Gradient Boosting y XGBoost proporcionan métricas que indican la importancia relativa de cada característica para la predicción.
#
# 3. **Selección de características basada en modelos**: Utiliza algoritmos como la selección progresiva, la eliminación regresiva o LASSO para identificar un subconjunto óptimo de características.
#
# 4. **Análisis de Componentes Principales (PCA)**: Transforma las características en un nuevo conjunto de variables no correlacionadas, donde los primeros componentes retienen la mayor parte de la variabilidad de los datos.
#
# 5. **Conocimiento del dominio**: El conocimiento especializado sobre el problema puede ser clave para identificar las características importantes.

# %%
# Template list
models = {
 "Linear Regression": LinearRegression(),
 "Decision Tree": DecisionTreeRegressor(),
 "Random Forest": RandomForestRegressor(),
 "KNN Regressor": KNeighborsRegressor(),
 "Gradient": GradientBoostingRegressor(),
 "XGBoost": XGBRegressor(),
 "AdaBoost": AdaBoostRegressor(),
 "LGBM Regressor": lgb.LGBMRegressor()
}


# Loop para crear y entrenar modelos
for nome, modelo in models.items():
    
    # Entrenar el modelo
    modelo.fit(X_train_imputed, y_train)

    # Comprobar si el modelo tiene el atributo o método 'feature_importances_'
    if hasattr(modelo, 'feature_importances_'):
        
        # Obtener la importancia de las características
        importancias = modelo.feature_importances_

        # Obtener los nombres de las características
        nomes_features = X_train.columns  

        # Ordenar las características y sus importancias
        indices = np.argsort(importancias)
        importancias = importancias[indices]
        nomes_features = nomes_features[indices]

        # Seleccionar las 6 características más importantes
        importancias_top10 = importancias[-10:]
        nomes_features_top10 = nomes_features[-10:]

        # Graficar las 6 características más importantes
        plt.figure(figsize=(10, 6))
        plt.barh(range(len(nomes_features_top10)), importancias_top10, align='center')
        plt.yticks(range(len(nomes_features_top10)), nomes_features_top10)
        plt.xlabel('Importancia de las Features')
        plt.ylabel('Features')
        plt.title(f'Importancia de Features - {nome}')
        plt.grid(False)
        plt.show()
