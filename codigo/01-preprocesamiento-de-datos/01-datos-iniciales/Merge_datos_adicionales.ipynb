# %% [markdown]
# # DATOS ADICIONALES
# ## TRABAJO FINAL DE MÁSTER

# %% [markdown]
# ## LIBRERÍAS

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # MERGE/CONCAT DE DATA FRAME: DATOS ADICIONALES DE BARRIOS Y TRANSPORTE PÚBLICO

# %%
df_barrios = pd.read_csv('/Users/AleVC/Library/CloudStorage/GoogleDrive-ale.vaquero.c@gmail.com/My Drive/Nuclio/Máster en Data Science/TFM/Datos-adicionales/Datos-limpios/distritos-y-barrios-limpio.csv')
df_barrios.head()
# Out:
#    cod_distrito distrito  cod_barrio       barrio
# 0             1   Centro          11      Palacio
# 1             1   Centro          12  Embajadores
# 2             1   Centro          13       Cortes
# 3             1   Centro          14     Justicia
# 4             1   Centro          15  Universidad

# %%
df_barrios.shape
# (131, 4)
# Out:
# (131, 4)

# %%
df_barrios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cod_distrito  131 non-null    int64
#  1   distrito      131 non-null    object
#  2   cod_barrio    131 non-null    int64
#  3   barrio        131 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 4.2+ KB

# %%
df_barrios.drop(columns=['cod_distrito'], inplace=True)
df_barrios.head()
# Out:
#   distrito  cod_barrio       barrio
# 0   Centro          11      Palacio
# 1   Centro          12  Embajadores
# 2   Centro          13       Cortes
# 3   Centro          14     Justicia
# 4   Centro          15  Universidad

# %%
df_buses = pd.read_csv('/Users/AleVC/Library/CloudStorage/GoogleDrive-ale.vaquero.c@gmail.com/My Drive/Nuclio/Máster en Data Science/TFM/Datos-adicionales/Datos-limpios/buses_limpio.csv')
df_buses.head()
# Out:
#                     nombre_estacion  cod_municipio tipo_via particula  \
# 0           Pº INFANTA ISABEL Nº 25             79    Paseo     de la
# 1    TORPEDERO TUCUMAN-ALFONSO XIII             79    Calle        de
# 2  Pº REINA CRISTINA-JULIAN GAYARRE             79    Paseo     de la
# 3      AV.PIO XII-COMANDANTE FRANCO             79     Avda        de
# 4     MQUES.DE ZAFRA-MQUES.MONDEJAR             79    Paseo       del
#
#           nombre_via  cod_postal  cod_distrito  cod_barrio  \
# 0     Infanta Isabel       28014             3          -1
# 1  Torpedero Tucumán       28016             5          -1
# 2     Reina Cristina       28014             3          -1
# 3            Pío XII       28016             5          -1
# 4   Marqués de Zafra       28028             4          -1
#
#                   lineas_buses
# 0  10, 14, 26, 32, C1, N9, NC1
# 1                           52
# 2  10, 14, 26, 32, C2, N9, NC2
# 3              16, 29, 150, N1
# ...

# %%
df_buses.shape
# (4846, 9)
# Out:
# (4846, 9)

# %%
df_buses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4846 entries, 0 to 4845
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nombre_estacion  4846 non-null   object
#  1   cod_municipio    4846 non-null   int64
#  2   tipo_via         4846 non-null   object
#  3   particula        4762 non-null   object
#  4   nombre_via       4846 non-null   object
#  5   cod_postal       4846 non-null   int64
#  6   cod_distrito     4846 non-null   int64
#  7   cod_barrio       4846 non-null   int64
#  8   lineas_buses     4846 non-null   object
# dtypes: int64(4), object(5)
# memory usage: 340.9+ KB

# %%
df_cercanias = pd.read_csv('/Users/AleVC/Library/CloudStorage/GoogleDrive-ale.vaquero.c@gmail.com/My Drive/Nuclio/Máster en Data Science/TFM/Datos-adicionales/Datos-limpios/cercanias_limpio.csv')
df_cercanias.head()
# Out:
#   nombre_estacion  cod_municipio tipo_via particula             nombre_via  \
# 0     EMBAJADORES             79      Gta        de            Embajadores
# 1             SOL             79    Plaza     de la         Puerta del Sol
# 2       PIRÁMIDES             79    Paseo       del  Doctor Vallejo Nágera
# 3        DELICIAS             79    Calle        de       Ramírez de Prado
# 4   MÉNDEZ ÁLVARO             79    Calle       del                   Ombu
#
#    cod_postal  cod_distrito  cod_barrio lineas_cercanias
# 0       28012             1          12              C-5
# 1       28013             1          16         C-3, C-4
# 2       28005             2          22        C-1, C-10
# 3       28045             2          25        C-1, C-10
# 4       28045             2          27   C-1, C-10, C-5

# %%
df_cercanias.shape
# (39, 9)
# Out:
# (39, 9)

# %%
df_cercanias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nombre_estacion   39 non-null     object
#  1   cod_municipio     39 non-null     int64
#  2   tipo_via          39 non-null     object
#  3   particula         39 non-null     object
#  4   nombre_via        39 non-null     object
#  5   cod_postal        39 non-null     int64
#  6   cod_distrito      39 non-null     int64
#  7   cod_barrio        39 non-null     int64
#  8   lineas_cercanias  39 non-null     object
# dtypes: int64(4), object(5)
# memory usage: 2.9+ KB

# %%
df_ligero = pd.read_csv('/Users/AleVC/Library/CloudStorage/GoogleDrive-ale.vaquero.c@gmail.com/My Drive/Nuclio/Máster en Data Science/TFM/Datos-adicionales/Datos-limpios/metro_ligero_limpio.csv')
df_ligero
# Out:
#          nombre_estacion  cod_municipio tipo_via particula  \
# 0           PALAS DE REY             79    Calle        de
# 1             LAS TABLAS             79    Calle        de
# 2    ESTACION DE ARAVACA             79    Calle     de la
# 3         COLONIA JARDIN             79    Calle        de
# 4         COLONIA JARDIN             79    Calle        de
# 5     PINAR DE CHAMARTIN             79    Calle        de
# 6          ANTONIO SAURA             79    Calle       del
# 7     VIRGEN DEL CORTIJO             79     Avda        de
# 8   ALVAREZ DE VILLAAMIL             79    Calle       del
# 9          BLASCO IBAÑEZ             79    Calle       del
# 10     FUENTE DE LA MORA             79    Calle        de
# 11           MARIA TUDOR             79    Calle        de
#
#              nombre_via  cod_postal  cod_distrito  cod_barrio  \
# 0          Palas de Rey       28050             8          86
# 1          Palas de Rey       28050             8          86
# ...

# %%
df_ligero.shape
# (12, 9)
# Out:
# (12, 9)

# %%
df_ligero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nombre_estacion      12 non-null     object
#  1   cod_municipio        12 non-null     int64
#  2   tipo_via             12 non-null     object
#  3   particula            12 non-null     object
#  4   nombre_via           12 non-null     object
#  5   cod_postal           12 non-null     int64
#  6   cod_distrito         12 non-null     int64
#  7   cod_barrio           12 non-null     int64
#  8   lineas_metro_ligero  12 non-null     int64
# dtypes: int64(5), object(4)
# memory usage: 996.0+ bytes

# %%
df_metro = pd.read_csv('/Users/AleVC/Library/CloudStorage/GoogleDrive-ale.vaquero.c@gmail.com/My Drive/Nuclio/Máster en Data Science/TFM/Datos-adicionales/Datos-limpios/metro_limpio.csv')
df_metro.head()
# Out:
#   nombre_estacion  cod_municipio tipo_via particula    nombre_via  cod_postal  \
# 0       NOVICIADO             79    Calle        de  San Bernardo       28015
# 1           OPERA             79    Plaza        de     Isabel II       28013
# 2           OPERA             79    Plaza        de     Isabel II       28013
# 3   SANTO DOMINGO             79    Calle        de  San Bernardo       28013
# 4           OPERA             79    Plaza        de     Isabel II       28013
#
#    cod_distrito  cod_barrio lineas_metro
# 0             1          11     2, 3, 10
# 1             1          11      2, 5, R
# 2             1          11      2, 5, R
# 3             1          11            2
# 4             1          11      2, 5, R

# %%
df_metro.shape
# (240, 9)
# Out:
# (240, 9)

# %%
df_metro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nombre_estacion  240 non-null    object
#  1   cod_municipio    240 non-null    int64
#  2   tipo_via         240 non-null    object
#  3   particula        238 non-null    object
#  4   nombre_via       240 non-null    object
#  5   cod_postal       240 non-null    int64
#  6   cod_distrito     240 non-null    int64
#  7   cod_barrio       240 non-null    int64
#  8   lineas_metro     240 non-null    object
# dtypes: int64(4), object(5)
# memory usage: 17.0+ KB

# %%
df_ligero2 = pd.merge(df_ligero, df_barrios, on='cod_barrio', how='left')
df_ligero2
# Out:
#          nombre_estacion  cod_municipio tipo_via particula  \
# 0           PALAS DE REY             79    Calle        de
# 1             LAS TABLAS             79    Calle        de
# 2    ESTACION DE ARAVACA             79    Calle     de la
# 3         COLONIA JARDIN             79    Calle        de
# 4         COLONIA JARDIN             79    Calle        de
# 5     PINAR DE CHAMARTIN             79    Calle        de
# 6          ANTONIO SAURA             79    Calle       del
# 7     VIRGEN DEL CORTIJO             79     Avda        de
# 8   ALVAREZ DE VILLAAMIL             79    Calle       del
# 9          BLASCO IBAÑEZ             79    Calle       del
# 10     FUENTE DE LA MORA             79    Calle        de
# 11           MARIA TUDOR             79    Calle        de
#
#              nombre_via  cod_postal  cod_distrito  cod_barrio  \
# 0          Palas de Rey       28050             8          86
# 1          Palas de Rey       28050             8          86
# ...

# %%
df_ligero2.shape
# (12, 11)
# Out:
# (12, 11)

# %%
df_cercanias2 = pd.merge(df_cercanias, df_barrios, on='cod_barrio', how='left')
df_cercanias2.head()
# Out:
#   nombre_estacion  cod_municipio tipo_via particula             nombre_via  \
# 0     EMBAJADORES             79      Gta        de            Embajadores
# 1             SOL             79    Plaza     de la         Puerta del Sol
# 2       PIRÁMIDES             79    Paseo       del  Doctor Vallejo Nágera
# 3        DELICIAS             79    Calle        de       Ramírez de Prado
# 4   MÉNDEZ ÁLVARO             79    Calle       del                   Ombu
#
#    cod_postal  cod_distrito  cod_barrio lineas_cercanias    distrito  \
# 0       28012             1          12              C-5      Centro
# 1       28013             1          16         C-3, C-4      Centro
# 2       28005             2          22        C-1, C-10  Arganzuela
# 3       28045             2          25        C-1, C-10  Arganzuela
# 4       28045             2          27   C-1, C-10, C-5  Arganzuela
#
#         barrio
# 0  Embajadores
# 1          Sol
# 2      Acacias
# 3     Delicias
# 4       Atocha

# %%
df_cercanias2.shape
# (39, 11)
# Out:
# (39, 11)

# %%
df_buses2 = pd.merge(df_buses, df_barrios, on='cod_barrio', how='left')
df_buses2.head()
# Out:
#                     nombre_estacion  cod_municipio tipo_via particula  \
# 0           Pº INFANTA ISABEL Nº 25             79    Paseo     de la
# 1    TORPEDERO TUCUMAN-ALFONSO XIII             79    Calle        de
# 2  Pº REINA CRISTINA-JULIAN GAYARRE             79    Paseo     de la
# 3      AV.PIO XII-COMANDANTE FRANCO             79     Avda        de
# 4     MQUES.DE ZAFRA-MQUES.MONDEJAR             79    Paseo       del
#
#           nombre_via  cod_postal  cod_distrito  cod_barrio  \
# 0     Infanta Isabel       28014             3          -1
# 1  Torpedero Tucumán       28016             5          -1
# 2     Reina Cristina       28014             3          -1
# 3            Pío XII       28016             5          -1
# 4   Marqués de Zafra       28028             4          -1
#
#                   lineas_buses distrito barrio
# 0  10, 14, 26, 32, C1, N9, NC1      NaN    NaN
# 1                           52      NaN    NaN
# ...

# %%
df_buses2.shape
# (4846, 11)
# Out:
# (4846, 11)

# %%
df_metro2 = pd.merge(df_metro, df_barrios, on='cod_barrio', how='left')
df_metro2.head()
# Out:
#   nombre_estacion  cod_municipio tipo_via particula    nombre_via  cod_postal  \
# 0       NOVICIADO             79    Calle        de  San Bernardo       28015
# 1           OPERA             79    Plaza        de     Isabel II       28013
# 2           OPERA             79    Plaza        de     Isabel II       28013
# 3   SANTO DOMINGO             79    Calle        de  San Bernardo       28013
# 4           OPERA             79    Plaza        de     Isabel II       28013
#
#    cod_distrito  cod_barrio lineas_metro distrito   barrio
# 0             1          11     2, 3, 10   Centro  Palacio
# 1             1          11      2, 5, R   Centro  Palacio
# 2             1          11      2, 5, R   Centro  Palacio
# 3             1          11            2   Centro  Palacio
# 4             1          11      2, 5, R   Centro  Palacio

# %%
df_metro2.shape
# (240, 11)
# Out:
# (240, 11)

# %%
df_adicional1 = pd.concat([df_ligero2, df_cercanias2], ignore_index=False)
df_adicional1.shape
# (51, 12)
# Out:
# (51, 12)

# %%
df_adicional1.head()
# Out:
#        nombre_estacion  cod_municipio tipo_via particula           nombre_via  \
# 0         PALAS DE REY             79    Calle        de         Palas de Rey
# 1           LAS TABLAS             79    Calle        de         Palas de Rey
# 2  ESTACION DE ARAVACA             79    Calle     de la           Golondrina
# 3       COLONIA JARDIN             79    Calle        de  Arenas de San Pedro
# 4       COLONIA JARDIN             79    Calle        de  Arenas de San Pedro
#
#    cod_postal  cod_distrito  cod_barrio  lineas_metro_ligero  \
# 0       28050             8          86                  1.0
# 1       28050             8          86                  1.0
# 2       28023             9          97                  2.0
# 3       28024            10         105                  3.0
# 4       28024            10         105                  2.0
#
#                 distrito      barrio lineas_cercanias
# 0  Fuencarral - El Pardo    Valverde              NaN
# ...

# %%
df_adicional2 = pd.concat([df_buses2, df_metro2], ignore_index=False)
df_adicional2.shape
# Out:
# (5086, 12)

# %%
df_adicional2.head()
# Out:
#                     nombre_estacion  cod_municipio tipo_via particula  \
# 0           Pº INFANTA ISABEL Nº 25             79    Paseo     de la
# 1    TORPEDERO TUCUMAN-ALFONSO XIII             79    Calle        de
# 2  Pº REINA CRISTINA-JULIAN GAYARRE             79    Paseo     de la
# 3      AV.PIO XII-COMANDANTE FRANCO             79     Avda        de
# 4     MQUES.DE ZAFRA-MQUES.MONDEJAR             79    Paseo       del
#
#           nombre_via  cod_postal  cod_distrito  cod_barrio  \
# 0     Infanta Isabel       28014             3          -1
# 1  Torpedero Tucumán       28016             5          -1
# 2     Reina Cristina       28014             3          -1
# 3            Pío XII       28016             5          -1
# 4   Marqués de Zafra       28028             4          -1
#
#                   lineas_buses distrito barrio lineas_metro
# 0  10, 14, 26, 32, C1, N9, NC1      NaN    NaN          NaN
# 1                           52      NaN    NaN          NaN
# ...

# %%
df_adicional = pd.concat([df_adicional1, df_adicional2], ignore_index=False)
df_adicional.shape
# Out:
# (5137, 14)

# %%
df_adicional.head()
# Out:
#        nombre_estacion  cod_municipio tipo_via particula           nombre_via  \
# 0         PALAS DE REY             79    Calle        de         Palas de Rey
# 1           LAS TABLAS             79    Calle        de         Palas de Rey
# 2  ESTACION DE ARAVACA             79    Calle     de la           Golondrina
# 3       COLONIA JARDIN             79    Calle        de  Arenas de San Pedro
# 4       COLONIA JARDIN             79    Calle        de  Arenas de San Pedro
#
#    cod_postal  cod_distrito  cod_barrio  lineas_metro_ligero  \
# 0       28050             8          86                  1.0
# 1       28050             8          86                  1.0
# 2       28023             9          97                  2.0
# 3       28024            10         105                  3.0
# 4       28024            10         105                  2.0
#
#                 distrito      barrio lineas_cercanias lineas_buses  \
# ...

# %%
df_adicional.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5137 entries, 0 to 239
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nombre_estacion      5137 non-null   object
#  1   cod_municipio        5137 non-null   int64
#  2   tipo_via             5137 non-null   object
#  3   particula            5051 non-null   object
#  4   nombre_via           5137 non-null   object
#  5   cod_postal           5137 non-null   int64
#  6   cod_distrito         5137 non-null   int64
#  7   cod_barrio           5137 non-null   int64
#  8   lineas_metro_ligero  12 non-null     float64
#  9   distrito             4647 non-null   object
#  10  barrio               4647 non-null   object
#  11  lineas_cercanias     39 non-null     object
#  12  lineas_buses         4846 non-null   object
#  13  lineas_metro         240 non-null    object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 602.0+ KB

# %% [markdown]
# ## NULOS Y TRATAMIENTO DE DATOS

# %%
df_adicional['particula'] = df_adicional['particula'].fillna('vacio')
df_adicional['lineas_metro_ligero'] = df_adicional['lineas_metro_ligero'].fillna(-1)
df_adicional['distrito'] = df_adicional['distrito'].fillna('desconocido')
df_adicional['barrio'] = df_adicional['barrio'].fillna('desconocido')
df_adicional['lineas_cercanias'] = df_adicional['lineas_cercanias'].fillna(-1)
df_adicional['lineas_buses'] = df_adicional['lineas_buses'].fillna(-1)
df_adicional['lineas_metro'] = df_adicional['lineas_metro'].fillna(-1)
df_adicional.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5137 entries, 0 to 239
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nombre_estacion      5137 non-null   object
#  1   cod_municipio        5137 non-null   int64
#  2   tipo_via             5137 non-null   object
#  3   particula            5137 non-null   object
#  4   nombre_via           5137 non-null   object
#  5   cod_postal           5137 non-null   int64
#  6   cod_distrito         5137 non-null   int64
#  7   cod_barrio           5137 non-null   int64
#  8   lineas_metro_ligero  5137 non-null   float64
#  9   distrito             5137 non-null   object
#  10  barrio               5137 non-null   object
#  11  lineas_cercanias     5137 non-null   object
#  12  lineas_buses         5137 non-null   object
#  13  lineas_metro         5137 non-null   object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 602.0+ KB

# %%
df_adicional['lineas_metro_ligero'] = df_adicional['lineas_metro_ligero'].astype('int32')
df_adicional.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5137 entries, 0 to 239
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nombre_estacion      5137 non-null   object
#  1   cod_municipio        5137 non-null   int64
#  2   tipo_via             5137 non-null   object
#  3   particula            5137 non-null   object
#  4   nombre_via           5137 non-null   object
#  5   cod_postal           5137 non-null   int64
#  6   cod_distrito         5137 non-null   int64
#  7   cod_barrio           5137 non-null   int64
#  8   lineas_metro_ligero  5137 non-null   int32
#  9   distrito             5137 non-null   object
#  10  barrio               5137 non-null   object
#  11  lineas_cercanias     5137 non-null   object
#  12  lineas_buses         5137 non-null   object
#  13  lineas_metro         5137 non-null   object
# dtypes: int32(1), int64(4), object(9)
# memory usage: 581.9+ KB

# %% [markdown]
# # MERGE/CONCAT DE DATAFRAME ADICIONAL + ÁREAS VERDES

# %%
df_verdes = pd.read_csv('/Users/AleVC/Library/CloudStorage/GoogleDrive-ale.vaquero.c@gmail.com/My Drive/Nuclio/Máster en Data Science/TFM/Datos-adicionales/Datos-limpios/areas_verdes_limpio.csv')
df_verdes.head()
# Out:
#   distrito                                    tipo_area_verde   area_m2  \
# 0   CENTRO  Parques Y Jardines                            ...   5025.42
# 1   CENTRO  Parques Y Jardines                            ...  26814.00
# 2   CENTRO  Parques Y Jardines                            ...   2979.20
# 3   CENTRO  Parques Y Jardines                            ...   1637.34
# 4   CENTRO  Parques Y Jardines                            ...    172.90
#
#    cod_distrito
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1

# %%
df_verdes.shape
# (1555, 4)
# Out:
# (1555, 4)

# %%
df_verdes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1555 entries, 0 to 1554
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   distrito         1555 non-null   object
#  1   tipo_area_verde  1555 non-null   object
#  2   area_m2          1555 non-null   float64
#  3   cod_distrito     1555 non-null   int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 48.7+ KB

# %%
df_adicional.shape
# (5137, 14)
# Out:
# (5137, 14)

# %%
df_adicional.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5137 entries, 0 to 239
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nombre_estacion      5137 non-null   object
#  1   cod_municipio        5137 non-null   int64
#  2   tipo_via             5137 non-null   object
#  3   particula            5137 non-null   object
#  4   nombre_via           5137 non-null   object
#  5   cod_postal           5137 non-null   int64
#  6   cod_distrito         5137 non-null   int64
#  7   cod_barrio           5137 non-null   int64
#  8   lineas_metro_ligero  5137 non-null   int32
#  9   distrito             5137 non-null   object
#  10  barrio               5137 non-null   object
#  11  lineas_cercanias     5137 non-null   object
#  12  lineas_buses         5137 non-null   object
#  13  lineas_metro         5137 non-null   object
# dtypes: int32(1), int64(4), object(9)
# memory usage: 581.9+ KB

# %%
df_adicional3 = pd.concat([df_adicional, df_verdes], ignore_index=False)
df_adicional3.shape
# (6692, 16)
# Out:
# (6692, 16)

# %%
df_adicional3.head()
# Out:
#        nombre_estacion  cod_municipio tipo_via particula           nombre_via  \
# 0         PALAS DE REY           79.0    Calle        de         Palas de Rey
# 1           LAS TABLAS           79.0    Calle        de         Palas de Rey
# 2  ESTACION DE ARAVACA           79.0    Calle     de la           Golondrina
# 3       COLONIA JARDIN           79.0    Calle        de  Arenas de San Pedro
# 4       COLONIA JARDIN           79.0    Calle        de  Arenas de San Pedro
#
#    cod_postal  cod_distrito  cod_barrio  lineas_metro_ligero  \
# 0     28050.0             8        86.0                  1.0
# 1     28050.0             8        86.0                  1.0
# 2     28023.0             9        97.0                  2.0
# 3     28024.0            10       105.0                  3.0
# 4     28024.0            10       105.0                  2.0
#
#                 distrito      barrio lineas_cercanias lineas_buses  \
# ...

# %%
df_adicional3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6692 entries, 0 to 1554
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nombre_estacion      5137 non-null   object
#  1   cod_municipio        5137 non-null   float64
#  2   tipo_via             5137 non-null   object
#  3   particula            5137 non-null   object
#  4   nombre_via           5137 non-null   object
#  5   cod_postal           5137 non-null   float64
#  6   cod_distrito         6692 non-null   int64
#  7   cod_barrio           5137 non-null   float64
#  8   lineas_metro_ligero  5137 non-null   float64
#  9   distrito             6692 non-null   object
#  10  barrio               5137 non-null   object
#  11  lineas_cercanias     5137 non-null   object
#  12  lineas_buses         5137 non-null   object
#  13  lineas_metro         5137 non-null   object
#  14  tipo_area_verde      1555 non-null   object
# ...

# %% [markdown]
# ## NULOS Y TRATAMIENTO DE DATOS

# %%
df_adicional3['nombre_estacion'] = df_adicional3['nombre_estacion'].fillna('vacio').astype('string')
df_adicional3['cod_municipio'] = df_adicional3['cod_municipio'].fillna(79).astype('int32')
df_adicional3['tipo_via'] = df_adicional3['tipo_via'].fillna('vacio').astype('category')
df_adicional3['particula'] = df_adicional3['particula'].fillna('vacio').astype('category')
df_adicional3['nombre_via'] = df_adicional3['nombre_via'].fillna('vacio').astype('string')
df_adicional3['cod_postal'] = df_adicional3['cod_postal'].fillna(-1).astype('int32')
df_adicional3['cod_distrito'] = df_adicional3['cod_distrito'].astype('int32')
df_adicional3['cod_barrio'] = df_adicional3['cod_barrio'].fillna(-1).astype('int32')
df_adicional3['lineas_metro_ligero'] = df_adicional3['lineas_metro_ligero'].fillna(-1).astype('int32')
df_adicional3['distrito'] = df_adicional3['distrito'].astype('category')
df_adicional3['barrio'] = df_adicional3['barrio'].fillna('desconocido').astype('category')
df_adicional3['lineas_cercanias'] = df_adicional3['lineas_cercanias'].fillna(-1)
df_adicional3['lineas_buses'] = df_adicional3['lineas_buses'].fillna(-1)
df_adicional3['lineas_metro'] = df_adicional3['lineas_metro'].fillna(-1)
df_adicional3['tipo_area_verde'] = df_adicional3['tipo_area_verde'].fillna('vacio').astype('string')
df_adicional3['area_m2'] = df_adicional3['area_m2'].fillna(-1).astype('float64')
df_adicional3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6692 entries, 0 to 1554
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nombre_estacion      6692 non-null   string
#  1   cod_municipio        6692 non-null   int32
#  2   tipo_via             6692 non-null   category
#  3   particula            6692 non-null   category
#  4   nombre_via           6692 non-null   string
#  5   cod_postal           6692 non-null   int32
#  6   cod_distrito         6692 non-null   int32
#  7   cod_barrio           6692 non-null   int32
#  8   lineas_metro_ligero  6692 non-null   int32
#  9   distrito             6692 non-null   category
#  10  barrio               6692 non-null   category
#  11  lineas_cercanias     6692 non-null   object
#  12  lineas_buses         6692 non-null   object
#  13  lineas_metro         6692 non-null   object
#  14  tipo_area_verde      6692 non-null   string
# ...

# %%
df_adicional3.head()
# Out:
#        nombre_estacion  cod_municipio tipo_via particula           nombre_via  \
# 0         PALAS DE REY             79    Calle        de         Palas de Rey
# 1           LAS TABLAS             79    Calle        de         Palas de Rey
# 2  ESTACION DE ARAVACA             79    Calle     de la           Golondrina
# 3       COLONIA JARDIN             79    Calle        de  Arenas de San Pedro
# 4       COLONIA JARDIN             79    Calle        de  Arenas de San Pedro
#
#    cod_postal  cod_distrito  cod_barrio  lineas_metro_ligero  \
# 0       28050             8          86                    1
# 1       28050             8          86                    1
# 2       28023             9          97                    2
# 3       28024            10         105                    3
# 4       28024            10         105                    2
#
#                 distrito      barrio lineas_cercanias lineas_buses  \
# ...

# %%
df_adicional3.tail()
# Out:
#      nombre_estacion  cod_municipio tipo_via particula nombre_via  cod_postal  \
# 1550           vacio             79    vacio     vacio      vacio          -1
# 1551           vacio             79    vacio     vacio      vacio          -1
# 1552           vacio             79    vacio     vacio      vacio          -1
# 1553           vacio             79    vacio     vacio      vacio          -1
# 1554           vacio             79    vacio     vacio      vacio          -1
#
#       cod_distrito  cod_barrio  lineas_metro_ligero distrito       barrio  \
# 1550            21          -1                   -1  BARAJAS  desconocido
# 1551            21          -1                   -1  BARAJAS  desconocido
# 1552            21          -1                   -1  BARAJAS  desconocido
# 1553            21          -1                   -1  BARAJAS  desconocido
# 1554            21          -1                   -1  BARAJAS  desconocido
#
#      lineas_cercanias lineas_buses lineas_metro  \
# ...

# %% [markdown]
# # COLUMNAS DEL DF COMPLETO DE DATOS ADICIONALES
# - `nombre_estacion`: string
# - `cod_municipio`: int32
# - `tipo_via`: category
# - `particula`: category
# - `nombre_via`: string
# - `cod_postal`: int32
# - `cod_distrito`:  int32
# - `cod_barrio`: int32
# - `lineas_metro_ligero`: int32
# - `distrito`: category
# - `barrio`: category
# - `lineas_cercanias`: object
# - `lineas_buses`: object
# - `lineas_metro`: object
# - `tipo_area_verde`: string
# - `area_m2`: float64

# %%
df_adicional3.to_csv('datos_adicionales_limpio.csv', index=False)
df_adicional3.columns
# Out:
# Index(['nombre_estacion', 'cod_municipio', 'tipo_via', 'particula',
#        'nombre_via', 'cod_postal', 'cod_distrito', 'cod_barrio',
#        'lineas_metro_ligero', 'distrito', 'barrio', 'lineas_cercanias',
#        'lineas_buses', 'lineas_metro', 'tipo_area_verde', 'area_m2'],
#       dtype='object')
