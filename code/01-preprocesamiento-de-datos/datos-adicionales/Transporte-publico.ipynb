# %% [markdown]
# # LIMPIEZA DE DATOS ADICIONALES PARA TFM

# %% [markdown]
# # LIBRERÍAS

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # METRO

# %%
# Cargar CSV M4_Estaciones-red-Metro.csv
df_metro = pd.read_csv('/Users/AleVC/Library/CloudStorage/GoogleDrive-ale.vaquero.c@gmail.com/My Drive/Nuclio/Máster en Data Science/TFM/Datos-adicionales/M4_Estaciones-red-Metro.csv')
df_metro.head()
# Out:
#    OBJECTID IDESTACION  FECHAACTUAL  MODO  CODIGOESTACION  \
# 0         1      4_153     20240628     4             153
# 1         2      4_183     20240628     4             183
# 2         3       4_38     20240628     4              38
# 3         4      4_199     20240628     4             199
# 4         5      4_200     20240628     4             200
#
#            DENOMINACION                    OBSERVACIONES SITUACION  \
# 0          ARROYOFRESNO                              NaN         I
# 1  RIVAS URBANIZACIONES                             0924         S
# 2             NOVICIADO                             0211         I
# 3                  LAGO  Estación de Ferrocarril\r\n1013         S
# 4                 BATAN                             1014         S
#
#    CODIGOCTMESTACIONREDMETRO  CODIGOEMPRESA  ...  FECHAINICIO  FECHAFIN  \
# 0                        153            722  ...     19990330       NaN
# ...

# %%
df_metro.shape
# (290, 53)
# Out:
# (290, 53)

# %%
df_metro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   OBJECTID                        290 non-null    int64
#  1   IDESTACION                      290 non-null    object
#  2   FECHAACTUAL                     290 non-null    int64
#  3   MODO                            290 non-null    int64
#  4   CODIGOESTACION                  290 non-null    int64
#  5   DENOMINACION                    290 non-null    object
#  6   OBSERVACIONES                   278 non-null    object
#  7   SITUACION                       290 non-null    object
#  8   CODIGOCTMESTACIONREDMETRO       290 non-null    int64
#  9   CODIGOEMPRESA                   290 non-null    int64
#  10  DENOMINACIONABREVIADA           0 non-null      float64
#  11  MODOINTERCAMBIADOR              289 non-null    float64
# ...

# %%
# Seleccionar columnas con al menos un valor nulo
metro_col_con_nulos = df_metro.columns[df_metro.isna().any()]
df_metro_col_con_nulos = df_metro[metro_col_con_nulos]
df_metro_col_con_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   OBSERVACIONES                   278 non-null    object
#  1   DENOMINACIONABREVIADA           0 non-null      float64
#  2   MODOINTERCAMBIADOR              289 non-null    float64
#  3   CODIGOINTERCAMBIADOR            289 non-null    float64
#  4   CODIGONUCLEO                    287 non-null    float64
#  5   PARTICULA                       286 non-null    object
#  6   CALIFICADORPORTAL               15 non-null     object
#  7   CARRETERA                       0 non-null      float64
#  8   BARRIO                          242 non-null    float64
#  9   TESELA                          288 non-null    object
#  10  SECTORURBANO                    283 non-null    object
#  11  SECTOR                          88 non-null     float64
# ...

# %%
df_metro.columns
# Out:
# Index(['OBJECTID', 'IDESTACION', 'FECHAACTUAL', 'MODO', 'CODIGOESTACION',
#        'DENOMINACION', 'OBSERVACIONES', 'SITUACION',
#        'CODIGOCTMESTACIONREDMETRO', 'CODIGOEMPRESA', 'DENOMINACIONABREVIADA',
#        'MODOINTERCAMBIADOR', 'CODIGOINTERCAMBIADOR', 'TIPO', 'CODIGOPROVINCIA',
#        'CODIGOMUNICIPIO', 'CODIGOENTIDAD', 'CODIGONUCLEO', 'CODIGOVIA',
#        'TIPOVIA', 'PARTICULA', 'NOMBREVIA', 'TIPONUMERO', 'NUMEROPORTAL',
#        'CALIFICADORPORTAL', 'CARRETERA', 'CODIGOPOSTAL', 'DISTRITO',
#        'SECCIONCENSAL', 'BARRIO', 'TESELA', 'SECTORURBANO', 'SECTOR',
#        'CORREDOR', 'CORONATARIFARIA', 'CORONA123', 'ZONATRANSPORTE',
#        'ENCUESTADOMICILIARIA', 'ENCUESTAAFOROS', 'HOJA25000',
#        'ACONDICIONAMIENTOVIAJEROS', 'ACONDICIONAMIENTOVEHICULOS', 'FECHAALTA',
#        'FECHAINICIO', 'FECHAFIN', 'X', 'Y', 'GRADOACCESIBILIDAD',
#        'SITUACIONCALLE', 'DENOMINACION_SAE', 'INTERURBANOS_CODIGOEMT_CRTM',
# ...

# %%
# Quedarme solo con las columnas que necesitamos
columnas_metro = df_metro[['DENOMINACION', 'CODIGOMUNICIPIO',
       'TIPOVIA', 'PARTICULA', 'NOMBREVIA', 'CODIGOPOSTAL', 'DISTRITO', 'BARRIO', 'LINEAS']]
columnas_metro.shape
# (290, 9)
# Out:
# (290, 9)

# %%
columnas_metro = columnas_metro[columnas_metro['CODIGOMUNICIPIO'] == 79]
columnas_metro.shape
# (240, 9)
# Out:
# (240, 9)

# %%
columnas_metro.head()
# Out:
#    DENOMINACION  CODIGOMUNICIPIO TIPOVIA PARTICULA          NOMBREVIA  \
# 0  ARROYOFRESNO               79   Calle        de  Federica Montseny
# 2     NOVICIADO               79   Calle        de       San Bernardo
# 3          LAGO               79   Ronda       del               Lago
# 4         BATAN               79   Paseo     de la              Venta
# 5           SOL               79   Plaza     de la     Puerta del Sol
#
#    CODIGOPOSTAL  DISTRITO  BARRIO    LINEAS
# 0         28035         8    81.0         7
# 2         28015         1    11.0  2, 3, 10
# 3         28011         9    91.0        10
# 4         28011         9    91.0        10
# 5         28013         1    16.0   1, 2, 3

# %%
columnas_metro = columnas_metro.rename(columns={'DENOMINACION': 'nombre_estacion', 'CODIGOMUNICIPIO': 'cod_municipio', 'TIPOVIA': 'tipo_via', 'PARTICULA': 'particula', 'NOMBREVIA': 'nombre_via', 'CODIGOPOSTAL': 'cod_postal', 'DISTRITO': 'cod_distrito', 'BARRIO': 'cod_barrio', 'LINEAS': 'lineas_metro'})
columnas_metro.head()
# Out:
#   nombre_estacion  cod_municipio tipo_via particula         nombre_via  \
# 0    ARROYOFRESNO             79    Calle        de  Federica Montseny
# 2       NOVICIADO             79    Calle        de       San Bernardo
# 3            LAGO             79    Ronda       del               Lago
# 4           BATAN             79    Paseo     de la              Venta
# 5             SOL             79    Plaza     de la     Puerta del Sol
#
#    cod_postal  cod_distrito  cod_barrio lineas_metro
# 0       28035             8        81.0            7
# 2       28015             1        11.0     2, 3, 10
# 3       28011             9        91.0           10
# 4       28011             9        91.0           10
# 5       28013             1        16.0      1, 2, 3

# %%
columnas_metro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 240 entries, 0 to 289
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nombre_estacion  240 non-null    object
#  1   cod_municipio    240 non-null    int64
#  2   tipo_via         240 non-null    object
#  3   particula        238 non-null    object
#  4   nombre_via       240 non-null    object
#  5   cod_postal       240 non-null    int64
#  6   cod_distrito     240 non-null    int64
#  7   cod_barrio       240 non-null    float64
#  8   lineas_metro     240 non-null    object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 18.8+ KB

# %%
# Rellenar nulos
columnas_metro['particula'] = columnas_metro['particula'].fillna('NaN')
columnas_metro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 240 entries, 0 to 289
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nombre_estacion  240 non-null    object
#  1   cod_municipio    240 non-null    int64
#  2   tipo_via         240 non-null    object
#  3   particula        240 non-null    object
#  4   nombre_via       240 non-null    object
#  5   cod_postal       240 non-null    int64
#  6   cod_distrito     240 non-null    int64
#  7   cod_barrio       240 non-null    float64
#  8   lineas_metro     240 non-null    object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 18.8+ KB

# %%
columnas_metro['nombre_estacion'] = columnas_metro['nombre_estacion'].astype('string')
columnas_metro['tipo_via'] = columnas_metro['tipo_via'].astype('string')
columnas_metro['particula'] = columnas_metro['particula'].astype('string')
columnas_metro['nombre_via'] = columnas_metro['nombre_via'].astype('string')
columnas_metro['cod_barrio'] = columnas_metro['cod_barrio'].astype('int32')
columnas_metro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 240 entries, 0 to 289
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nombre_estacion  240 non-null    string
#  1   cod_municipio    240 non-null    int64
#  2   tipo_via         240 non-null    string
#  3   particula        240 non-null    string
#  4   nombre_via       240 non-null    string
#  5   cod_postal       240 non-null    int64
#  6   cod_distrito     240 non-null    int64
#  7   cod_barrio       240 non-null    int32
#  8   lineas_metro     240 non-null    object
# dtypes: int32(1), int64(3), object(1), string(4)
# memory usage: 17.8+ KB

# %%
columnas_metro = columnas_metro.sort_values(by='cod_barrio')
columnas_metro = columnas_metro.reset_index(drop=True)
columnas_metro
# Out:
#          nombre_estacion  cod_municipio tipo_via particula  \
# 0              NOVICIADO             79    Calle        de
# 1                  OPERA             79    Plaza        de
# 2                  OPERA             79    Plaza        de
# 3          SANTO DOMINGO             79    Calle        de
# 4                  OPERA             79    Plaza        de
# ..                   ...            ...      ...       ...
# 235     ALAMEDA DE OSUNA             79    Calle     de la
# 236       AEROPUERTO T-4             79     Ctra        de
# 237  AEROPUERTO T1-T2-T3             79     Avda     de la
# 238              BARAJAS             79     Cmno       NaN
# 239      FERIA DE MADRID             79     Avda       del
#
#                nombre_via  cod_postal  cod_distrito  cod_barrio lineas_metro
# 0            San Bernardo       28015             1          11     2, 3, 10
# 1               Isabel II       28013             1          11      2, 5, R
# ...

# %%
columnas_metro.to_csv('metro_limpio.csv', index=False)

# %%
columnas_metro.columns
# Out:
# Index(['nombre_estacion', 'cod_municipio', 'tipo_via', 'particula',
#        'nombre_via', 'cod_postal', 'cod_distrito', 'cod_barrio',
#        'lineas_metro'],
#       dtype='object')

# %% [markdown]
# ### COLUMNAS DEL DF DE ESTACIONES DE METRO
# - `nombre_estacion`: string
# - `cod_municipio`: int64
# - `tipo_via`: string
# - `particula`: string
# - `nombre_via`: string
# - `cod_postal`: int64
# - `cod_distrito`: int64
# - `cod_barrio`: int32
# - `lineas_metro`: object

# %% [markdown]
# # METRO LIGERO

# %%
# Cargar CSV M10_Estaciones-Metro-Ligero.csv
df_metro_lig = pd.read_csv('/Users/AleVC/Library/CloudStorage/GoogleDrive-ale.vaquero.c@gmail.com/My Drive/Nuclio/Máster en Data Science/TFM/Datos-adicionales/M10_Estaciones-Metro-Ligero.csv')
df_metro_lig.head()
# Out:
#    OBJECTID IDESTACION  FECHAACTUAL  MODO  CODIGOESTACION        DENOMINACION  \
# 0         1      10_29     20240628    10              29       MONTEPRINCIPE
# 1         2      10_30     20240628    10              30   VENTORRO DEL CANO
# 2         3      10_31     20240628    10              31    PRADO DEL ESPINO
# 3         4      10_32     20240628    10              32           CANTABRIA
# 4         5      10_33     20240628    10              33  FERIAL DE BOADILLA
#
#            OBSERVACIONES SITUACION  CODIGOCTMESTACIONREDMETRO CODIGOEMPRESA  \
# 0            Subterránea         I                         29           NaN
# 1  Con Calle Valdelaguna         S                         30           NaN
# 2             Superficie         S                         31           NaN
# 3             Superficie         S                         32           NaN
# 4             Superficie         S                         33           NaN
#
# ...

# %%
df_metro_lig.shape
# (57, 53)
# Out:
# (57, 53)

# %%
df_metro_lig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   OBJECTID                        57 non-null     int64
#  1   IDESTACION                      57 non-null     object
#  2   FECHAACTUAL                     57 non-null     int64
#  3   MODO                            57 non-null     int64
#  4   CODIGOESTACION                  57 non-null     int64
#  5   DENOMINACION                    57 non-null     object
#  6   OBSERVACIONES                   48 non-null     object
#  7   SITUACION                       57 non-null     object
#  8   CODIGOCTMESTACIONREDMETRO       57 non-null     int64
#  9   CODIGOEMPRESA                   28 non-null     object
#  10  DENOMINACIONABREVIADA           0 non-null      float64
#  11  MODOINTERCAMBIADOR              57 non-null     int64
# ...

# %%
# Seleccionar columnas con al menos un valor nulo
metro_lig_con_nulos = df_metro_lig.columns[df_metro_lig.isna().any()]
df_metro_lig_con_nulos = df_metro_lig[metro_lig_con_nulos]
df_metro_lig_con_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   OBSERVACIONES                   48 non-null     object
#  1   CODIGOEMPRESA                   28 non-null     object
#  2   DENOMINACIONABREVIADA           0 non-null      float64
#  3   PARTICULA                       56 non-null     object
#  4   CALIFICADORPORTAL               5 non-null      object
#  5   CARRETERA                       0 non-null      float64
#  6   BARRIO                          12 non-null     float64
#  7   SECTORURBANO                    38 non-null     float64
#  8   SECTOR                          25 non-null     float64
#  9   ENCUESTAAFOROS                  0 non-null      float64
#  10  FECHAFIN                        0 non-null      float64
#  11  SITUACIONCALLE                  0 non-null      float64
# ...

# %%
df_metro_lig.columns
# Out:
# Index(['OBJECTID', 'IDESTACION', 'FECHAACTUAL', 'MODO', 'CODIGOESTACION',
#        'DENOMINACION', 'OBSERVACIONES', 'SITUACION',
#        'CODIGOCTMESTACIONREDMETRO', 'CODIGOEMPRESA', 'DENOMINACIONABREVIADA',
#        'MODOINTERCAMBIADOR', 'CODIGOINTERCAMBIADOR', 'TIPO', 'CODIGOPROVINCIA',
#        'CODIGOMUNICIPIO', 'CODIGOENTIDAD', 'CODIGONUCLEO', 'CODIGOVIA',
#        'TIPOVIA', 'PARTICULA', 'NOMBREVIA', 'TIPONUMERO', 'NUMEROPORTAL',
#        'CALIFICADORPORTAL', 'CARRETERA', 'CODIGOPOSTAL', 'DISTRITO',
#        'SECCIONCENSAL', 'BARRIO', 'TESELA', 'SECTORURBANO', 'SECTOR',
#        'CORREDOR', 'CORONATARIFARIA', 'CORONA123', 'ZONATRANSPORTE',
#        'ENCUESTADOMICILIARIA', 'ENCUESTAAFOROS', 'HOJA25000',
#        'ACONDICIONAMIENTOVIAJEROS', 'ACONDICIONAMIENTOVEHICULOS', 'FECHAALTA',
#        'FECHAINICIO', 'FECHAFIN', 'X', 'Y', 'GRADOACCESIBILIDAD',
#        'SITUACIONCALLE', 'DENOMINACION_SAE', 'INTERURBANOS_CODIGOEMT_CRTM',
# ...

# %%
# Quedarme solo con las columnas que necesitamos
columnas_metro_lig = df_metro_lig[['DENOMINACION', 'CODIGOMUNICIPIO',
       'TIPOVIA', 'PARTICULA', 'NOMBREVIA', 'CODIGOPOSTAL', 'DISTRITO', 'BARRIO', 'LINEAS']]
columnas_metro_lig.head()
# Out:
#          DENOMINACION  CODIGOMUNICIPIO TIPOVIA PARTICULA  \
# 0       MONTEPRINCIPE                7    Avda       del
# 1   VENTORRO DEL CANO                7    Avda       del
# 2    PRADO DEL ESPINO               22   Calle
# 3           CANTABRIA               22    Avda        de
# 4  FERIAL DE BOADILLA               22    Ctra        de
#
#                NOMBREVIA  CODIGOPOSTAL  DISTRITO  BARRIO  LINEAS
# 0          Montepríncipe         28925         1     NaN       3
# 1                Tranvía         28925         1     NaN       3
# 2             Labradores         28660         1     NaN       3
# 3              Cantabria         28660         1     NaN       3
# 4  Boadilla-Villaviciosa         28660         1     NaN       3

# %%
columnas_metro_lig = columnas_metro_lig.rename(columns={'DENOMINACION': 'nombre_estacion', 'CODIGOMUNICIPIO': 'cod_municipio', 'TIPOVIA': 'tipo_via', 'PARTICULA': 'particula', 'NOMBREVIA': 'nombre_via', 'CODIGOPOSTAL': 'cod_postal', 'DISTRITO': 'cod_distrito', 'BARRIO': 'cod_barrio', 'LINEAS': 'lineas_metro_ligero'})
columnas_metro_lig.head()
# Out:
#       nombre_estacion  cod_municipio tipo_via particula  \
# 0       MONTEPRINCIPE              7     Avda       del
# 1   VENTORRO DEL CANO              7     Avda       del
# 2    PRADO DEL ESPINO             22    Calle
# 3           CANTABRIA             22     Avda        de
# 4  FERIAL DE BOADILLA             22     Ctra        de
#
#               nombre_via  cod_postal  cod_distrito  cod_barrio  \
# 0          Montepríncipe       28925             1         NaN
# 1                Tranvía       28925             1         NaN
# 2             Labradores       28660             1         NaN
# 3              Cantabria       28660             1         NaN
# 4  Boadilla-Villaviciosa       28660             1         NaN
#
#    lineas_metro_ligero
# 0                    3
# 1                    3
# 2                    3
# 3                    3
# 4                    3

# %%
columnas_metro_lig = columnas_metro_lig[columnas_metro_lig['cod_municipio'] == 79]
columnas_metro_lig.head()
# Out:
#          nombre_estacion  cod_municipio tipo_via particula       nombre_via  \
# 10         BLASCO IBAÑEZ             79    Calle       del  Príncipe Carlos
# 11          PALAS DE REY             79    Calle        de     Palas de Rey
# 34    VIRGEN DEL CORTIJO             79     Avda        de        Manoteras
# 35         ANTONIO SAURA             79    Calle       del  Príncipe Carlos
# 36  ALVAREZ DE VILLAAMIL             79    Calle       del  Príncipe Carlos
#
#     cod_postal  cod_distrito  cod_barrio  lineas_metro_ligero
# 10       28050            16       166.0                    1
# 11       28050             8        86.0                    1
# 34       28050            16       166.0                    1
# 35       28050            16       166.0                    1
# 36       28050            16       166.0                    1

# %%
columnas_metro_lig.shape
# (12, 9)
# Out:
# (12, 9)

# %%
columnas_metro_lig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 10 to 50
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nombre_estacion      12 non-null     object
#  1   cod_municipio        12 non-null     int64
#  2   tipo_via             12 non-null     object
#  3   particula            12 non-null     object
#  4   nombre_via           12 non-null     object
#  5   cod_postal           12 non-null     int64
#  6   cod_distrito         12 non-null     int64
#  7   cod_barrio           12 non-null     float64
#  8   lineas_metro_ligero  12 non-null     int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 960.0+ bytes

# %%
# Transformar datos
columnas_metro_lig['nombre_estacion'] = columnas_metro_lig['nombre_estacion'].astype('string')
columnas_metro_lig['tipo_via'] = columnas_metro_lig['tipo_via'].astype('string')
columnas_metro_lig['particula'] = columnas_metro_lig['particula'].astype('string')
columnas_metro_lig['nombre_via'] = columnas_metro_lig['nombre_via'].astype('string')
columnas_metro_lig['cod_barrio'] = columnas_metro_lig['cod_barrio'].astype('int32')
columnas_metro_lig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 10 to 50
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   nombre_estacion      12 non-null     string
#  1   cod_municipio        12 non-null     int64
#  2   tipo_via             12 non-null     string
#  3   particula            12 non-null     string
#  4   nombre_via           12 non-null     string
#  5   cod_postal           12 non-null     int64
#  6   cod_distrito         12 non-null     int64
#  7   cod_barrio           12 non-null     int32
#  8   lineas_metro_ligero  12 non-null     int64
# dtypes: int32(1), int64(4), string(4)
# memory usage: 912.0 bytes

# %%
# Ordenar datos
columnas_metro_lig = columnas_metro_lig.sort_values(by='cod_barrio')
columnas_metro_lig = columnas_metro_lig.reset_index(drop=True)
columnas_metro_lig
# Out:
#          nombre_estacion  cod_municipio tipo_via particula  \
# 0           PALAS DE REY             79    Calle        de
# 1             LAS TABLAS             79    Calle        de
# 2    ESTACION DE ARAVACA             79    Calle     de la
# 3         COLONIA JARDIN             79    Calle        de
# 4         COLONIA JARDIN             79    Calle        de
# 5     PINAR DE CHAMARTIN             79    Calle        de
# 6          ANTONIO SAURA             79    Calle       del
# 7     VIRGEN DEL CORTIJO             79     Avda        de
# 8   ALVAREZ DE VILLAAMIL             79    Calle       del
# 9          BLASCO IBAÑEZ             79    Calle       del
# 10     FUENTE DE LA MORA             79    Calle        de
# 11           MARIA TUDOR             79    Calle        de
#
#              nombre_via  cod_postal  cod_distrito  cod_barrio  \
# 0          Palas de Rey       28050             8          86
# 1          Palas de Rey       28050             8          86
# ...

# %%
columnas_metro_lig.to_csv('metro_ligero_limpio.csv', index=False)
columnas_metro_lig.columns
# Out:
# Index(['nombre_estacion', 'cod_municipio', 'tipo_via', 'particula',
#        'nombre_via', 'cod_postal', 'cod_distrito', 'cod_barrio',
#        'lineas_metro_ligero'],
#       dtype='object')

# %% [markdown]
# ### COLUMNAS DEL DF DE ESTACIONES DE METRO LIGERO
# - `nombre_estacion`: string
# - `cod_municipio`: int64
# - `tipo_via`: string
# - `particula`: string
# - `nombre_via`: string
# - `cod_postal`: int64
# - `cod_distrito`: int64
# - `cod_barrio`: int32
# - `lineas_metro_ligero`: int64

# %% [markdown]
# # CERCANÍAS

# %%
# Cargar CSV M5_Estaciones_Cercanías.csv
df_cercanias = pd.read_csv('/Users/AleVC/Library/CloudStorage/GoogleDrive-ale.vaquero.c@gmail.com/My Drive/Nuclio/Máster en Data Science/TFM/Datos-adicionales/M5_Estaciones_Cercanías.csv')
df_cercanias.head()
# Out:
#    OBJECTID IDESTACION  FECHAACTUAL  MODO  CODIGOESTACION  \
# 0         1       5_70     20240628     5              70
# 1         2       5_69     20240628     5              69
# 2         3       5_85     20240628     5              85
# 3         4       5_84     20240628     5              84
# 4         5       5_15     20240628     5              15
#
#                    DENOMINACION OBSERVACIONES SITUACION  \
# 0      SAN CRISTÓBAL INDUSTRIAL        Ndup-E         S
# 1  SAN CRISTÓBAL DE LOS ANGELES           NaN         S
# 2               VALDELASFUENTES           NaN         I
# 3       UNIVERSIDAD P. COMILLAS           NaN         S
# 4       CANTOBLANCO UNIVERSIDAD           NaN         S
#
#    CODIGOCTMESTACIONREDMETRO  CODIGOEMPRESA  ...  FECHAINICIO  FECHAFIN  \
# 0                         70          60101  ...     19860101       NaN
# 1                         69          60107  ...     19860101       NaN
# ...

# %%
df_cercanias.shape
# (111, 53)
# Out:
# (111, 53)

# %%
df_cercanias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   OBJECTID                        111 non-null    int64
#  1   IDESTACION                      111 non-null    object
#  2   FECHAACTUAL                     111 non-null    int64
#  3   MODO                            111 non-null    int64
#  4   CODIGOESTACION                  111 non-null    int64
#  5   DENOMINACION                    111 non-null    object
#  6   OBSERVACIONES                   22 non-null     object
#  7   SITUACION                       111 non-null    object
#  8   CODIGOCTMESTACIONREDMETRO       111 non-null    int64
#  9   CODIGOEMPRESA                   111 non-null    int64
#  10  DENOMINACIONABREVIADA           0 non-null      float64
#  11  MODOINTERCAMBIADOR              96 non-null     float64
# ...

# %%
# Seleccionar columnas con al menos un valor nulo
cercanias_con_nulos = df_cercanias.columns[df_cercanias.isna().any()]
df_cercanias_con_nulos = df_cercanias[cercanias_con_nulos]
df_cercanias_con_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   OBSERVACIONES                   22 non-null     object
#  1   DENOMINACIONABREVIADA           0 non-null      float64
#  2   MODOINTERCAMBIADOR              96 non-null     float64
#  3   CODIGOINTERCAMBIADOR            96 non-null     float64
#  4   CODIGOENTIDAD                   107 non-null    float64
#  5   CODIGONUCLEO                    93 non-null     float64
#  6   PARTICULA                       95 non-null     object
#  7   CALIFICADORPORTAL               4 non-null      object
#  8   CARRETERA                       0 non-null      float64
#  9   CODIGOPOSTAL                    107 non-null    object
#  10  DISTRITO                        107 non-null    float64
#  11  SECCIONCENSAL                   97 non-null     float64
# ...

# %%
df_cercanias.columns
# Out:
# Index(['OBJECTID', 'IDESTACION', 'FECHAACTUAL', 'MODO', 'CODIGOESTACION',
#        'DENOMINACION', 'OBSERVACIONES', 'SITUACION',
#        'CODIGOCTMESTACIONREDMETRO', 'CODIGOEMPRESA', 'DENOMINACIONABREVIADA',
#        'MODOINTERCAMBIADOR', 'CODIGOINTERCAMBIADOR', 'TIPO', 'CODIGOPROVINCIA',
#        'CODIGOMUNICIPIO', 'CODIGOENTIDAD', 'CODIGONUCLEO', 'CODIGOVIA',
#        'TIPOVIA', 'PARTICULA', 'NOMBREVIA', 'TIPONUMERO', 'NUMEROPORTAL',
#        'CALIFICADORPORTAL', 'CARRETERA', 'CODIGOPOSTAL', 'DISTRITO',
#        'SECCIONCENSAL', 'BARRIO', 'TESELA', 'SECTORURBANO', 'SECTOR',
#        'CORREDOR', 'CORONATARIFARIA', 'CORONA123', 'ZONATRANSPORTE',
#        'ENCUESTADOMICILIARIA', 'ENCUESTAAFOROS', 'HOJA25000',
#        'ACONDICIONAMIENTOVIAJEROS', 'ACONDICIONAMIENTOVEHICULOS', 'FECHAALTA',
#        'FECHAINICIO', 'FECHAFIN', 'X', 'Y', 'GRADOACCESIBILIDAD',
#        'SITUACIONCALLE', 'DENOMINACION_SAE', 'INTERURBANOS_CODIGOEMT_CRTM',
# ...

# %%
df_cercanias_unicos = df_cercanias['CODIGOMUNICIPIO'].value_counts(ascending=True)
df_cercanias_unicos
# Out:
# CODIGOMUNICIPIO
# 83      1
# 73      1
# 76      1
# 80      1
# 904     1
# 135     1
# 45      1
# 903     1
# 85      1
# 16      1
# 115     1
# 257     1
# 25      1
# 181     1
# 194     1
# 47      1
# 130     1
# 93      1
# 113     1
# 87      1
# 106     1
# 34      1
# 40      1
# 186     1
# 13      1
# 125     1
# 183     1
# 152     2
# 58      2
# 46      2
# 6       2
# 38      2
# 49      2
# 161     2
# 148     2
# 54      2
# 61      2
# 92      2
# 19      2
# 168     2
# 10      2
# 74      3
# 7       3
# 5       3
# 127     3
# 65      5
# 79     39
# Name: count, dtype: int64

# %%
# Quedarme solo con las columnas que necesitamos
columnas_cercanias = df_cercanias[['DENOMINACION', 'CODIGOMUNICIPIO',
       'TIPOVIA', 'PARTICULA', 'NOMBREVIA', 'CODIGOPOSTAL', 'DISTRITO', 'BARRIO', 'LINEAS']]
columnas_cercanias.head()
# Out:
#                    DENOMINACION  CODIGOMUNICIPIO TIPOVIA PARTICULA  \
# 0      SAN CRISTÓBAL INDUSTRIAL               79   Acces      a la
# 1  SAN CRISTÓBAL DE LOS ANGELES               79   Calle        de
# 2               VALDELASFUENTES                6   Calle       del
# 3       UNIVERSIDAD P. COMILLAS               79    Ctra       del
# 4       CANTOBLANCO UNIVERSIDAD               79   Calle        de
#
#                 NOMBREVIA CODIGOPOSTAL  DISTRITO  BARRIO LINEAS
# 0         Colonia Marconi        28021      17.0   171.0    C-3
# 1                 Paterna        28021      17.0   172.0    C-3
# 2  Marqués de la Valdavia        28100       1.0     NaN    C-4
# 3                  Goloso        28790       8.0    88.0    C-4
# 4                   Freud        28049       8.0    88.0    C-4

# %%
columnas_cercanias = columnas_cercanias.rename(columns={'DENOMINACION': 'nombre_estacion', 'CODIGOMUNICIPIO': 'cod_municipio', 'TIPOVIA': 'tipo_via', 'PARTICULA': 'particula', 'NOMBREVIA': 'nombre_via', 'CODIGOPOSTAL': 'cod_postal', 'DISTRITO': 'cod_distrito', 'BARRIO': 'cod_barrio', 'LINEAS': 'lineas_cercanias'})
columnas_cercanias.head()
# Out:
#                 nombre_estacion  cod_municipio tipo_via particula  \
# 0      SAN CRISTÓBAL INDUSTRIAL             79    Acces      a la
# 1  SAN CRISTÓBAL DE LOS ANGELES             79    Calle        de
# 2               VALDELASFUENTES              6    Calle       del
# 3       UNIVERSIDAD P. COMILLAS             79     Ctra       del
# 4       CANTOBLANCO UNIVERSIDAD             79    Calle        de
#
#                nombre_via cod_postal  cod_distrito  cod_barrio  \
# 0         Colonia Marconi      28021          17.0       171.0
# 1                 Paterna      28021          17.0       172.0
# 2  Marqués de la Valdavia      28100           1.0         NaN
# 3                  Goloso      28790           8.0        88.0
# 4                   Freud      28049           8.0        88.0
#
#   lineas_cercanias
# 0              C-3
# 1              C-3
# 2              C-4
# 3              C-4
# 4              C-4

# %%
columnas_cercanias = columnas_cercanias[columnas_cercanias['cod_municipio'] == 79]
columnas_cercanias.head()
# Out:
#                 nombre_estacion  cod_municipio tipo_via particula  \
# 0      SAN CRISTÓBAL INDUSTRIAL             79    Acces      a la
# 1  SAN CRISTÓBAL DE LOS ANGELES             79    Calle        de
# 3       UNIVERSIDAD P. COMILLAS             79     Ctra       del
# 4       CANTOBLANCO UNIVERSIDAD             79    Calle        de
# 5                    FUENCARRAL             79    Calle        de
#
#            nombre_via cod_postal  cod_distrito  cod_barrio lineas_cercanias
# 0     Colonia Marconi      28021          17.0       171.0              C-3
# 1             Paterna      28021          17.0       172.0              C-3
# 3              Goloso      28790           8.0        88.0              C-4
# 4               Freud      28049           8.0        88.0              C-4
# 5  Antonio de Cabezón      28034           8.0        86.0              C-4

# %%
columnas_cercanias.shape
# (39, 9)
# Out:
# (39, 9)

# %%
columnas_cercanias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39 entries, 0 to 110
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nombre_estacion   39 non-null     object
#  1   cod_municipio     39 non-null     int64
#  2   tipo_via          39 non-null     object
#  3   particula         39 non-null     object
#  4   nombre_via        39 non-null     object
#  5   cod_postal        39 non-null     object
#  6   cod_distrito      39 non-null     float64
#  7   cod_barrio        39 non-null     float64
#  8   lineas_cercanias  39 non-null     object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 3.0+ KB

# %%
# Transformar datos
columnas_cercanias['nombre_estacion'] = columnas_cercanias['nombre_estacion'].astype('string')
columnas_cercanias['tipo_via'] = columnas_cercanias['tipo_via'].astype('string')
columnas_cercanias['particula'] = columnas_cercanias['particula'].astype('string')
columnas_cercanias['nombre_via'] = columnas_cercanias['nombre_via'].astype('string')
columnas_cercanias['cod_distrito'] = columnas_cercanias['cod_distrito'].astype('int32')
columnas_cercanias['cod_barrio'] = columnas_cercanias['cod_barrio'].astype('int32')
columnas_cercanias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39 entries, 0 to 110
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nombre_estacion   39 non-null     string
#  1   cod_municipio     39 non-null     int64
#  2   tipo_via          39 non-null     string
#  3   particula         39 non-null     string
#  4   nombre_via        39 non-null     string
#  5   cod_postal        39 non-null     object
#  6   cod_distrito      39 non-null     int32
#  7   cod_barrio        39 non-null     int32
#  8   lineas_cercanias  39 non-null     object
# dtypes: int32(2), int64(1), object(2), string(4)
# memory usage: 2.7+ KB

# %%
# Ordenar datos
columnas_cercanias = columnas_cercanias.sort_values(by='cod_barrio')
columnas_cercanias = columnas_cercanias.reset_index(drop=True)
columnas_cercanias
# Out:
#                  nombre_estacion  cod_municipio tipo_via particula  \
# 0                    EMBAJADORES             79      Gta        de
# 1                            SOL             79    Plaza     de la
# 2                      PIRÁMIDES             79    Paseo       del
# 3                       DELICIAS             79    Calle        de
# 4                  MÉNDEZ ÁLVARO             79    Calle       del
# 5                         ATOCHA             79     Avda     de la
# 6                      RECOLETOS             79    Paseo        de
# 7                      CHAMARTÍN             79    Calle        de
# 8             NUEVOS MINISTERIOS             79    Calle        de
# 9                  RAMÓN Y CAJAL             79    Calle        de
# 10                    FUENCARRAL             79    Calle        de
# 11                         PITIS             79     Ctra      a la
# 12      MIRASIERRA-PACO DE LUCÍA             79    Calle     de la
# ...

# %%
columnas_cercanias.to_csv('cercanias_limpio.csv', index=False)
columnas_cercanias.columns
# Out:
# Index(['nombre_estacion', 'cod_municipio', 'tipo_via', 'particula',
#        'nombre_via', 'cod_postal', 'cod_distrito', 'cod_barrio',
#        'lineas_cercanias'],
#       dtype='object')

# %% [markdown]
# ### COLUMNAS DEL DF DE ESTACIONES DE CERCANÍAS
# - `nombre_estacion`: string
# - `cod_municipio`: int64
# - `tipo_via`: string
# - `particula`: string
# - `nombre_via`: string
# - `cod_postal`: int64
# - `cod_distrito`: int32
# - `cod_barrio`: int32
# - `lineas_cercanias`: int64

# %% [markdown]
# # BUSES URBANOS

# %%
# Cargar CSV M6_Estaciones_Buses_Urbanos.csv
df_buses = pd.read_csv('/Users/AleVC/Library/CloudStorage/GoogleDrive-ale.vaquero.c@gmail.com/My Drive/Nuclio/Máster en Data Science/TFM/Datos-adicionales/M6_Estaciones_Buses_Urbanos.csv')
df_buses.head()
# Out:
#    OBJECTID IDESTACION  FECHAACTUAL  MODO  CODIGOESTACION  \
# 0         1     6_3061     20240117     6            3061
# 1         2     6_3007     20240117     6            3007
# 2         3     6_3066     20240117     6            3066
# 3         4     6_2948     20240117     6            2948
# 4         5     6_2953     20240117     6            2953
#
#                              DENOMINACION OBSERVACIONES SITUACION  \
# 0             AV.PABLO NERUDA-MALGRAT MAR           NaN         S
# 1          CERRO DEL CASTAÑAR-MORALZARZAL           NaN         S
# 2                   ANDALUCES-SAN CLAUDIO           NaN         S
# 3   CTRA.VILLAVERDE A VALLECAS-AV.ROSALES           NaN         S
# 4  CTRA.CCHEL A VILLAVERDE-CENTRO ESCOLAR           NaN         S
#
#    CODIGOCTMESTACIONREDMETRO  CODIGOEMPRESA  ... FECHAINICIO  FECHAFIN  \
# 0                        NaN           2522  ...    19861001       NaN
# 1                        NaN           1748  ...    19861001       NaN
# ...

# %%
df_buses.shape
# (4852, 53)
# Out:
# (4852, 53)

# %%
df_buses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4852 entries, 0 to 4851
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   OBJECTID                        4852 non-null   int64
#  1   IDESTACION                      4852 non-null   object
#  2   FECHAACTUAL                     4852 non-null   int64
#  3   MODO                            4852 non-null   int64
#  4   CODIGOESTACION                  4852 non-null   int64
#  5   DENOMINACION                    4852 non-null   object
#  6   OBSERVACIONES                   587 non-null    object
#  7   SITUACION                       4852 non-null   object
#  8   CODIGOCTMESTACIONREDMETRO       1 non-null      float64
#  9   CODIGOEMPRESA                   4852 non-null   int64
#  10  DENOMINACIONABREVIADA           3480 non-null   object
#  11  MODOINTERCAMBIADOR              1129 non-null   float64
# ...

# %%
# Seleccionar columnas con al menos un valor nulo
buses_con_nulos = df_buses.columns[df_buses.isna().any()]
df_buses_con_nulos = df_buses[buses_con_nulos]
df_buses_con_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4852 entries, 0 to 4851
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   OBSERVACIONES                   587 non-null    object
#  1   CODIGOCTMESTACIONREDMETRO       1 non-null      float64
#  2   DENOMINACIONABREVIADA           3480 non-null   object
#  3   MODOINTERCAMBIADOR              1129 non-null   float64
#  4   CODIGOINTERCAMBIADOR            1128 non-null   float64
#  5   CODIGONUCLEO                    2839 non-null   float64
#  6   TIPOVIA                         4851 non-null   object
#  7   PARTICULA                       4767 non-null   object
#  8   NOMBREVIA                       4851 non-null   object
#  9   CALIFICADORPORTAL               291 non-null    object
#  10  CARRETERA                       0 non-null      float64
#  11  SECCIONCENSAL                   4636 non-null   float64
# ...

# %%
df_buses.columns
# Out:
# Index(['OBJECTID', 'IDESTACION', 'FECHAACTUAL', 'MODO', 'CODIGOESTACION',
#        'DENOMINACION', 'OBSERVACIONES', 'SITUACION',
#        'CODIGOCTMESTACIONREDMETRO', 'CODIGOEMPRESA', 'DENOMINACIONABREVIADA',
#        'MODOINTERCAMBIADOR', 'CODIGOINTERCAMBIADOR', 'TIPO', 'CODIGOPROVINCIA',
#        'CODIGOMUNICIPIO', 'CODIGOENTIDAD', 'CODIGONUCLEO', 'CODIGOVIA',
#        'TIPOVIA', 'PARTICULA', 'NOMBREVIA', 'TIPONUMERO', 'NUMEROPORTAL',
#        'CALIFICADORPORTAL', 'CARRETERA', 'CODIGOPOSTAL', 'DISTRITO',
#        'SECCIONCENSAL', 'BARRIO', 'TESELA', 'SECTORURBANO', 'SECTOR',
#        'CORREDOR', 'CORONATARIFARIA', 'CORONA123', 'ZONATRANSPORTE',
#        'ENCUESTADOMICILIARIA', 'ENCUESTAAFOROS', 'HOJA25000',
#        'ACONDICIONAMIENTOVIAJEROS', 'ACONDICIONAMIENTOVEHICULOS', 'FECHAALTA',
#        'FECHAINICIO', 'FECHAFIN', 'X', 'Y', 'GRADOACCESIBILIDAD',
#        'SITUACIONCALLE', 'DENOMINACION_SAE', 'INTERURBANOS_CODIGOEMT_CRTM',
# ...

# %%
df_buses_unicos = df_buses['CODIGOMUNICIPIO'].value_counts(ascending=True)
df_buses_unicos
# Out:
# CODIGOMUNICIPIO
# 80        2
# 115       4
# 79     4846
# Name: count, dtype: int64

# %%
# Quedarme solo con las columnas que necesitamos
columnas_buses = df_buses[['DENOMINACION', 'CODIGOMUNICIPIO',
       'TIPOVIA', 'PARTICULA', 'NOMBREVIA', 'CODIGOPOSTAL', 'DISTRITO', 'BARRIO', 'LINEAS']]
columnas_buses.head()
# Out:
#                              DENOMINACION  CODIGOMUNICIPIO TIPOVIA PARTICULA  \
# 0             AV.PABLO NERUDA-MALGRAT MAR               79    Avda        de
# 1          CERRO DEL CASTAÑAR-MORALZARZAL               79   Calle       del
# 2                   ANDALUCES-SAN CLAUDIO               79   Calle    de los
# 3   CTRA.VILLAVERDE A VALLECAS-AV.ROSALES               79    Ctra        de
# 4  CTRA.CCHEL A VILLAVERDE-CENTRO ESCOLAR               79    Ctra        de
#
#                   NOMBREVIA  CODIGOPOSTAL  DISTRITO  BARRIO        LINEAS
# 0              Pablo Neruda         28038        13   135.0  54, 142, 144
# 1        Cerro del Castañar         28034         8    87.0           134
# 2                 Andaluces         28038        13   134.0            54
# 3     Villaverde a Vallecas         28041        17   174.0       23, 130
# 4  Carabanchel a Villaverde         28021        17   171.0           131

# %%
columnas_buses = columnas_buses.rename(columns={'DENOMINACION': 'nombre_estacion', 'CODIGOMUNICIPIO': 'cod_municipio', 'TIPOVIA': 'tipo_via', 'PARTICULA': 'particula', 'NOMBREVIA': 'nombre_via', 'CODIGOPOSTAL': 'cod_postal', 'DISTRITO': 'cod_distrito', 'BARRIO': 'cod_barrio', 'LINEAS': 'lineas_buses'})
columnas_buses.head()
# Out:
#                           nombre_estacion  cod_municipio tipo_via particula  \
# 0             AV.PABLO NERUDA-MALGRAT MAR             79     Avda        de
# 1          CERRO DEL CASTAÑAR-MORALZARZAL             79    Calle       del
# 2                   ANDALUCES-SAN CLAUDIO             79    Calle    de los
# 3   CTRA.VILLAVERDE A VALLECAS-AV.ROSALES             79     Ctra        de
# 4  CTRA.CCHEL A VILLAVERDE-CENTRO ESCOLAR             79     Ctra        de
#
#                  nombre_via  cod_postal  cod_distrito  cod_barrio  \
# 0              Pablo Neruda       28038            13       135.0
# 1        Cerro del Castañar       28034             8        87.0
# 2                 Andaluces       28038            13       134.0
# 3     Villaverde a Vallecas       28041            17       174.0
# 4  Carabanchel a Villaverde       28021            17       171.0
#
#    lineas_buses
# 0  54, 142, 144
# 1           134
# 2            54
# 3       23, 130
# 4           131

# %%
columnas_buses = columnas_buses[columnas_buses['cod_municipio'] == 79]
columnas_buses.head()
# Out:
#                           nombre_estacion  cod_municipio tipo_via particula  \
# 0             AV.PABLO NERUDA-MALGRAT MAR             79     Avda        de
# 1          CERRO DEL CASTAÑAR-MORALZARZAL             79    Calle       del
# 2                   ANDALUCES-SAN CLAUDIO             79    Calle    de los
# 3   CTRA.VILLAVERDE A VALLECAS-AV.ROSALES             79     Ctra        de
# 4  CTRA.CCHEL A VILLAVERDE-CENTRO ESCOLAR             79     Ctra        de
#
#                  nombre_via  cod_postal  cod_distrito  cod_barrio  \
# 0              Pablo Neruda       28038            13       135.0
# 1        Cerro del Castañar       28034             8        87.0
# 2                 Andaluces       28038            13       134.0
# 3     Villaverde a Vallecas       28041            17       174.0
# 4  Carabanchel a Villaverde       28021            17       171.0
#
#    lineas_buses
# 0  54, 142, 144
# 1           134
# 2            54
# 3       23, 130
# 4           131

# %%
columnas_buses.shape
# (4846, 9)
# Out:
# (4846, 9)

# %%
columnas_buses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4846 entries, 0 to 4851
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nombre_estacion  4846 non-null   object
#  1   cod_municipio    4846 non-null   int64
#  2   tipo_via         4846 non-null   object
#  3   particula        4762 non-null   object
#  4   nombre_via       4845 non-null   object
#  5   cod_postal       4846 non-null   int64
#  6   cod_distrito     4846 non-null   int64
#  7   cod_barrio       4631 non-null   float64
#  8   lineas_buses     4841 non-null   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 378.6+ KB

# %%
# Visualizar filas con al menos un valor nulo
df_buses_barrios_nulos = columnas_buses[columnas_buses['cod_barrio'].isna()]
df_buses_barrios_nulos
# Out:
#                            nombre_estacion  cod_municipio tipo_via particula  \
# 25                  CANTALEJO-ARROYOFRESNO             79    Calle        de
# 37                 Pº PONTONES-Pº IMPERIAL             79    Paseo        de
# 41           AV.JUAN HERRERA-MARTIN FIERRO             79     Avda        de
# 50          VENTISQUERO CONDESA-C.MINGUETE             79     Avda       del
# 62         VALLE ENMEDIO-GTA.P.CORRALILLOS             79    Calle       del
# ...                                    ...            ...      ...       ...
# 3975              DOCTOR RAMON CASTROVIEJO             79    Calle       del
# 4003                   Pº YESERIAS-ARGANDA             79    Paseo        de
# 4015  VENTISQUERO CONDESA-VALLE DE ENMEDIO             79     Avda       del
# 4027                 Pº HABANA-CREVILLENTE             79    Paseo     de la
# 4040             ANTONIO MACHADO-VALDERREY             79    Calle        de
#
# ...

# %%
df_buses_lineas_nulos = columnas_buses[columnas_buses['lineas_buses'].isna()]
df_buses_lineas_nulos
# Out:
#                               nombre_estacion  cod_municipio tipo_via  \
# 1782       NICETO ALCALA ZAMORA-ISABEL VALOIS             79     Avda
# 3981  HOSPITAL 12 DE OCTUBRE-DR.TOLOSA LATOUR             79     Avda
# 4381      ENTRADA PPAL.HOSPITAL 12 DE OCTUBRE             79     Avda
# 4622  AV.FUERZAS ARMADAS-EDUARDO HARO TECGLEN             79     Avda
# 4837        REAL DE ARGANDA-PZA.JUAN MALASAÑA             79    Calle
#
#      particula                            nombre_via  cod_postal  \
# 1782        de                  Niceto Alcalá Zamora       28050
# 3981        de                               Córdoba       28041
# 4381        de                               Córdoba       28041
# 4622            Provisional Parque de Valdebebas Uno       28055
# 4837                                 Real de Arganda       28031
#
#       cod_distrito  cod_barrio lineas_buses
# 1782            16       166.0          NaN
# 3981            12       122.0          NaN
# ...

# %%
# Rellenar nulos
columnas_buses['particula'] = columnas_buses['particula'].fillna('NaN')
columnas_buses['nombre_via'] = columnas_buses['nombre_via'].fillna('desconocido')
columnas_buses['cod_barrio'] = columnas_buses['cod_barrio'].fillna(-1)
columnas_buses['lineas_buses'] = columnas_buses['lineas_buses'].fillna('desconocido')
columnas_buses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4846 entries, 0 to 4851
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nombre_estacion  4846 non-null   object
#  1   cod_municipio    4846 non-null   int64
#  2   tipo_via         4846 non-null   object
#  3   particula        4846 non-null   object
#  4   nombre_via       4846 non-null   object
#  5   cod_postal       4846 non-null   int64
#  6   cod_distrito     4846 non-null   int64
#  7   cod_barrio       4846 non-null   float64
#  8   lineas_buses     4846 non-null   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 378.6+ KB

# %%
# Transformar datos
columnas_buses['nombre_estacion'] = columnas_buses['nombre_estacion'].astype('string')
columnas_buses['tipo_via'] = columnas_buses['tipo_via'].astype('string')
columnas_buses['particula'] = columnas_buses['particula'].astype('string')
columnas_buses['nombre_via'] = columnas_buses['nombre_via'].astype('string')
columnas_buses['cod_barrio'] = columnas_buses['cod_barrio'].astype('int32')
columnas_buses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4846 entries, 0 to 4851
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nombre_estacion  4846 non-null   string
#  1   cod_municipio    4846 non-null   int64
#  2   tipo_via         4846 non-null   string
#  3   particula        4846 non-null   string
#  4   nombre_via       4846 non-null   string
#  5   cod_postal       4846 non-null   int64
#  6   cod_distrito     4846 non-null   int64
#  7   cod_barrio       4846 non-null   int32
#  8   lineas_buses     4846 non-null   object
# dtypes: int32(1), int64(3), object(1), string(4)
# memory usage: 359.7+ KB

# %%
# Ordenar datos
columnas_buses = columnas_buses.sort_values(by='cod_barrio')
columnas_buses = columnas_buses.reset_index(drop=True)
columnas_buses
# Out:
#                          nombre_estacion  cod_municipio tipo_via particula  \
# 0                Pº INFANTA ISABEL Nº 25             79    Paseo     de la
# 1         TORPEDERO TUCUMAN-ALFONSO XIII             79    Calle        de
# 2       Pº REINA CRISTINA-JULIAN GAYARRE             79    Paseo     de la
# 3           AV.PIO XII-COMANDANTE FRANCO             79     Avda        de
# 4          MQUES.DE ZAFRA-MQUES.MONDEJAR             79    Paseo       del
# ...                                  ...            ...      ...       ...
# 4841               RIBERA DEL LOIRA Nº16             79    Calle     de la
# 4842      CAMPO NACIONES-GTA.J.DE BORBON             79      Gta        de
# 4843               PARTENON-GTA.HAMBURGO             79     Avda       del
# 4844          BAHIA POLLENSA-BAHIA GANDO             79    Calle        de
# 4845  BAHIA DE LA CONCHA-BAHIA DE MALAGA             79    Calle        de
#
# ...

# %%
columnas_buses.to_csv('buses_limpio.csv', index=False)
columnas_buses.columns
# Out:
# Index(['nombre_estacion', 'cod_municipio', 'tipo_via', 'particula',
#        'nombre_via', 'cod_postal', 'cod_distrito', 'cod_barrio',
#        'lineas_buses'],
#       dtype='object')

# %% [markdown]
# ### COLUMNAS DEL DF DE ESTACIONES DE BUSES URBANOS
# - `nombre_estacion`: string
# - `cod_municipio`: int64
# - `tipo_via`: string
# - `particula`: string
# - `nombre_via`: string
# - `cod_postal`: int64
# - `cod_distrito`: int64
# - `cod_barrio`: int32
# - `lineas_buses`: object

# %% [markdown]
# # POSTES DE BUSES

# %%
# Cargar CSV M6_Postes_Buses_Urbanos.csv
df_postes = pd.read_csv('/Users/AleVC/Library/CloudStorage/GoogleDrive-ale.vaquero.c@gmail.com/My Drive/Nuclio/Máster en Data Science/TFM/Datos-adicionales/M6_Postes_Buses_Urbanos.csv')
df_postes.head()
# Out:
#    OBJECTID   IDPOSTE  FECHAACTUAL  MODO  CODIGOESTACION CODIGOPOSTE  \
# 0         1  6_5306_*     20240628     6            5306           *
# 1         2  6_5313_*     20240628     6            5313           *
# 2         3  6_5315_*     20240628     6            5315           *
# 3         4     6_8_*     20240628     6               8           *
# 4         5   6_235_*     20240628     6             235           *
#
#    OBSERVACIONES IDENTIFICATIVO CODIGOTIPOPOSTE CODIGOEMPRESA  ...  FECHAALTA  \
# 0            NaN             PS               6           100  ...   20140626
# 1            NaN             PS               6           100  ...   20050630
# 2            NaN             PS               6           100  ...   20150211
# 3            NaN             PS               6           100  ...   20181126
# 4            NaN             PS               6           100  ...   20201203
#
#    FECHAINICIO  FECHAFIN             X             Y  CODIGOMUNICIPIO  \
# ...

# %%
df_postes.shape
# (4852, 21)
# Out:
# (4852, 21)

# %%
df_postes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4852 entries, 0 to 4851
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OBJECTID              4852 non-null   int64
#  1   IDPOSTE               4852 non-null   object
#  2   FECHAACTUAL           4852 non-null   int64
#  3   MODO                  4852 non-null   int64
#  4   CODIGOESTACION        4852 non-null   int64
#  5   CODIGOPOSTE           4852 non-null   object
#  6   OBSERVACIONES         0 non-null      float64
#  7   IDENTIFICATIVO        4852 non-null   object
#  8   CODIGOTIPOPOSTE       4852 non-null   object
#  9   CODIGOEMPRESA         4852 non-null   object
#  10  CODIGODARSENA         0 non-null      float64
#  11  FECHAALTA             4852 non-null   int64
#  12  FECHAINICIO           0 non-null      float64
#  13  FECHAFIN              0 non-null      float64
#  14  X                     4840 non-null   float64
# ...

# %%
# Seleccionar columnas con al menos un valor nulo
postes_con_nulos = df_postes.columns[df_postes.isna().any()]
df_postes_con_nulos = df_postes[postes_con_nulos]
df_postes_con_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4852 entries, 0 to 4851
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OBSERVACIONES         0 non-null      float64
#  1   CODIGODARSENA         0 non-null      float64
#  2   FECHAINICIO           0 non-null      float64
#  3   FECHAFIN              0 non-null      float64
#  4   X                     4840 non-null   float64
#  5   Y                     4840 non-null   float64
#  6   FECHAMAQUETACIONTIRA  4003 non-null   object
#  7   FECHACOLOCACIONTIRA   1 non-null      object
# dtypes: float64(6), object(2)
# memory usage: 303.4+ KB

# %%
df_postes.columns
# Out:
# Index(['OBJECTID', 'IDPOSTE', 'FECHAACTUAL', 'MODO', 'CODIGOESTACION',
#        'CODIGOPOSTE', 'OBSERVACIONES', 'IDENTIFICATIVO', 'CODIGOTIPOPOSTE',
#        'CODIGOEMPRESA', 'CODIGODARSENA', 'FECHAALTA', 'FECHAINICIO',
#        'FECHAFIN', 'X', 'Y', 'CODIGOMUNICIPIO', 'CODIGOPROVINCIA',
#        'FECHAMAQUETACIONTIRA', 'FECHACOLOCACIONTIRA', 'IDFESTACION'],
#       dtype='object')

# %%
df_postes_unicos = df_postes['CODIGOMUNICIPIO'].value_counts(ascending=True)
df_postes_unicos
# Out:
# CODIGOMUNICIPIO
# 80        2
# 115       4
# 79     4846
# Name: count, dtype: int64

# %%
# NO TIENE LAS MISMAS COLUMNAS QUE LOS OTROS DATA FRAME DE TRANSPORTE PÚBLICO. NO TENEMOS LA INFORMACIÓN NECESARIA PARA QUE GENERE VALOR AL HACER MERGE
