# %% [markdown]
# ![Nuclio logo](https://nuclio.school/wp-content/uploads/2018/12/nucleoDS-newBlack.png)

# %% [markdown]
# # CAPSTONE PROJECT: Predicción de precios de las viviendas en Madrid
# Limpieza de datos: Pisos.com

# %% [markdown]
# Meta de creación de columnas:
# - `fecha_descarga`
# - `web`
# - `url`
# - `precio`
# - `barrio`
# - `distrito`
# - `codigo_postal`
# - `metros_utiles`
# - `metros_construidos`
# - `num_hab`
# - `num_banos`
# - `planta`
# - `tipologia`
# - `obra_nueva`
# - `cocina`
# - `garage`
# - `trastero`
# - `orientacion`
# - `estado`
# - `antiguedad`
# - `consumo`
# - `fecha_publicacion`
# - `subasta`
# - `visitas`
# - `amueblado`
# - `calefaccion`
# - `terraza`
# - `balcon`
# - `piscina`
# - `jardin`
# - `aire_acondionado`
# - `detalle`
#
# Dos datasets recibidos
# - Detalles_datasales19102024.xlsx
# - Detalles2_datasales19102024.xlsx

# %%
import pandas as pd
import numpy as np
import re
import plotly.express as px

pd.options.plotting.backend = 'plotly' # Para ejecutar las gráficas con Plotly y no Matpolotlib.

# Ajustar pandas para mostrar contenido completo
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

# pd.reset_option('display.max_columns')
# pd.reset_option('display.max_rows')
# pd.reset_option('display.max_colwidth')

# %% [markdown]
# # Explorar los dataframes de "detalles"

# %% [markdown]
# ### TRANSFORMAR COLUMNAS Y MERGE

# %%
df_detalles1 = pd.read_excel('/Detalles_datasales19102024.xlsx')
df_detalles1.tail(1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_detalles1 = pd.read_excel('/Detalles_datasales19102024.xlsx')
#       2 df_detalles1.tail(1)
#
# File /opt/anaconda3/envs/Nuclio/lib/python3.12/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File /opt/anaconda3/envs/Nuclio/lib/python3.12/site-packages/pandas/io/excel/_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File /opt/anaconda3/envs/Nuclio/lib/python3.12/site-packages/pandas/io/excel/_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File /opt/anaconda3/envs/Nuclio/lib/python3.12/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Detalles_datasales19102024.xlsx'

# %%
df_detalles2 = pd.read_excel('/Users/AleVC/Library/CloudStorage/GoogleDrive-ale.vaquero.c@gmail.com/My Drive/Nuclio/Máster en Data Science/TFM/PisosCom/Detalles2_datasales19102024.xlsx')
df_detalles2.head(1)
# Out:
#       Campo1   Campo2  Campo3 Campo4     Campo5      Campo6  \
# 0  245.000 €  2 habs.  1 baño  42 m²  3ª planta  5.833 €/m²
#
#                                          Título  \
# 0  Apartamento en venta en Paseo de las Acacias
#
#                                           Campo7  \
# 0  Acacias (Distrito Arganzuela. Madrid Capital)
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Campo8  \
# 0  Situado en el céntrico Paseo de las Acacias.\n\nActualmente alquilado con una rentabilidad del 5,0%\n\nEl apartamento se ha reformado con un diseño y decoración moderna, está compuesto por un salón comedor con cocina abierta. El baño se encuentra distribuido en dos partes: cuenta con plato de ducha y mampara y en la parte exterior el lavabo.\n\nLa cocina, equipada con todos los electrodomésticos necesarios.\n\nDetalles:\nSuelo de tarima flotante,\nVentanas de madera\nParedes son lisas\nArmarios empotrados\nAire acondicionado\nCalefacción eléctrica\n\nLa vivienda está situada en una zona espléndida de Madrid, en el Paseo de las Acacias  a escasos metros de la parada Acacias L5 de metro, próximo a todo tipo de servicios, centros de salud, centros comerciales, supermercados, centros culturales y transporte público.
#
#                                                                                                            Campo9  \
# 0  Superficie construida: \n                                                                                42 m²
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Campo10  \
# 0  Superficie construida: \n                                                                                42 m²\n                                                                \n                            \n                            \n                                                                \n                                                                \n                                                                        Habitaciones: \n                                                                                2\n                                                                \n                            \n                            \n                                                                \n                                                                \n                                                                        Baños: \n                                                                                1\n                                                                \n                            \n                            \n                                                                \n                                                                \n                                                                        Planta: \n                                                                                3ª\n                                                                \n                            \n                            \n                                                                \n                                                                \n                                                                        Interior\n                                                                \n                            \n                            \n                                                                \n                                                                \n                                                                        Conservación: \n                                                                                En buen estado\n                                                                \n                            \n                            \n                                                                \n                                                                \n                                                                        Referencia: \n                                                                                SA179-IM/VENTAPACACIAS0924
#
#                            Tiempo                           Campo11  \
# 0  Baños: \n\t\t\t\t\t\t\t\t\t\t1  Planta: \n\t\t\t\t\t\t\t\t\t\t3ª
#
#                                                                                              Tiempo1  \
# 0  Habitaciones: \n                                                                                2
#
#                      Campo12                 Campo13  \
# 0  Clasificación: En trámite  Certificado energético
#
#                              Campo14                           Campo15
# 0  Anuncio actualizado el 25/09/2024  Ref.: SA179-IM/VENTAPACACIAS0924

# %%
df_detalles1.shape
# (2868, 21)
# Out:
# (2868, 21)

# %%
df_detalles2.shape
# (2807, 18)
# Out:
# (2807, 18)

# %%
df_detalles1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2868 entries, 0 to 2867
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Campo1          2867 non-null   object
#  1   Campo2          2860 non-null   object
#  2   Título          2617 non-null   object
#  3   Campo3          2617 non-null   object
#  4   Campo4          2867 non-null   object
#  5   Campo5          2789 non-null   object
#  6   Campo6          2867 non-null   object
#  7   Campo7          2715 non-null   object
#  8   Campo8          2867 non-null   object
#  9   Campo9_texto    2867 non-null   object
#  10  Campo9_enlaces  2867 non-null   object
#  11  Campo10         2867 non-null   object
#  12  Campo11         2866 non-null   object
#  13  Campo12         0 non-null      float64
#  14  Campo13         0 non-null      float64
#  15  Campo14         0 non-null      float64
#  16  Campo15         0 non-null      float64
#  17  Campo16         0 non-null      float64
#  18  Campo17         0 non-null      float64
#  19  Campo18         0 non-null      float64
#  20  Campo19         0 non-null      float64
# dtypes: float64(8), object(13)
# memory usage: 470.7+ KB

# %%
df_detalles2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2807 entries, 0 to 2806
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Campo1   2806 non-null   object
#  1   Campo2   2799 non-null   object
#  2   Campo3   2799 non-null   object
#  3   Campo4   2790 non-null   object
#  4   Campo5   2710 non-null   object
#  5   Campo6   1767 non-null   object
#  6   Título   2563 non-null   object
#  7   Campo7   2563 non-null   object
#  8   Campo8   2806 non-null   object
#  9   Campo9   2806 non-null   object
#  10  Campo10  2806 non-null   object
#  11  Tiempo   2797 non-null   object
#  12  Campo11  2762 non-null   object
#  13  Tiempo1  2804 non-null   object
#  14  Campo12  2806 non-null   object
#  15  Campo13  2806 non-null   object
#  16  Campo14  2806 non-null   object
#  17  Campo15  2805 non-null   object
# dtypes: object(18)
# memory usage: 394.9+ KB

# %%
df_detalles1 = df_detalles1.drop(['Campo5', 'Campo7', 'Campo9_texto', 'Campo12', 'Campo13', 'Campo14', 'Campo15', 'Campo16', 'Campo17', 'Campo18', 'Campo19'], axis=1)
df_detalles1.shape
# 2868, 10
# Out:
# (2868, 10)

# %%
df_detalles2 = df_detalles2.drop(['Tiempo', 'Campo9', 'Campo11', 'Tiempo1', 'Campo13'], axis=1)
df_detalles2.shape
# (2807, 13)
# Out:
# (2807, 13)

# %%
df_detalles1.columns
# Out:
# Index(['Campo1', 'Campo2', 'Título', 'Campo3', 'Campo4', 'Campo6', 'Campo8',
#        'Campo9_enlaces', 'Campo10', 'Campo11'],
#       dtype='object')

# %%
df_detalles2.columns
# Out:
# Index(['Campo1', 'Campo2', 'Campo3', 'Campo4', 'Campo5', 'Campo6', 'Título',
#        'Campo7', 'Campo8', 'Campo10', 'Campo12', 'Campo14', 'Campo15'],
#       dtype='object')

# %%
df_detalles1 = df_detalles1.rename(columns={'Campo1': 'precio', 'Campo2': 'espacios', 'Título': 'title', 'Campo3': 'distrito', 'Campo4': 'detalle', 'Campo6': 'caracteristicas', 'Campo8': 'consumo', 'Campo9_enlaces': 'url', 'Campo10': 'actualizacion', 'Campo11': 'referencia'})
df_detalles1.tail(1)
# Out:
#          precio  \
# 2867  179.500 €
#
#                                                                    espacios  \
# 2867  2 habs.\n\t\t\t1 baño\n\t\t\t69 m²\n\t\t\t2ª planta\n\t\t\t2.601 €/m²
#
#                                                                         title  \
# 2867  Piso en venta en Calle de Silvio Abad, cerca de Calle de Antonio Prieto
#
#                                     distrito  \
# 2867  Zofío (Distrito Usera. Madrid Capital)
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           detalle  \
# 2867  Linkcasa Embajadores Servicio Inmobiliario te ofrece en exclusiva esta acogedora vivienda en una ubicación céntrico, en la zona de Zofío, perteneciente al distrito de USERA muy cercano a la Plaza Elíptica.\n\nLa vivienda se localiza en la planta 2ª del edificio.  El estado de la vivienda está para ENTRAR A VIVIR. \n\nEl inmueble tiene la siguiente distribución:\n\n- Hall de entrada con pasillo distribuidor.\n\n- Salón Comedor muy luminoso (Actualmente se utiliza como habitación), con acceso a una terraza amplia con toldo.\n\n- Cocina INDEPENDIENTE, amueblada y equipada con espacio de almacenaje y cómoda para cocinar, con acceso a tendedero.\n\n- 2 Dormitorios espaciosos.\n\n- 1 baño completo.\n \n\nOtras características:\nLa vivienda se encuentra en una ubicación inigualable, a 600 m de Plaza Elíptica, varios colegios de primaria y secundaria, a 100 m se encuentra el Transbordador de la zona sur de Madrid con autobuses para muchos barrios de Madrid y extrarradios.\n\nEl Zofío es un barrio de Madrid (España) situado en distrito de Usera. Limita al norte con Marcelo Usera, al oeste con la A-42, al este con Rafaela Ybarra y al sur con la avenida de los Poblados. Zona dotada de todo tipo de servicios y comercios.\n\nSi deseas visitar esta propiedad, no dudes en ponerte en contacto con nosotros para organizar una visita personalizada. ¡Estaremos encantados de atenderte!
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      caracteristicas  \
# 2867  Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t69 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie útil: \n\t\t\t\t\t\t\t\t\t\t66 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t2\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPlanta: \n\t\t\t\t\t\t\t\t\t\t2ª\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tAntigüedad: \n\t\t\t\t\t\t\t\t\t\tMás de 50 años\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tGastos de comunidad: \n\t\t\t\t\t\t\t\t\t\tEntre 20 y 40 €\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\tSA1457-E-0050/5300\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Muebles y acabados\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tArmarios empotrados: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tAgua\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTeléfono\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tCalefacción: \n\t\t\t\t\t\t\t\t\t\tGas natural\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tComedor\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPuerta blindada\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTerraza\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          consumo  \
# 2867  Certificado energético\n\n        Clasificación: No indicado\n\n\n\n        Ver detalle \n\n        \n            \n                \n                \n                    \n                        \n                        \n                    \n                    \n                        \n                        \n                            \n                                \n                                    \n                                        Certificado energético\n                                    \n                                    \n                                        La certificación energética indica la eficiencia del inmueble en cuanto a consumo de energía, agua, etc.  La categoría A es la más eficiente y la G la menos.\n                                    \n                                    Etiqueta de certificación energética\n\n                                        Este anuncio no dispone de etiqueta de certificación energética ya que el anunciante comunica que está "no indicado".
#
#                                                                      url  \
# 2867  https://www.pisos.com/comprar/piso-zofio28026-47515110475_100500/#
#
#                                                     actualizacion  \
# 2867  Última actualización\n    Anuncio actualizado el 23/10/2024
#
#                     referencia
# 2867  Ref.: SA1457-E-0050/5300

# %%
df_detalles2 = df_detalles2.rename(columns={'Campo1': 'precio', 'Campo2': 'num_hab', 'Campo3': 'num_banos', 'Campo4': 'metros_construidos', 'Campo5': 'planta', 'Campo6': 'precio_por_area', 'Título': 'title', 'Campo7': 'ubicacion', 'Campo8': 'detalle', 'Campo10': 'estado', 'Campo12': 'consumo', 'Campo14': 'actualizacion', 'Campo15': 'referencia'})
df_detalles2.tail(1)
# Out:
#          precio  num_hab num_banos metros_construidos     planta  \
# 2806  179.500 €  2 habs.    1 baño              69 m²  2ª planta
#
#      precio_por_area  \
# 2806      2.601 €/m²
#
#                                                                         title  \
# 2806  Piso en venta en Calle de Silvio Abad, cerca de Calle de Antonio Prieto
#
#                                    ubicacion  \
# 2806  Zofío (Distrito Usera. Madrid Capital)
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           detalle  \
# 2806  Linkcasa Embajadores Servicio Inmobiliario te ofrece en exclusiva esta acogedora vivienda en una ubicación céntrico, en la zona de Zofío, perteneciente al distrito de USERA muy cercano a la Plaza Elíptica.\n\nLa vivienda se localiza en la planta 2ª del edificio.  El estado de la vivienda está para ENTRAR A VIVIR. \n\nEl inmueble tiene la siguiente distribución:\n\n- Hall de entrada con pasillo distribuidor.\n\n- Salón Comedor muy luminoso (Actualmente se utiliza como habitación), con acceso a una terraza amplia con toldo.\n\n- Cocina INDEPENDIENTE, amueblada y equipada con espacio de almacenaje y cómoda para cocinar, con acceso a tendedero.\n\n- 2 Dormitorios espaciosos.\n\n- 1 baño completo.\n \n\nOtras características:\nLa vivienda se encuentra en una ubicación inigualable, a 600 m de Plaza Elíptica, varios colegios de primaria y secundaria, a 100 m se encuentra el Transbordador de la zona sur de Madrid con autobuses para muchos barrios de Madrid y extrarradios.\n\nEl Zofío es un barrio de Madrid (España) situado en distrito de Usera. Limita al norte con Marcelo Usera, al oeste con la A-42, al este con Rafaela Ybarra y al sur con la avenida de los Poblados. Zona dotada de todo tipo de servicios y comercios.\n\nSi deseas visitar esta propiedad, no dudes en ponerte en contacto con nosotros para organizar una visita personalizada. ¡Estaremos encantados de atenderte!
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          estado  \
# 2806  Superficie construida: \n\t\t\t\t\t\t\t\t\t\t69 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie útil: \n\t\t\t\t\t\t\t\t\t\t66 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t2\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPlanta: \n\t\t\t\t\t\t\t\t\t\t2ª\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tAntigüedad: \n\t\t\t\t\t\t\t\t\t\tMás de 50 años\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tGastos de comunidad: \n\t\t\t\t\t\t\t\t\t\tEntre 20 y 40 €\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\tSA1457-E-0050/5300
#
#                          consumo                      actualizacion  \
# 2806  Clasificación: No indicado  Anuncio actualizado el 24/10/2024
#
#                     referencia
# 2806  Ref.: SA1457-E-0050/5300

# %%
df_detalles1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2868 entries, 0 to 2867
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   precio           2867 non-null   object
#  1   espacios         2860 non-null   object
#  2   title            2617 non-null   object
#  3   distrito         2617 non-null   object
#  4   detalle          2867 non-null   object
#  5   caracteristicas  2867 non-null   object
#  6   consumo          2867 non-null   object
#  7   url              2867 non-null   object
#  8   actualizacion    2867 non-null   object
#  9   referencia       2866 non-null   object
# dtypes: object(10)
# memory usage: 224.2+ KB

# %%
df_detalles1.dropna(subset=['referencia'], inplace=True)
df_detalles1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2866 entries, 0 to 2867
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   precio           2866 non-null   object
#  1   espacios         2859 non-null   object
#  2   title            2616 non-null   object
#  3   distrito         2616 non-null   object
#  4   detalle          2866 non-null   object
#  5   caracteristicas  2866 non-null   object
#  6   consumo          2866 non-null   object
#  7   url              2866 non-null   object
#  8   actualizacion    2866 non-null   object
#  9   referencia       2866 non-null   object
# dtypes: object(10)
# memory usage: 246.3+ KB

# %%
df_detalles2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2807 entries, 0 to 2806
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Campo1   2806 non-null   object
#  1   Campo2   2799 non-null   object
#  2   Campo3   2799 non-null   object
#  3   Campo4   2790 non-null   object
#  4   Campo5   2710 non-null   object
#  5   Campo6   1767 non-null   object
#  6   Título   2563 non-null   object
#  7   Campo7   2563 non-null   object
#  8   Campo8   2806 non-null   object
#  9   Campo10  2806 non-null   object
#  10  Campo12  2806 non-null   object
#  11  Campo14  2806 non-null   object
#  12  Campo15  2805 non-null   object
# dtypes: object(13)
# memory usage: 285.2+ KB

# %%
df_detalles2.dropna(subset=['referencia'], inplace=True)
df_detalles2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2805 entries, 0 to 2806
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   precio              2805 non-null   object
#  1   num_hab             2798 non-null   object
#  2   num_banos           2798 non-null   object
#  3   metros_construidos  2789 non-null   object
#  4   planta              2709 non-null   object
#  5   precio_por_area     1767 non-null   object
#  6   title               2562 non-null   object
#  7   ubicacion           2562 non-null   object
#  8   detalle             2805 non-null   object
#  9   estado              2805 non-null   object
#  10  consumo             2805 non-null   object
#  11  actualizacion       2805 non-null   object
#  12  referencia          2805 non-null   object
# dtypes: object(13)
# memory usage: 306.8+ KB

# %%
df_detalles = pd.merge(df_detalles1, df_detalles2, on='referencia', how='outer')
df_detalles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3033 entries, 0 to 3032
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   precio_x            3032 non-null   object
#  1   espacios            3025 non-null   object
#  2   title_x             2777 non-null   object
#  3   distrito            2777 non-null   object
#  4   detalle_x           3032 non-null   object
#  5   caracteristicas     3032 non-null   object
#  6   consumo_x           3032 non-null   object
#  7   url                 3032 non-null   object
#  8   actualizacion_x     3032 non-null   object
#  9   referencia          3033 non-null   object
#  10  precio_y            2971 non-null   object
#  11  num_hab             2964 non-null   object
#  12  num_banos           2964 non-null   object
#  13  metros_construidos  2955 non-null   object
#  14  planta              2875 non-null   object
#  15  precio_por_area     1931 non-null   object
#  16  title_y             2723 non-null   object
#  17  ubicacion           2723 non-null   object
#  18  detalle_y           2971 non-null   object
#  19  estado              2971 non-null   object
#  20  consumo_y           2971 non-null   object
#  21  actualizacion_y     2971 non-null   object
# dtypes: object(22)
# memory usage: 521.4+ KB

# %%
df_detalles.columns
# Out:
# Index(['precio_x', 'espacios', 'title_x', 'distrito', 'detalle_x',
#        'caracteristicas', 'consumo_x', 'url', 'actualizacion_x', 'referencia',
#        'precio_y', 'num_hab', 'num_banos', 'metros_construidos', 'planta',
#        'precio_por_area', 'title_y', 'ubicacion', 'detalle_y', 'estado',
#        'consumo_y', 'actualizacion_y'],
#       dtype='object')

# %%
df_detalles = df_detalles[['precio_x', 'precio_y', 'espacios', 'title_x', 'title_y', 'distrito', 'detalle_x', 'detalle_y', 
                           'caracteristicas', 'consumo_x', 'consumo_y', 'url', 'actualizacion_x', 'actualizacion_y', 
                           'referencia', 'num_hab', 'num_banos', 'metros_construidos', 'planta', 'precio_por_area', 'ubicacion', 'estado']]
df_detalles.columns
# Out:
# Index(['precio_x', 'precio_y', 'espacios', 'title_x', 'title_y', 'distrito',
#        'detalle_x', 'detalle_y', 'caracteristicas', 'consumo_x', 'consumo_y',
#        'url', 'actualizacion_x', 'actualizacion_y', 'referencia', 'num_hab',
#        'num_banos', 'metros_construidos', 'planta', 'precio_por_area',
#        'ubicacion', 'estado'],
#       dtype='object')

# %%
df_detalles.sort_values(by='referencia', ascending=True).head(10)
# Out:
#       precio_x     precio_y  \
# 0  2.950.000 €  2.950.000 €
# 1  2.950.000 €  2.985.000 €
# 2  2.985.000 €  2.950.000 €
# 3  2.985.000 €  2.985.000 €
# 4    322.700 €    322.700 €
# 5    437.700 €    437.700 €
# 6    377.700 €          NaN
# 7    377.700 €    377.700 €
# 8  3.025.000 €  3.025.000 €
# 9  2.900.000 €  2.900.000 €
#
#                                                                                     espacios  \
# 0                 Obra nueva\n\n\t\t\t7 habs.\n\t\t\t8 baños\n\t\t\t561 m²\n\t\t\t5.258 €/m²
# 1                 Obra nueva\n\n\t\t\t7 habs.\n\t\t\t8 baños\n\t\t\t561 m²\n\t\t\t5.258 €/m²
# 2                 Obra nueva\n\n\t\t\t7 habs.\n\t\t\t8 baños\n\t\t\t565 m²\n\t\t\t5.283 €/m²
# 3                 Obra nueva\n\n\t\t\t7 habs.\n\t\t\t8 baños\n\t\t\t565 m²\n\t\t\t5.283 €/m²
# 4       Obra nueva\n\n\t\t\t1 hab.\n\t\t\t1 baño\n\t\t\t66 m²\n\t\t\tBajo \n\t\t\t4.889 €/m²
# 5  Obra nueva\n\n\t\t\t2 habs.\n\t\t\t1 baño\n\t\t\t62 m²\n\t\t\t3ª planta\n\t\t\t7.059 €/m²
# 6   Obra nueva\n\n\t\t\t1 hab.\n\t\t\t1 baño\n\t\t\t59 m²\n\t\t\t3ª planta\n\t\t\t6.401 €/m²
# 7   Obra nueva\n\n\t\t\t1 hab.\n\t\t\t1 baño\n\t\t\t60 m²\n\t\t\t3ª planta\n\t\t\t6.295 €/m²
# 8                 Obra nueva\n\n\t\t\t7 habs.\n\t\t\t8 baños\n\t\t\t577 m²\n\t\t\t5.242 €/m²
# 9                 Obra nueva\n\n\t\t\t7 habs.\n\t\t\t8 baños\n\t\t\t563 m²\n\t\t\t5.150 €/m²
#
#                                                         title_x  \
# 0                 Chalet en venta en Calle del Pico Milano, s/n
# 1                 Chalet en venta en Calle del Pico Milano, s/n
# 2                 Chalet en venta en Calle del Pico Milano, s/n
# 3                 Chalet en venta en Calle del Pico Milano, s/n
# 4               Piso en venta en Calle de la Virgen de Lluc, 49
# 5                                                           NaN
# 6  Ático en venta en Calle de Nuestra Señora de los Dolores, 18
# 7  Ático en venta en Calle de Nuestra Señora de los Dolores, 18
# 8                 Chalet en venta en Calle del Pico Milano, s/n
# 9                 Chalet en venta en Calle del Pico Milano, s/n
#
#                                            title_y  \
# 0    Chalet en venta en Calle del Pico Milano, s/n
# 1    Chalet en venta en Calle del Pico Milano, s/n
# 2    Chalet en venta en Calle del Pico Milano, s/n
# 3    Chalet en venta en Calle del Pico Milano, s/n
# 4  Piso en venta en Calle de la Virgen de Lluc, 49
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8    Chalet en venta en Calle del Pico Milano, s/n
# 9    Chalet en venta en Calle del Pico Milano, s/n
#
#                                                                       distrito  \
# 0  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
# 1  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
# 2  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
# 3  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
# 4                            Quintana (Distrito Ciudad Lineal. Madrid Capital)
# 5                                                                          NaN
# 6                              Valdeacederas (Distrito Tetuán. Madrid Capital)
# 7                              Valdeacederas (Distrito Tetuán. Madrid Capital)
# 8  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
# 9  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
#
#                                                                                                                                                                                                                                                                              detalle_x  \
# 0                                 Parcela 2, Tipo B. Chalet de obra nueva de 561  m2 de superficie construida y situado en la zona de Madrid Capital. Está estructurado en 7 habitaciones, 8 baños completos y terraza. El Chalet tiene piscina. Aporta como extras garaje y trastero.
# 1                                 Parcela 2, Tipo B. Chalet de obra nueva de 561  m2 de superficie construida y situado en la zona de Madrid Capital. Está estructurado en 7 habitaciones, 8 baños completos y terraza. El Chalet tiene piscina. Aporta como extras garaje y trastero.
# 2                              Parcela 4, Tipo A. Chalet de obra nueva de 565 m2 de superficie construida y emplazado en la zona de Madrid Capital. Está dispuesto en 7 habitaciones, 8 baños completos y terraza. El Chalet dispone de piscina. Cuenta como extras garaje y trastero.
# 3                              Parcela 4, Tipo A. Chalet de obra nueva de 565 m2 de superficie construida y emplazado en la zona de Madrid Capital. Está dispuesto en 7 habitaciones, 8 baños completos y terraza. El Chalet dispone de piscina. Cuenta como extras garaje y trastero.
# 4                 Bajo. Piso en un inmueble de obra nueva de 66 m2 de superficie construida y situado en la zona de Madrid Capital, acomodado en planta baja. Está estructurado en 1 habitación, 1 baño completo y jardín de 14.80 m2. Aporta como extras ascensor, garaje y trastero.
# 5  Ático A. Ático en una finca de obra nueva de 62 m2 de superficie construida y emplazado en la zona de Madrid Capital, posicionado en planta 3. Está dispuesto en 2 habitaciones, 1 baño completo y terrazas de 3.25+11.70+34.50 m2. Cuenta como extras ascensor, garaje y trastero.
# 6                                   Ático A. Ático en una finca de obra nueva de 59 m2 de superficie construida y emplazado en la zona de Madrid Capital, posicionado en planta 3. Está dispuesto en 1 habitación, 1 baño completo y terraza de 22.98 m2. Cuenta como extras ascensor.
# 7                                  Ático B. Ático en un edificio de obra nueva de 60 m2 de superficie construida y ubicado en la zona de Madrid Capital, enclavado en planta 3. Está distribuido en 1 habitación, 1 baño completo y terraza de 23.77 m2. Incluye extras como ascensor.
# 8                                    Parcela 15, Tipo C. Chalet de obra nueva 577 m2 de superficie construida y situado en la zona de Madrid Capital. Está estructurado en 7 habitaciones, 8 baños completos y terraza. El Chalet tiene piscina. Aporta como extras garaje y trastero.
# 9                                     Parcela 3, Tipo B. Chalet de obra nueva 563 m2 de superficie construida y situado en la zona de Madrid Capital. Está estructurado en 7 habitaciones, 8 baños completos y terraza. El Chalet tiene piscina. Aporta como extras garaje y trastero.
#
#                                                                                                                                                                                                                                                                              detalle_y  \
# 0                                 Parcela 2, Tipo B. Chalet de obra nueva de 561  m2 de superficie construida y situado en la zona de Madrid Capital. Está estructurado en 7 habitaciones, 8 baños completos y terraza. El Chalet tiene piscina. Aporta como extras garaje y trastero.
# 1                              Parcela 4, Tipo A. Chalet de obra nueva de 565 m2 de superficie construida y emplazado en la zona de Madrid Capital. Está dispuesto en 7 habitaciones, 8 baños completos y terraza. El Chalet dispone de piscina. Cuenta como extras garaje y trastero.
# 2                                 Parcela 2, Tipo B. Chalet de obra nueva de 561  m2 de superficie construida y situado en la zona de Madrid Capital. Está estructurado en 7 habitaciones, 8 baños completos y terraza. El Chalet tiene piscina. Aporta como extras garaje y trastero.
# 3                              Parcela 4, Tipo A. Chalet de obra nueva de 565 m2 de superficie construida y emplazado en la zona de Madrid Capital. Está dispuesto en 7 habitaciones, 8 baños completos y terraza. El Chalet dispone de piscina. Cuenta como extras garaje y trastero.
# 4                 Bajo. Piso en un inmueble de obra nueva de 66 m2 de superficie construida y situado en la zona de Madrid Capital, acomodado en planta baja. Está estructurado en 1 habitación, 1 baño completo y jardín de 14.80 m2. Aporta como extras ascensor, garaje y trastero.
# 5  Ático A. Ático en una finca de obra nueva de 62 m2 de superficie construida y emplazado en la zona de Madrid Capital, posicionado en planta 3. Está dispuesto en 2 habitaciones, 1 baño completo y terrazas de 3.25+11.70+34.50 m2. Cuenta como extras ascensor, garaje y trastero.
# 6                                                                                                                                                                                                                                                                                  NaN
# 7                                  Ático B. Ático en un edificio de obra nueva de 60 m2 de superficie construida y ubicado en la zona de Madrid Capital, enclavado en planta 3. Está distribuido en 1 habitación, 1 baño completo y terraza de 23.77 m2. Incluye extras como ascensor.
# 8                                    Parcela 15, Tipo C. Chalet de obra nueva 577 m2 de superficie construida y situado en la zona de Madrid Capital. Está estructurado en 7 habitaciones, 8 baños completos y terraza. El Chalet tiene piscina. Aporta como extras garaje y trastero.
# 9                                     Parcela 3, Tipo B. Chalet de obra nueva 563 m2 de superficie construida y situado en la zona de Madrid Capital. Está estructurado en 7 habitaciones, 8 baños completos y terraza. El Chalet tiene piscina. Aporta como extras garaje y trastero.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       caracteristicas  \
# 0                                                                                                                                                                                 Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t561 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-0\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tGaraje\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTrastero\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTerraza\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tJardín: \n\t\t\t\t\t\t\t\t\t\tPrivado\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPiscina\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
# 1                                                                                                                                                                                 Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t561 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-0\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tGaraje\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTrastero\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTerraza\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tJardín: \n\t\t\t\t\t\t\t\t\t\tPrivado\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPiscina\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
# 2                                                                                                                                                                                 Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t565 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-0\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tGaraje\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTrastero\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTerraza\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tJardín: \n\t\t\t\t\t\t\t\t\t\tPrivado\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPiscina\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
# 3                                                                                                                                                                                 Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t565 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-0\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tGaraje\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTrastero\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTerraza\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tJardín: \n\t\t\t\t\t\t\t\t\t\tPrivado\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPiscina\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
# 4  Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t66 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPlanta: \n\t\t\t\t\t\t\t\t\t\tBajo\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-20659923\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tGaraje\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTrastero\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tAscensor\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTerraza\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tJardín: \n\t\t\t\t\t\t\t\t\t\tPrivado\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
# 5                                                                                                                                                                               Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t62 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t2\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPlanta: \n\t\t\t\t\t\t\t\t\t\t3ª\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-20659961\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tGaraje\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTrastero\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tAscensor\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTerraza\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t59 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPlanta: \n\t\t\t\t\t\t\t\t\t\t3ª\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-20883233\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tAscensor\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTerraza\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t60 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPlanta: \n\t\t\t\t\t\t\t\t\t\t3ª\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-20883234\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tAscensor\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTerraza\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
# 8                                                                                                                                                                          Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t577 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-21398012\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tGaraje\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTrastero\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTerraza\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tJardín: \n\t\t\t\t\t\t\t\t\t\tPrivado\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPiscina\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
# 9                                                                                                                                                                          Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t563 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-21398015\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tGaraje\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTrastero\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTerraza\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tJardín: \n\t\t\t\t\t\t\t\t\t\tPrivado\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPiscina\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   consumo_x  \
# 0  Certificado energético\n\n        Clasificación: En trámite\n\n\n\n        Ver detalle \n\n        \n            \n                \n                \n                    \n                        \n                        \n                    \n                    \n                        \n                        \n                            \n                                \n                                    \n                                        Certificado energético\n                                    \n                                    \n                                        La certificación energética indica la eficiencia del inmueble en cuanto a consumo de energía, agua, etc.  La categoría A es la más eficiente y la G la menos.\n                                    \n                                    Etiqueta de certificación energética\n\n                                        Este anuncio no dispone de etiqueta de certificación energética ya que el anunciante comunica que está "en trámite".
# 1  Certificado energético\n\n        Clasificación: En trámite\n\n\n\n        Ver detalle \n\n        \n            \n                \n                \n                    \n                        \n                        \n                    \n                    \n                        \n                        \n                            \n                                \n                                    \n                                        Certificado energético\n                                    \n                                    \n                                        La certificación energética indica la eficiencia del inmueble en cuanto a consumo de energía, agua, etc.  La categoría A es la más eficiente y la G la menos.\n                                    \n                                    Etiqueta de certificación energética\n\n                                        Este anuncio no dispone de etiqueta de certificación energética ya que el anunciante comunica que está "en trámite".
# 2  Certificado energético\n\n        Clasificación: En trámite\n\n\n\n        Ver detalle \n\n        \n            \n                \n                \n                    \n                        \n                        \n                    \n                    \n                        \n                        \n                            \n                                \n                                    \n                                        Certificado energético\n                                    \n                                    \n                                        La certificación energética indica la eficiencia del inmueble en cuanto a consumo de energía, agua, etc.  La categoría A es la más eficiente y la G la menos.\n                                    \n                                    Etiqueta de certificación energética\n\n                                        Este anuncio no dispone de etiqueta de certificación energética ya que el anunciante comunica que está "en trámite".
# 3  Certificado energético\n\n        Clasificación: En trámite\n\n\n\n        Ver detalle \n\n        \n            \n                \n                \n                    \n                        \n                        \n                    \n                    \n                        \n                        \n                            \n                                \n                                    \n                                        Certificado energético\n                                    \n                                    \n                                        La certificación energética indica la eficiencia del inmueble en cuanto a consumo de energía, agua, etc.  La categoría A es la más eficiente y la G la menos.\n                                    \n                                    Etiqueta de certificación energética\n\n                                        Este anuncio no dispone de etiqueta de certificación energética ya que el anunciante comunica que está "en trámite".
# 4  Certificado energético\n\n        Clasificación: En trámite\n\n\n\n        Ver detalle \n\n        \n            \n                \n                \n                    \n                        \n                        \n                    \n                    \n                        \n                        \n                            \n                                \n                                    \n                                        Certificado energético\n                                    \n                                    \n                                        La certificación energética indica la eficiencia del inmueble en cuanto a consumo de energía, agua, etc.  La categoría A es la más eficiente y la G la menos.\n                                    \n                                    Etiqueta de certificación energética\n\n                                        Este anuncio no dispone de etiqueta de certificación energética ya que el anunciante comunica que está "en trámite".
# 5  Certificado energético\n\n        Clasificación: En trámite\n\n\n\n        Ver detalle \n\n        \n            \n                \n                \n                    \n                        \n                        \n                    \n                    \n                        \n                        \n                            \n                                \n                                    \n                                        Certificado energético\n                                    \n                                    \n                                        La certificación energética indica la eficiencia del inmueble en cuanto a consumo de energía, agua, etc.  La categoría A es la más eficiente y la G la menos.\n                                    \n                                    Etiqueta de certificación energética\n\n                                        Este anuncio no dispone de etiqueta de certificación energética ya que el anunciante comunica que está "en trámite".
# 6  Certificado energético\n\n        Clasificación: En trámite\n\n\n\n        Ver detalle \n\n        \n            \n                \n                \n                    \n                        \n                        \n                    \n                    \n                        \n                        \n                            \n                                \n                                    \n                                        Certificado energético\n                                    \n                                    \n                                        La certificación energética indica la eficiencia del inmueble en cuanto a consumo de energía, agua, etc.  La categoría A es la más eficiente y la G la menos.\n                                    \n                                    Etiqueta de certificación energética\n\n                                        Este anuncio no dispone de etiqueta de certificación energética ya que el anunciante comunica que está "en trámite".
# 7  Certificado energético\n\n        Clasificación: En trámite\n\n\n\n        Ver detalle \n\n        \n            \n                \n                \n                    \n                        \n                        \n                    \n                    \n                        \n                        \n                            \n                                \n                                    \n                                        Certificado energético\n                                    \n                                    \n                                        La certificación energética indica la eficiencia del inmueble en cuanto a consumo de energía, agua, etc.  La categoría A es la más eficiente y la G la menos.\n                                    \n                                    Etiqueta de certificación energética\n\n                                        Este anuncio no dispone de etiqueta de certificación energética ya que el anunciante comunica que está "en trámite".
# 8  Certificado energético\n\n        Clasificación: En trámite\n\n\n\n        Ver detalle \n\n        \n            \n                \n                \n                    \n                        \n                        \n                    \n                    \n                        \n                        \n                            \n                                \n                                    \n                                        Certificado energético\n                                    \n                                    \n                                        La certificación energética indica la eficiencia del inmueble en cuanto a consumo de energía, agua, etc.  La categoría A es la más eficiente y la G la menos.\n                                    \n                                    Etiqueta de certificación energética\n\n                                        Este anuncio no dispone de etiqueta de certificación energética ya que el anunciante comunica que está "en trámite".
# 9  Certificado energético\n\n        Clasificación: En trámite\n\n\n\n        Ver detalle \n\n        \n            \n                \n                \n                    \n                        \n                        \n                    \n                    \n                        \n                        \n                            \n                                \n                                    \n                                        Certificado energético\n                                    \n                                    \n                                        La certificación energética indica la eficiencia del inmueble en cuanto a consumo de energía, agua, etc.  La categoría A es la más eficiente y la G la menos.\n                                    \n                                    Etiqueta de certificación energética\n\n                                        Este anuncio no dispone de etiqueta de certificación energética ya que el anunciante comunica que está "en trámite".
#
#                    consumo_y  \
# 0  Clasificación: En trámite
# 1  Clasificación: En trámite
# 2  Clasificación: En trámite
# 3  Clasificación: En trámite
# 4  Clasificación: En trámite
# 5  Clasificación: En trámite
# 6                        NaN
# 7  Clasificación: En trámite
# 8  Clasificación: En trámite
# 9  Clasificación: En trámite
#
#                                                                                           url  \
# 0  https://www.pisos.com/comprar/chalet-mirasierra_arroyo_del_fresno28034-3860362029_109700/#
# 1  https://www.pisos.com/comprar/chalet-mirasierra_arroyo_del_fresno28034-3860362029_109700/#
# 2  https://www.pisos.com/comprar/chalet-mirasierra_arroyo_del_fresno28034-4869216252_109700/#
# 3  https://www.pisos.com/comprar/chalet-mirasierra_arroyo_del_fresno28034-4869216252_109700/#
# 4               https://www.pisos.com/comprar/piso-ciudad_lineal_quintana-4016497783_109700/#
# 5              https://www.pisos.com/comprar/atico-ciudad_lineal_quintana-4006055570_109700/#
# 6                  https://www.pisos.com/comprar/atico-valdeacederas28039-4269208361_109700/#
# 7                  https://www.pisos.com/comprar/atico-valdeacederas28039-4289932667_109700/#
# 8  https://www.pisos.com/comprar/chalet-mirasierra_arroyo_del_fresno28034-3814003407_109700/#
# 9  https://www.pisos.com/comprar/chalet-mirasierra_arroyo_del_fresno28034-4777777134_109700/#
#
#                                                actualizacion_x  \
# 0  Última actualización\n    Anuncio actualizado el 22/10/2024
# 1  Última actualización\n    Anuncio actualizado el 22/10/2024
# 2  Última actualización\n    Anuncio actualizado el 21/10/2024
# 3  Última actualización\n    Anuncio actualizado el 21/10/2024
# 4  Última actualización\n    Anuncio actualizado el 11/10/2024
# 5  Última actualización\n    Anuncio actualizado el 21/10/2024
# 6  Última actualización\n    Anuncio actualizado el 23/10/2024
# 7  Última actualización\n    Anuncio actualizado el 17/10/2024
# 8  Última actualización\n    Anuncio actualizado el 06/10/2024
# 9  Última actualización\n    Anuncio actualizado el 22/10/2024
#
#                      actualizacion_y       referencia     num_hab num_banos  \
# 0  Anuncio actualizado el 24/10/2024         Ref.: -0  Obra nueva   7 habs.
# 1  Anuncio actualizado el 21/10/2024         Ref.: -0  Obra nueva   7 habs.
# 2  Anuncio actualizado el 24/10/2024         Ref.: -0  Obra nueva   7 habs.
# 3  Anuncio actualizado el 21/10/2024         Ref.: -0  Obra nueva   7 habs.
# 4  Anuncio actualizado el 24/10/2024  Ref.: -20659923  Obra nueva    1 hab.
# 5  Anuncio actualizado el 21/10/2024  Ref.: -20659961  Obra nueva   2 habs.
# 6                                NaN  Ref.: -20883233         NaN       NaN
# 7  Anuncio actualizado el 24/10/2024  Ref.: -20883234  Obra nueva    1 hab.
# 8  Anuncio actualizado el 23/10/2024  Ref.: -21398012  Obra nueva   7 habs.
# 9  Anuncio actualizado el 22/10/2024  Ref.: -21398015  Obra nueva   7 habs.
#
#   metros_construidos  planta precio_por_area  \
# 0            8 baños  561 m²      5.258 €/m²
# 1            8 baños  565 m²      5.283 €/m²
# 2            8 baños  561 m²      5.258 €/m²
# 3            8 baños  565 m²      5.283 €/m²
# 4             1 baño   66 m²            Bajo
# 5             1 baño   62 m²       3ª planta
# 6                NaN     NaN             NaN
# 7             1 baño   60 m²       3ª planta
# 8            8 baños  577 m²      5.242 €/m²
# 9            8 baños  563 m²      5.150 €/m²
#
#                                                                      ubicacion  \
# 0  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
# 1  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
# 2  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
# 3  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
# 4                            Quintana (Distrito Ciudad Lineal. Madrid Capital)
# 5                                                                          NaN
# 6                                                                          NaN
# 7                                                                          NaN
# 8  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
# 9  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            estado
# 0                                                                                                                                                                                Superficie construida: \n\t\t\t\t\t\t\t\t\t\t561 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-0
# 1                                                                                                                                                                                Superficie construida: \n\t\t\t\t\t\t\t\t\t\t565 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-0
# 2                                                                                                                                                                                Superficie construida: \n\t\t\t\t\t\t\t\t\t\t561 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-0
# 3                                                                                                                                                                                Superficie construida: \n\t\t\t\t\t\t\t\t\t\t565 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-0
# 4  Superficie construida: \n\t\t\t\t\t\t\t\t\t\t66 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPlanta: \n\t\t\t\t\t\t\t\t\t\tBajo\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-20659923
# 5    Superficie construida: \n\t\t\t\t\t\t\t\t\t\t62 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t2\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPlanta: \n\t\t\t\t\t\t\t\t\t\t3ª\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-20659961
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 7    Superficie construida: \n\t\t\t\t\t\t\t\t\t\t60 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPlanta: \n\t\t\t\t\t\t\t\t\t\t3ª\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-20883234
# 8                                                                                                                                                                         Superficie construida: \n\t\t\t\t\t\t\t\t\t\t577 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-21398012
# 9                                                                                                                                                                         Superficie construida: \n\t\t\t\t\t\t\t\t\t\t563 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-21398015

# %%
df_detalles['ubicacion'] = df_detalles['ubicacion'].fillna('/')
df_detalles['distrito'] = df_detalles['distrito'].fillna('/')

# %%
df_detalles['ubicacion'] = df_detalles['ubicacion'] + ' / ' + df_detalles['distrito']
df_detalles.columns
# Out:
# Index(['precio_x', 'precio_y', 'espacios', 'title_x', 'title_y', 'distrito',
#        'detalle_x', 'detalle_y', 'caracteristicas', 'consumo_x', 'consumo_y',
#        'url', 'actualizacion_x', 'actualizacion_y', 'referencia', 'num_hab',
#        'num_banos', 'metros_construidos', 'planta', 'precio_por_area',
#        'ubicacion', 'estado'],
#       dtype='object')

# %%
df_detalles.head(10)
# Out:
#       precio_x     precio_y  \
# 0  2.950.000 €  2.950.000 €
# 1  2.950.000 €  2.985.000 €
# 2  2.985.000 €  2.950.000 €
# 3  2.985.000 €  2.985.000 €
# 4    322.700 €    322.700 €
# 5    437.700 €    437.700 €
# 6    377.700 €          NaN
# 7    377.700 €    377.700 €
# 8  3.025.000 €  3.025.000 €
# 9  2.900.000 €  2.900.000 €
#
#                                                                                     espacios  \
# 0                 Obra nueva\n\n\t\t\t7 habs.\n\t\t\t8 baños\n\t\t\t561 m²\n\t\t\t5.258 €/m²
# 1                 Obra nueva\n\n\t\t\t7 habs.\n\t\t\t8 baños\n\t\t\t561 m²\n\t\t\t5.258 €/m²
# 2                 Obra nueva\n\n\t\t\t7 habs.\n\t\t\t8 baños\n\t\t\t565 m²\n\t\t\t5.283 €/m²
# 3                 Obra nueva\n\n\t\t\t7 habs.\n\t\t\t8 baños\n\t\t\t565 m²\n\t\t\t5.283 €/m²
# 4       Obra nueva\n\n\t\t\t1 hab.\n\t\t\t1 baño\n\t\t\t66 m²\n\t\t\tBajo \n\t\t\t4.889 €/m²
# 5  Obra nueva\n\n\t\t\t2 habs.\n\t\t\t1 baño\n\t\t\t62 m²\n\t\t\t3ª planta\n\t\t\t7.059 €/m²
# 6   Obra nueva\n\n\t\t\t1 hab.\n\t\t\t1 baño\n\t\t\t59 m²\n\t\t\t3ª planta\n\t\t\t6.401 €/m²
# 7   Obra nueva\n\n\t\t\t1 hab.\n\t\t\t1 baño\n\t\t\t60 m²\n\t\t\t3ª planta\n\t\t\t6.295 €/m²
# 8                 Obra nueva\n\n\t\t\t7 habs.\n\t\t\t8 baños\n\t\t\t577 m²\n\t\t\t5.242 €/m²
# 9                 Obra nueva\n\n\t\t\t7 habs.\n\t\t\t8 baños\n\t\t\t563 m²\n\t\t\t5.150 €/m²
#
#                                                         title_x  \
# 0                 Chalet en venta en Calle del Pico Milano, s/n
# 1                 Chalet en venta en Calle del Pico Milano, s/n
# 2                 Chalet en venta en Calle del Pico Milano, s/n
# 3                 Chalet en venta en Calle del Pico Milano, s/n
# 4               Piso en venta en Calle de la Virgen de Lluc, 49
# 5                                                           NaN
# 6  Ático en venta en Calle de Nuestra Señora de los Dolores, 18
# 7  Ático en venta en Calle de Nuestra Señora de los Dolores, 18
# 8                 Chalet en venta en Calle del Pico Milano, s/n
# 9                 Chalet en venta en Calle del Pico Milano, s/n
#
#                                            title_y  \
# 0    Chalet en venta en Calle del Pico Milano, s/n
# 1    Chalet en venta en Calle del Pico Milano, s/n
# 2    Chalet en venta en Calle del Pico Milano, s/n
# 3    Chalet en venta en Calle del Pico Milano, s/n
# 4  Piso en venta en Calle de la Virgen de Lluc, 49
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8    Chalet en venta en Calle del Pico Milano, s/n
# 9    Chalet en venta en Calle del Pico Milano, s/n
#
#                                                                       distrito  \
# 0  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
# 1  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
# 2  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
# 3  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
# 4                            Quintana (Distrito Ciudad Lineal. Madrid Capital)
# 5                                                                            /
# 6                              Valdeacederas (Distrito Tetuán. Madrid Capital)
# 7                              Valdeacederas (Distrito Tetuán. Madrid Capital)
# 8  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
# 9  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
#
#                                                                                                                                                                                                                                                                              detalle_x  \
# 0                                 Parcela 2, Tipo B. Chalet de obra nueva de 561  m2 de superficie construida y situado en la zona de Madrid Capital. Está estructurado en 7 habitaciones, 8 baños completos y terraza. El Chalet tiene piscina. Aporta como extras garaje y trastero.
# 1                                 Parcela 2, Tipo B. Chalet de obra nueva de 561  m2 de superficie construida y situado en la zona de Madrid Capital. Está estructurado en 7 habitaciones, 8 baños completos y terraza. El Chalet tiene piscina. Aporta como extras garaje y trastero.
# 2                              Parcela 4, Tipo A. Chalet de obra nueva de 565 m2 de superficie construida y emplazado en la zona de Madrid Capital. Está dispuesto en 7 habitaciones, 8 baños completos y terraza. El Chalet dispone de piscina. Cuenta como extras garaje y trastero.
# 3                              Parcela 4, Tipo A. Chalet de obra nueva de 565 m2 de superficie construida y emplazado en la zona de Madrid Capital. Está dispuesto en 7 habitaciones, 8 baños completos y terraza. El Chalet dispone de piscina. Cuenta como extras garaje y trastero.
# 4                 Bajo. Piso en un inmueble de obra nueva de 66 m2 de superficie construida y situado en la zona de Madrid Capital, acomodado en planta baja. Está estructurado en 1 habitación, 1 baño completo y jardín de 14.80 m2. Aporta como extras ascensor, garaje y trastero.
# 5  Ático A. Ático en una finca de obra nueva de 62 m2 de superficie construida y emplazado en la zona de Madrid Capital, posicionado en planta 3. Está dispuesto en 2 habitaciones, 1 baño completo y terrazas de 3.25+11.70+34.50 m2. Cuenta como extras ascensor, garaje y trastero.
# 6                                   Ático A. Ático en una finca de obra nueva de 59 m2 de superficie construida y emplazado en la zona de Madrid Capital, posicionado en planta 3. Está dispuesto en 1 habitación, 1 baño completo y terraza de 22.98 m2. Cuenta como extras ascensor.
# 7                                  Ático B. Ático en un edificio de obra nueva de 60 m2 de superficie construida y ubicado en la zona de Madrid Capital, enclavado en planta 3. Está distribuido en 1 habitación, 1 baño completo y terraza de 23.77 m2. Incluye extras como ascensor.
# 8                                    Parcela 15, Tipo C. Chalet de obra nueva 577 m2 de superficie construida y situado en la zona de Madrid Capital. Está estructurado en 7 habitaciones, 8 baños completos y terraza. El Chalet tiene piscina. Aporta como extras garaje y trastero.
# 9                                     Parcela 3, Tipo B. Chalet de obra nueva 563 m2 de superficie construida y situado en la zona de Madrid Capital. Está estructurado en 7 habitaciones, 8 baños completos y terraza. El Chalet tiene piscina. Aporta como extras garaje y trastero.
#
#                                                                                                                                                                                                                                                                              detalle_y  \
# 0                                 Parcela 2, Tipo B. Chalet de obra nueva de 561  m2 de superficie construida y situado en la zona de Madrid Capital. Está estructurado en 7 habitaciones, 8 baños completos y terraza. El Chalet tiene piscina. Aporta como extras garaje y trastero.
# 1                              Parcela 4, Tipo A. Chalet de obra nueva de 565 m2 de superficie construida y emplazado en la zona de Madrid Capital. Está dispuesto en 7 habitaciones, 8 baños completos y terraza. El Chalet dispone de piscina. Cuenta como extras garaje y trastero.
# 2                                 Parcela 2, Tipo B. Chalet de obra nueva de 561  m2 de superficie construida y situado en la zona de Madrid Capital. Está estructurado en 7 habitaciones, 8 baños completos y terraza. El Chalet tiene piscina. Aporta como extras garaje y trastero.
# 3                              Parcela 4, Tipo A. Chalet de obra nueva de 565 m2 de superficie construida y emplazado en la zona de Madrid Capital. Está dispuesto en 7 habitaciones, 8 baños completos y terraza. El Chalet dispone de piscina. Cuenta como extras garaje y trastero.
# 4                 Bajo. Piso en un inmueble de obra nueva de 66 m2 de superficie construida y situado en la zona de Madrid Capital, acomodado en planta baja. Está estructurado en 1 habitación, 1 baño completo y jardín de 14.80 m2. Aporta como extras ascensor, garaje y trastero.
# 5  Ático A. Ático en una finca de obra nueva de 62 m2 de superficie construida y emplazado en la zona de Madrid Capital, posicionado en planta 3. Está dispuesto en 2 habitaciones, 1 baño completo y terrazas de 3.25+11.70+34.50 m2. Cuenta como extras ascensor, garaje y trastero.
# 6                                                                                                                                                                                                                                                                                  NaN
# 7                                  Ático B. Ático en un edificio de obra nueva de 60 m2 de superficie construida y ubicado en la zona de Madrid Capital, enclavado en planta 3. Está distribuido en 1 habitación, 1 baño completo y terraza de 23.77 m2. Incluye extras como ascensor.
# 8                                    Parcela 15, Tipo C. Chalet de obra nueva 577 m2 de superficie construida y situado en la zona de Madrid Capital. Está estructurado en 7 habitaciones, 8 baños completos y terraza. El Chalet tiene piscina. Aporta como extras garaje y trastero.
# 9                                     Parcela 3, Tipo B. Chalet de obra nueva 563 m2 de superficie construida y situado en la zona de Madrid Capital. Está estructurado en 7 habitaciones, 8 baños completos y terraza. El Chalet tiene piscina. Aporta como extras garaje y trastero.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       caracteristicas  \
# 0                                                                                                                                                                                 Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t561 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-0\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tGaraje\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTrastero\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTerraza\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tJardín: \n\t\t\t\t\t\t\t\t\t\tPrivado\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPiscina\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
# 1                                                                                                                                                                                 Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t561 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-0\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tGaraje\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTrastero\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTerraza\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tJardín: \n\t\t\t\t\t\t\t\t\t\tPrivado\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPiscina\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
# 2                                                                                                                                                                                 Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t565 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-0\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tGaraje\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTrastero\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTerraza\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tJardín: \n\t\t\t\t\t\t\t\t\t\tPrivado\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPiscina\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
# 3                                                                                                                                                                                 Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t565 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-0\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tGaraje\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTrastero\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTerraza\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tJardín: \n\t\t\t\t\t\t\t\t\t\tPrivado\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPiscina\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
# 4  Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t66 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPlanta: \n\t\t\t\t\t\t\t\t\t\tBajo\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-20659923\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tGaraje\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTrastero\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tAscensor\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTerraza\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tJardín: \n\t\t\t\t\t\t\t\t\t\tPrivado\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
# 5                                                                                                                                                                               Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t62 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t2\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPlanta: \n\t\t\t\t\t\t\t\t\t\t3ª\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-20659961\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tGaraje\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTrastero\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tAscensor\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTerraza\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t59 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPlanta: \n\t\t\t\t\t\t\t\t\t\t3ª\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-20883233\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tAscensor\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTerraza\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t60 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPlanta: \n\t\t\t\t\t\t\t\t\t\t3ª\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-20883234\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tAscensor\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTerraza\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
# 8                                                                                                                                                                          Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t577 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-21398012\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tGaraje\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTrastero\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTerraza\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tJardín: \n\t\t\t\t\t\t\t\t\t\tPrivado\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPiscina\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
# 9                                                                                                                                                                          Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t563 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-21398015\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tGaraje\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTrastero\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTerraza\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tJardín: \n\t\t\t\t\t\t\t\t\t\tPrivado\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPiscina\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   consumo_x  \
# 0  Certificado energético\n\n        Clasificación: En trámite\n\n\n\n        Ver detalle \n\n        \n            \n                \n                \n                    \n                        \n                        \n                    \n                    \n                        \n                        \n                            \n                                \n                                    \n                                        Certificado energético\n                                    \n                                    \n                                        La certificación energética indica la eficiencia del inmueble en cuanto a consumo de energía, agua, etc.  La categoría A es la más eficiente y la G la menos.\n                                    \n                                    Etiqueta de certificación energética\n\n                                        Este anuncio no dispone de etiqueta de certificación energética ya que el anunciante comunica que está "en trámite".
# 1  Certificado energético\n\n        Clasificación: En trámite\n\n\n\n        Ver detalle \n\n        \n            \n                \n                \n                    \n                        \n                        \n                    \n                    \n                        \n                        \n                            \n                                \n                                    \n                                        Certificado energético\n                                    \n                                    \n                                        La certificación energética indica la eficiencia del inmueble en cuanto a consumo de energía, agua, etc.  La categoría A es la más eficiente y la G la menos.\n                                    \n                                    Etiqueta de certificación energética\n\n                                        Este anuncio no dispone de etiqueta de certificación energética ya que el anunciante comunica que está "en trámite".
# 2  Certificado energético\n\n        Clasificación: En trámite\n\n\n\n        Ver detalle \n\n        \n            \n                \n                \n                    \n                        \n                        \n                    \n                    \n                        \n                        \n                            \n                                \n                                    \n                                        Certificado energético\n                                    \n                                    \n                                        La certificación energética indica la eficiencia del inmueble en cuanto a consumo de energía, agua, etc.  La categoría A es la más eficiente y la G la menos.\n                                    \n                                    Etiqueta de certificación energética\n\n                                        Este anuncio no dispone de etiqueta de certificación energética ya que el anunciante comunica que está "en trámite".
# 3  Certificado energético\n\n        Clasificación: En trámite\n\n\n\n        Ver detalle \n\n        \n            \n                \n                \n                    \n                        \n                        \n                    \n                    \n                        \n                        \n                            \n                                \n                                    \n                                        Certificado energético\n                                    \n                                    \n                                        La certificación energética indica la eficiencia del inmueble en cuanto a consumo de energía, agua, etc.  La categoría A es la más eficiente y la G la menos.\n                                    \n                                    Etiqueta de certificación energética\n\n                                        Este anuncio no dispone de etiqueta de certificación energética ya que el anunciante comunica que está "en trámite".
# 4  Certificado energético\n\n        Clasificación: En trámite\n\n\n\n        Ver detalle \n\n        \n            \n                \n                \n                    \n                        \n                        \n                    \n                    \n                        \n                        \n                            \n                                \n                                    \n                                        Certificado energético\n                                    \n                                    \n                                        La certificación energética indica la eficiencia del inmueble en cuanto a consumo de energía, agua, etc.  La categoría A es la más eficiente y la G la menos.\n                                    \n                                    Etiqueta de certificación energética\n\n                                        Este anuncio no dispone de etiqueta de certificación energética ya que el anunciante comunica que está "en trámite".
# 5  Certificado energético\n\n        Clasificación: En trámite\n\n\n\n        Ver detalle \n\n        \n            \n                \n                \n                    \n                        \n                        \n                    \n                    \n                        \n                        \n                            \n                                \n                                    \n                                        Certificado energético\n                                    \n                                    \n                                        La certificación energética indica la eficiencia del inmueble en cuanto a consumo de energía, agua, etc.  La categoría A es la más eficiente y la G la menos.\n                                    \n                                    Etiqueta de certificación energética\n\n                                        Este anuncio no dispone de etiqueta de certificación energética ya que el anunciante comunica que está "en trámite".
# 6  Certificado energético\n\n        Clasificación: En trámite\n\n\n\n        Ver detalle \n\n        \n            \n                \n                \n                    \n                        \n                        \n                    \n                    \n                        \n                        \n                            \n                                \n                                    \n                                        Certificado energético\n                                    \n                                    \n                                        La certificación energética indica la eficiencia del inmueble en cuanto a consumo de energía, agua, etc.  La categoría A es la más eficiente y la G la menos.\n                                    \n                                    Etiqueta de certificación energética\n\n                                        Este anuncio no dispone de etiqueta de certificación energética ya que el anunciante comunica que está "en trámite".
# 7  Certificado energético\n\n        Clasificación: En trámite\n\n\n\n        Ver detalle \n\n        \n            \n                \n                \n                    \n                        \n                        \n                    \n                    \n                        \n                        \n                            \n                                \n                                    \n                                        Certificado energético\n                                    \n                                    \n                                        La certificación energética indica la eficiencia del inmueble en cuanto a consumo de energía, agua, etc.  La categoría A es la más eficiente y la G la menos.\n                                    \n                                    Etiqueta de certificación energética\n\n                                        Este anuncio no dispone de etiqueta de certificación energética ya que el anunciante comunica que está "en trámite".
# 8  Certificado energético\n\n        Clasificación: En trámite\n\n\n\n        Ver detalle \n\n        \n            \n                \n                \n                    \n                        \n                        \n                    \n                    \n                        \n                        \n                            \n                                \n                                    \n                                        Certificado energético\n                                    \n                                    \n                                        La certificación energética indica la eficiencia del inmueble en cuanto a consumo de energía, agua, etc.  La categoría A es la más eficiente y la G la menos.\n                                    \n                                    Etiqueta de certificación energética\n\n                                        Este anuncio no dispone de etiqueta de certificación energética ya que el anunciante comunica que está "en trámite".
# 9  Certificado energético\n\n        Clasificación: En trámite\n\n\n\n        Ver detalle \n\n        \n            \n                \n                \n                    \n                        \n                        \n                    \n                    \n                        \n                        \n                            \n                                \n                                    \n                                        Certificado energético\n                                    \n                                    \n                                        La certificación energética indica la eficiencia del inmueble en cuanto a consumo de energía, agua, etc.  La categoría A es la más eficiente y la G la menos.\n                                    \n                                    Etiqueta de certificación energética\n\n                                        Este anuncio no dispone de etiqueta de certificación energética ya que el anunciante comunica que está "en trámite".
#
#                    consumo_y  \
# 0  Clasificación: En trámite
# 1  Clasificación: En trámite
# 2  Clasificación: En trámite
# 3  Clasificación: En trámite
# 4  Clasificación: En trámite
# 5  Clasificación: En trámite
# 6                        NaN
# 7  Clasificación: En trámite
# 8  Clasificación: En trámite
# 9  Clasificación: En trámite
#
#                                                                                           url  \
# 0  https://www.pisos.com/comprar/chalet-mirasierra_arroyo_del_fresno28034-3860362029_109700/#
# 1  https://www.pisos.com/comprar/chalet-mirasierra_arroyo_del_fresno28034-3860362029_109700/#
# 2  https://www.pisos.com/comprar/chalet-mirasierra_arroyo_del_fresno28034-4869216252_109700/#
# 3  https://www.pisos.com/comprar/chalet-mirasierra_arroyo_del_fresno28034-4869216252_109700/#
# 4               https://www.pisos.com/comprar/piso-ciudad_lineal_quintana-4016497783_109700/#
# 5              https://www.pisos.com/comprar/atico-ciudad_lineal_quintana-4006055570_109700/#
# 6                  https://www.pisos.com/comprar/atico-valdeacederas28039-4269208361_109700/#
# 7                  https://www.pisos.com/comprar/atico-valdeacederas28039-4289932667_109700/#
# 8  https://www.pisos.com/comprar/chalet-mirasierra_arroyo_del_fresno28034-3814003407_109700/#
# 9  https://www.pisos.com/comprar/chalet-mirasierra_arroyo_del_fresno28034-4777777134_109700/#
#
#                                                actualizacion_x  \
# 0  Última actualización\n    Anuncio actualizado el 22/10/2024
# 1  Última actualización\n    Anuncio actualizado el 22/10/2024
# 2  Última actualización\n    Anuncio actualizado el 21/10/2024
# 3  Última actualización\n    Anuncio actualizado el 21/10/2024
# 4  Última actualización\n    Anuncio actualizado el 11/10/2024
# 5  Última actualización\n    Anuncio actualizado el 21/10/2024
# 6  Última actualización\n    Anuncio actualizado el 23/10/2024
# 7  Última actualización\n    Anuncio actualizado el 17/10/2024
# 8  Última actualización\n    Anuncio actualizado el 06/10/2024
# 9  Última actualización\n    Anuncio actualizado el 22/10/2024
#
#                      actualizacion_y       referencia     num_hab num_banos  \
# 0  Anuncio actualizado el 24/10/2024         Ref.: -0  Obra nueva   7 habs.
# 1  Anuncio actualizado el 21/10/2024         Ref.: -0  Obra nueva   7 habs.
# 2  Anuncio actualizado el 24/10/2024         Ref.: -0  Obra nueva   7 habs.
# 3  Anuncio actualizado el 21/10/2024         Ref.: -0  Obra nueva   7 habs.
# 4  Anuncio actualizado el 24/10/2024  Ref.: -20659923  Obra nueva    1 hab.
# 5  Anuncio actualizado el 21/10/2024  Ref.: -20659961  Obra nueva   2 habs.
# 6                                NaN  Ref.: -20883233         NaN       NaN
# 7  Anuncio actualizado el 24/10/2024  Ref.: -20883234  Obra nueva    1 hab.
# 8  Anuncio actualizado el 23/10/2024  Ref.: -21398012  Obra nueva   7 habs.
# 9  Anuncio actualizado el 22/10/2024  Ref.: -21398015  Obra nueva   7 habs.
#
#   metros_construidos  planta precio_por_area  \
# 0            8 baños  561 m²      5.258 €/m²
# 1            8 baños  565 m²      5.283 €/m²
# 2            8 baños  561 m²      5.258 €/m²
# 3            8 baños  565 m²      5.283 €/m²
# 4             1 baño   66 m²            Bajo
# 5             1 baño   62 m²       3ª planta
# 6                NaN     NaN             NaN
# 7             1 baño   60 m²       3ª planta
# 8            8 baños  577 m²      5.242 €/m²
# 9            8 baños  563 m²      5.150 €/m²
#
#                                                                                                                                                    ubicacion  \
# 0  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital) / Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
# 1  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital) / Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
# 2  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital) / Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
# 3  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital) / Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
# 4                                                      Quintana (Distrito Ciudad Lineal. Madrid Capital) / Quintana (Distrito Ciudad Lineal. Madrid Capital)
# 5                                                                                                                                                      / / /
# 6                                                                                                        / / Valdeacederas (Distrito Tetuán. Madrid Capital)
# 7                                                                                                        / / Valdeacederas (Distrito Tetuán. Madrid Capital)
# 8  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital) / Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
# 9  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital) / Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            estado
# 0                                                                                                                                                                                Superficie construida: \n\t\t\t\t\t\t\t\t\t\t561 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-0
# 1                                                                                                                                                                                Superficie construida: \n\t\t\t\t\t\t\t\t\t\t565 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-0
# 2                                                                                                                                                                                Superficie construida: \n\t\t\t\t\t\t\t\t\t\t561 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-0
# 3                                                                                                                                                                                Superficie construida: \n\t\t\t\t\t\t\t\t\t\t565 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-0
# 4  Superficie construida: \n\t\t\t\t\t\t\t\t\t\t66 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPlanta: \n\t\t\t\t\t\t\t\t\t\tBajo\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-20659923
# 5    Superficie construida: \n\t\t\t\t\t\t\t\t\t\t62 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t2\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPlanta: \n\t\t\t\t\t\t\t\t\t\t3ª\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-20659961
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 7    Superficie construida: \n\t\t\t\t\t\t\t\t\t\t60 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPlanta: \n\t\t\t\t\t\t\t\t\t\t3ª\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-20883234
# 8                                                                                                                                                                         Superficie construida: \n\t\t\t\t\t\t\t\t\t\t577 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-21398012
# 9                                                                                                                                                                         Superficie construida: \n\t\t\t\t\t\t\t\t\t\t563 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-21398015

# %%
df_detalles = df_detalles.drop(columns=['precio_y', 'title_y', 'detalle_y', 'consumo_x', 'actualizacion_x', 'distrito'], axis=1)
df_detalles = df_detalles.rename(columns={'precio_x': 'precio', 'title_x': 'title', 'detalle_x': 'detalle', 'consumo_y': 'consumo', 'actualizacion_y': 'actualizacion'})  
df_detalles.tail(1)
# Out:
#            precio  \
# 3032  2.200.000 €
#
#                                                                       espacios  \
# 3032  2 habs.\n\t\t\t2 baños\n\t\t\t150 m²\n\t\t\t3ª planta\n\t\t\t14.666 €/m²
#
#                         title  \
# 3032  Piso en venta en Madrid
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 detalle  \
# 3032  Barrio de Salamanca. Inmuebles de lujo y máxima calidad. Recién Reformados en su totalidad. Inmuebles de alto standing y exclusivos. Para mayor información póngase en contacto con el responsable para ofrecerle el que más se adecúe a sus necesidades y presupuesto.\n\nEl distrito de Salamanca, también citado frecuentemente como barrio de Salamanca, es uno de los 21 distritos que forman el municipio de Madrid (España). Debe su nombre a su constructor, el malagueño José de Salamanca y Mayol, marqués de Salamanca, que lo promovió y erigió en parte en el siglo xix. Se ha convertido en una de las más importantes zonas comerciales de la ciudad y uno de los distritos de mayor nivel de vida de España con la mayor zona de compras de lujo de Madrid en torno a la Milla de Oro, que incluye las calles Serrano, Claudio Coello, Lagasca y Ortega y Gasset.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             caracteristicas  \
# 3032  Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t150 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t2\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t2\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPlanta: \n\t\t\t\t\t\t\t\t\t\t3ª\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tExterior\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tEn buen estado\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\tsa5578-M211\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Muebles y acabados\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tAmueblado\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tArmarios empotrados: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tAire acondicionado: \n\t\t\t\t\t\t\t\t\t\tFrío\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tCalefacción: \n\t\t\t\t\t\t\t\t\t\tCentral\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tCocina equipada: \n\t\t\t\t\t\t\t\t\t\tCocina amueblada\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tAscensor\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBalcón\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
#
#                         consumo  \
# 3032  Clasificación: En trámite
#
#                                                                          url  \
# 3032  https://www.pisos.com/comprar/piso-recoletos28001-48433256858_100500/#
#
#                           actualizacion         referencia  num_hab num_banos  \
# 3032  Anuncio actualizado el 23/10/2024  Ref.: sa5578-M211  2 habs.   2 baños
#
#      metros_construidos     planta precio_por_area  \
# 3032             150 m²  3ª planta     14.666 €/m²
#
#                                                                                             ubicacion  \
# 3032  Recoletos (Distrito Salamanca. Madrid Capital) / Recoletos (Distrito Salamanca. Madrid Capital)
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  estado
# 3032  Superficie construida: \n\t\t\t\t\t\t\t\t\t\t150 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t2\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t2\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPlanta: \n\t\t\t\t\t\t\t\t\t\t3ª\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tExterior\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tEn buen estado\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\tsa5578-M211

# %%
df_detalles['fecha_descarga'] = pd.to_datetime('2024-10-19')
df_detalles['web'] = 'pisos.com'
df_detalles.columns
# Out:
# Index(['precio', 'espacios', 'title', 'detalle', 'caracteristicas', 'consumo',
#        'url', 'actualizacion', 'referencia', 'num_hab', 'num_banos',
#        'metros_construidos', 'planta', 'precio_por_area', 'ubicacion',
#        'estado', 'fecha_descarga', 'web'],
#       dtype='object')

# %%
df_detalles = df_detalles[['title', 'ubicacion', 'precio', 'num_hab', 'num_banos', 'metros_construidos', 
                           'planta', 'precio_por_area', 'estado', 'url', 'fecha_descarga', 'web', 'espacios', 'detalle',
                           'caracteristicas', 'consumo',  'actualizacion', 'referencia']]
df_detalles.columns
# Out:
# Index(['title', 'ubicacion', 'precio', 'num_hab', 'num_banos',
#        'metros_construidos', 'planta', 'precio_por_area', 'estado', 'url',
#        'fecha_descarga', 'web', 'espacios', 'detalle', 'caracteristicas',
#        'consumo', 'actualizacion', 'referencia'],
#       dtype='object')

# %%
df_detalles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3033 entries, 0 to 3032
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               2777 non-null   object
#  1   ubicacion           3033 non-null   object
#  2   precio              3032 non-null   object
#  3   num_hab             2964 non-null   object
#  4   num_banos           2964 non-null   object
#  5   metros_construidos  2955 non-null   object
#  6   planta              2875 non-null   object
#  7   precio_por_area     1931 non-null   object
#  8   estado              2971 non-null   object
#  9   url                 3032 non-null   object
#  10  fecha_descarga      3033 non-null   datetime64[ns]
#  11  web                 3033 non-null   object
#  12  espacios            3025 non-null   object
#  13  detalle             3032 non-null   object
#  14  caracteristicas     3032 non-null   object
#  15  consumo             2971 non-null   object
#  16  actualizacion       2971 non-null   object
#  17  referencia          3033 non-null   object
# dtypes: datetime64[ns](1), object(17)
# memory usage: 426.6+ KB

# %%
df_detalles = df_detalles.reset_index(drop=True)

# %% [markdown]
# ### TRANSFORMAR DATOS

# %%
precio_decimales = df_detalles[df_detalles['precio'].str.contains(',', na=False)]
precio_decimales
# Se ha comprobado que ningún 'precio' contiene decimales.
# Out:
# Empty DataFrame
# Columns: [title, ubicacion, precio, num_hab, num_banos, metros_construidos, planta, precio_por_area, estado, url, fecha_descarga, web, espacios, detalle, caracteristicas, consumo, actualizacion, referencia]
# Index: []

# %%
area_decimales = df_detalles[df_detalles['precio_por_area'].str.contains(',', na=False)]
area_decimales
# Se ha comprobado que ningún 'precio_por_area' contiene decimales.
# Out:
# Empty DataFrame
# Columns: [title, ubicacion, precio, num_hab, num_banos, metros_construidos, planta, precio_por_area, estado, url, fecha_descarga, web, espacios, detalle, caracteristicas, consumo, actualizacion, referencia]
# Index: []

# %%
metros_decimales = df_detalles[df_detalles['metros_construidos'].str.contains(',', na=False)]
metros_decimales
# Se ha comprobado que ningún 'metros_construidos' contiene decimales.
# Out:
# Empty DataFrame
# Columns: [title, ubicacion, precio, num_hab, num_banos, metros_construidos, planta, precio_por_area, estado, url, fecha_descarga, web, espacios, detalle, caracteristicas, consumo, actualizacion, referencia]
# Index: []

# %%
df_detalles['precio'] = df_detalles['precio'].str.replace(r'\D', '', regex=True)
df_detalles['metros_construidos'] = df_detalles['metros_construidos'].str.replace(r'\D', '', regex=True)
df_detalles['precio_por_area'] = df_detalles['precio_por_area'].str.replace(r'\D', '', regex=True)
df_detalles['num_hab'] = df_detalles['num_hab'].str.replace(r'\D', '', regex=True)
df_detalles['num_banos'] = df_detalles['num_banos'].str.replace(r'\D', '', regex=True)
df_detalles['planta'] = df_detalles['planta'].str.replace(r'\D', '', regex=True)
df_detalles['actualizacion'] = df_detalles['actualizacion'].astype('string')
df_detalles.head(1)
# Out:
#                                            title  \
# 0  Chalet en venta en Calle del Pico Milano, s/n
#
#                                                                                                                                                    ubicacion  \
# 0  Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital) / Mirasierra-Arroyo del Fresno (Distrito Fuencarral-El Pardo. Madrid Capital)
#
#     precio num_hab num_banos metros_construidos planta precio_por_area  \
# 0  2950000                 7                  8    561            5258
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              estado  \
# 0  Superficie construida: \n\t\t\t\t\t\t\t\t\t\t561 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-0
#
#                                                                                           url  \
# 0  https://www.pisos.com/comprar/chalet-mirasierra_arroyo_del_fresno28034-3860362029_109700/#
#
#   fecha_descarga        web  \
# 0     2024-10-19  pisos.com
#
#                                                                      espacios  \
# 0  Obra nueva\n\n\t\t\t7 habs.\n\t\t\t8 baños\n\t\t\t561 m²\n\t\t\t5.258 €/m²
#
#                                                                                                                                                                                                                                                 detalle  \
# 0  Parcela 2, Tipo B. Chalet de obra nueva de 561  m2 de superficie construida y situado en la zona de Madrid Capital. Está estructurado en 7 habitaciones, 8 baños completos y terraza. El Chalet tiene piscina. Aporta como extras garaje y trastero.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        caracteristicas  \
# 0  Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t561 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t7\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t8\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tA estrenar\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\t-0\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tGaraje\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTrastero\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tTerraza\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tJardín: \n\t\t\t\t\t\t\t\t\t\tPrivado\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPiscina\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
#
#                      consumo                      actualizacion referencia
# 0  Clasificación: En trámite  Anuncio actualizado el 24/10/2024   Ref.: -0

# %%
# Extraer la fecha de actualización
formato_fecha = r'(\d{2}/\d{2}/\d{4})'
df_detalles['fecha'] = df_detalles['actualizacion'].str.extract(formato_fecha)

# Eliminar el texto 'Clasificación: ' de la columna 'consumo'
df_detalles['consumo'] = df_detalles['consumo'].str.replace('Clasificación: ', '', regex=False)

# Eliminar el carácter '#' de la columna 'url'
df_detalles['url'] = df_detalles['url'].str.replace('#', '', regex=False)

# Extraer texto de la columna estado
df_detalles['conservacion'] = df_detalles['estado'].str.extract(r'Conservación: \s*(.*?)\s*(?:\n|$)')
df_detalles['metros_utiles'] = df_detalles['estado'].str.extract(r'Superficie útil: \s*(.*?)\s*(?:\n|$)')
df_detalles['antiguedad'] = df_detalles['estado'].str.extract(r'Antigüedad: \s*(.*?)\s*(?:\n|$)')
df_detalles['comunidad'] = df_detalles['estado'].str.extract(r'Gastos de comunidad: \s*(.*?)\s*(?:\n|$)')

df_detalles['interior_exterior'] = df_detalles['estado'].str.extract(r'Planta:\s*.*?\n\s*(.*?)\n\s*Antigüedad')
df_detalles['interior_exterior'] = df_detalles['interior_exterior'].str.strip() # Limpiar espacios en blanco

# Extraer texto de la columna características
df_detalles['orientacion'] = df_detalles['caracteristicas'].str.extract(r'Orientación: \s*(.*?)\s*(?:\n|$)')
df_detalles['jardin'] = df_detalles['caracteristicas'].str.extract(r'Jardín: \s*(.*?)\s*(?:\n|$)')
df_detalles['aire_acond'] = df_detalles['caracteristicas'].str.extract(r'Aire acondicionado: \s*(.*?)\s*(?:\n|$)')
df_detalles['calefaccion'] = df_detalles['caracteristicas'].str.extract(r'Calefacción: \s*(.*?)\s*(?:\n|$)')
df_detalles['cocina'] = df_detalles['caracteristicas'].str.extract(r'Cocina equipada: \s*(.*?)\s*(?:\n|$)')
df_detalles['suelo'] = df_detalles['caracteristicas'].str.extract(r'Tipo suelo: \s*(.*?)\s*(?:\n|$)')
df_detalles['piscina'] = df_detalles['caracteristicas'].str.extract(r'Piscina: \s*(.*?)\s*(?:\n|$)')
df_detalles['armarios'] = df_detalles['caracteristicas'].str.extract(r'Armarios empotrados: \s*(.*?)\s*(?:\n|$)')
df_detalles['garaje'] = df_detalles['caracteristicas'].str.extract(r'Garaje: \s*(.*?)\s*(?:\n|$)')

# Lista de características a buscar
lista_caracteristicas = ['Terraza', 'Trastero', 'Ascensor', 'Balcón']
# Crear una columna para cada característica
for caracteristica in lista_caracteristicas:
    df_detalles[caracteristica] = df_detalles['caracteristicas'].str.contains(fr'\b{caracteristica}\b', regex=True, na=False).replace({True: caracteristica, False: None})

df_detalles.tail(1)
# Out:
#                         title  \
# 3032  Piso en venta en Madrid
#
#                                                                                             ubicacion  \
# 3032  Recoletos (Distrito Salamanca. Madrid Capital) / Recoletos (Distrito Salamanca. Madrid Capital)
#
#        precio num_hab num_banos metros_construidos planta precio_por_area  \
# 3032  2200000       2         2                150      3           14666
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  estado  \
# 3032  Superficie construida: \n\t\t\t\t\t\t\t\t\t\t150 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t2\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t2\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPlanta: \n\t\t\t\t\t\t\t\t\t\t3ª\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tExterior\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tEn buen estado\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\tsa5578-M211
#
#                                                                         url  \
# 3032  https://www.pisos.com/comprar/piso-recoletos28001-48433256858_100500/
#
#      fecha_descarga        web  \
# 3032     2024-10-19  pisos.com
#
#                                                                       espacios  \
# 3032  2 habs.\n\t\t\t2 baños\n\t\t\t150 m²\n\t\t\t3ª planta\n\t\t\t14.666 €/m²
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 detalle  \
# 3032  Barrio de Salamanca. Inmuebles de lujo y máxima calidad. Recién Reformados en su totalidad. Inmuebles de alto standing y exclusivos. Para mayor información póngase en contacto con el responsable para ofrecerle el que más se adecúe a sus necesidades y presupuesto.\n\nEl distrito de Salamanca, también citado frecuentemente como barrio de Salamanca, es uno de los 21 distritos que forman el municipio de Madrid (España). Debe su nombre a su constructor, el malagueño José de Salamanca y Mayol, marqués de Salamanca, que lo promovió y erigió en parte en el siglo xix. Se ha convertido en una de las más importantes zonas comerciales de la ciudad y uno de los distritos de mayor nivel de vida de España con la mayor zona de compras de lujo de Madrid en torno a la Milla de Oro, que incluye las calles Serrano, Claudio Coello, Lagasca y Ortega y Gasset.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             caracteristicas  \
# 3032  Características\n\t\t\n                    Datos básicos\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tSuperficie construida: \n\t\t\t\t\t\t\t\t\t\t150 m²\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tHabitaciones: \n\t\t\t\t\t\t\t\t\t\t2\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBaños: \n\t\t\t\t\t\t\t\t\t\t2\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tPlanta: \n\t\t\t\t\t\t\t\t\t\t3ª\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tExterior\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tConservación: \n\t\t\t\t\t\t\t\t\t\tEn buen estado\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tReferencia: \n\t\t\t\t\t\t\t\t\t\tsa5578-M211\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Muebles y acabados\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tAmueblado\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tArmarios empotrados: \n\t\t\t\t\t\t\t\t\t\t1\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Equipamiento e instalaciones\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tAire acondicionado: \n\t\t\t\t\t\t\t\t\t\tFrío\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tCalefacción: \n\t\t\t\t\t\t\t\t\t\tCentral\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tCocina equipada: \n\t\t\t\t\t\t\t\t\t\tCocina amueblada\n\t\t\t\t\t\t\t\t\n                            \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tAscensor\n\t\t\t\t\t\t\t\t\n                            \n                    \n                    Exteriores\n                    \n                            \n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\tBalcón\n\t\t\t\t\t\t\t\t\n                            \n                    \n        \n\t\tVer todas las características\n\n\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\tCaracterísticas
#
#          consumo                      actualizacion         referencia  \
# 3032  En trámite  Anuncio actualizado el 23/10/2024  Ref.: sa5578-M211
#
#            fecha    conservacion metros_utiles antiguedad comunidad  \
# 3032  23/10/2024  En buen estado           NaN        NaN       NaN
#
#      interior_exterior orientacion jardin aire_acond calefaccion  \
# 3032               NaN         NaN    NaN       Frío     Central
#
#                 cocina suelo piscina armarios garaje Terraza Trastero  \
# 3032  Cocina amueblada   NaN     NaN        1    NaN    None     None
#
#       Ascensor  Balcón
# 3032  Ascensor  Balcón

# %%
df_detalles = df_detalles.drop(['estado', 'caracteristicas', 'espacios'], axis=1)
df_detalles.tail(1)
# Out:
#                         title  \
# 3032  Piso en venta en Madrid
#
#                                                                                             ubicacion  \
# 3032  Recoletos (Distrito Salamanca. Madrid Capital) / Recoletos (Distrito Salamanca. Madrid Capital)
#
#        precio num_hab num_banos metros_construidos planta precio_por_area  \
# 3032  2200000       2         2                150      3           14666
#
#                                                                         url  \
# 3032  https://www.pisos.com/comprar/piso-recoletos28001-48433256858_100500/
#
#      fecha_descarga        web  \
# 3032     2024-10-19  pisos.com
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 detalle  \
# 3032  Barrio de Salamanca. Inmuebles de lujo y máxima calidad. Recién Reformados en su totalidad. Inmuebles de alto standing y exclusivos. Para mayor información póngase en contacto con el responsable para ofrecerle el que más se adecúe a sus necesidades y presupuesto.\n\nEl distrito de Salamanca, también citado frecuentemente como barrio de Salamanca, es uno de los 21 distritos que forman el municipio de Madrid (España). Debe su nombre a su constructor, el malagueño José de Salamanca y Mayol, marqués de Salamanca, que lo promovió y erigió en parte en el siglo xix. Se ha convertido en una de las más importantes zonas comerciales de la ciudad y uno de los distritos de mayor nivel de vida de España con la mayor zona de compras de lujo de Madrid en torno a la Milla de Oro, que incluye las calles Serrano, Claudio Coello, Lagasca y Ortega y Gasset.
#
#          consumo                      actualizacion         referencia  \
# 3032  En trámite  Anuncio actualizado el 23/10/2024  Ref.: sa5578-M211
#
#            fecha    conservacion metros_utiles antiguedad comunidad  \
# 3032  23/10/2024  En buen estado           NaN        NaN       NaN
#
#      interior_exterior orientacion jardin aire_acond calefaccion  \
# 3032               NaN         NaN    NaN       Frío     Central
#
#                 cocina suelo piscina armarios garaje Terraza Trastero  \
# 3032  Cocina amueblada   NaN     NaN        1    NaN    None     None
#
#       Ascensor  Balcón
# 3032  Ascensor  Balcón

# %%
utiles_decimales = df_detalles[df_detalles['metros_utiles'].str.contains(',', na=False)]
utiles_decimales
# Se ha comprobado que ningún 'metros_utiles' contiene decimales.
# Out:
# Empty DataFrame
# Columns: [title, ubicacion, precio, num_hab, num_banos, metros_construidos, planta, precio_por_area, url, fecha_descarga, web, detalle, consumo, actualizacion, referencia, fecha, conservacion, metros_utiles, antiguedad, comunidad, interior_exterior, orientacion, jardin, aire_acond, calefaccion, cocina, suelo, piscina, armarios, garaje, Terraza, Trastero, Ascensor, Balcón]
# Index: []

# %%
df_detalles['metros_utiles'] = df_detalles['metros_utiles'].str.replace(r'\D', '', regex=True)
df_detalles['fecha'] = df_detalles['fecha'].str.replace(r'(\d{2})/(\d{2})/(\d{4})', r'\3-\2-\1', regex=True)
df_detalles['fecha'] = pd.to_datetime(df_detalles['fecha'])
df_detalles.tail(2)
# Out:
#                         title  \
# 3031  Piso en venta en Madrid
# 3032  Piso en venta en Madrid
#
#                                                                                             ubicacion  \
# 3031            Goya (Distrito Salamanca. Madrid Capital) / Goya (Distrito Salamanca. Madrid Capital)
# 3032  Recoletos (Distrito Salamanca. Madrid Capital) / Recoletos (Distrito Salamanca. Madrid Capital)
#
#        precio num_hab num_banos metros_construidos planta precio_por_area  \
# 3031  2990000       4         4                308      4            9707
# 3032  2200000       2         2                150      3           14666
#
#                                                                         url  \
# 3031       https://www.pisos.com/comprar/piso-goya28001-48408085356_100500/
# 3032  https://www.pisos.com/comprar/piso-recoletos28001-48433256858_100500/
#
#      fecha_descarga        web  \
# 3031     2024-10-19  pisos.com
# 3032     2024-10-19  pisos.com
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               detalle  \
# 3031  Propiedad Exclusiva junto a la calle Goya.\n\nOs invitamos a conocer una propiedad perfecta para todos aquellos que buscan exclusividad y lujo desde el mismo corazón de la Milla de oro.\n\nEsta Vivienda presenta una Superficie de 308 m², destacando su excelente iluminación natural gracias a sus múltiples ventanales y balcones con 17m de fachada a la calle.\n\nLa distribución del inmueble se articula a través de un elegante recibidor, que da lugar al fantástico salón-comedor con 3 balcones a la calle, a continuación accedemos a un despacho también con balcón a la calle. Además, cuenta con un baño completo de cortesía y una magnífica cocina independiente y amueblada de 20m y con numerosas ventanas que le dan una gran luminosidad.\nA la zona de descanso accedemos a través de un amplísimo distribuidor al cual se le puede dar distintos usos (sala de estar o lectura, etc.),  se compone por cuatro dormitorios dobles y tres baños: siendo el principal en suite y equipado con numerosos armarios. Respecto a sus calidades, la vivienda mantiene la carpintería en ventanas y puertas de madera maciza original, el suelo de tarima Pino Meli, la calefacción es central y entra dentro del recibo de la comunidad, con A/A. en salón y cocina, la vivienda dispone de una entrada de servicio y dos trasteros.\n\nLa vivienda se encuentra en una magnífica finca señorial representativa de bellísima fachada clásica.
# 3032                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Barrio de Salamanca. Inmuebles de lujo y máxima calidad. Recién Reformados en su totalidad. Inmuebles de alto standing y exclusivos. Para mayor información póngase en contacto con el responsable para ofrecerle el que más se adecúe a sus necesidades y presupuesto.\n\nEl distrito de Salamanca, también citado frecuentemente como barrio de Salamanca, es uno de los 21 distritos que forman el municipio de Madrid (España). Debe su nombre a su constructor, el malagueño José de Salamanca y Mayol, marqués de Salamanca, que lo promovió y erigió en parte en el siglo xix. Se ha convertido en una de las más importantes zonas comerciales de la ciudad y uno de los distritos de mayor nivel de vida de España con la mayor zona de compras de lujo de Madrid en torno a la Milla de Oro, que incluye las calles Serrano, Claudio Coello, Lagasca y Ortega y Gasset.
#
#          consumo actualizacion         referencia      fecha    conservacion  \
# 3031  En trámite           NaT  Ref.: sa5578-M106 2024-10-23  En buen estado
# 3032  En trámite           NaT  Ref.: sa5578-M211 2024-10-23  En buen estado
#
#      metros_utiles      antiguedad     comunidad interior_exterior  \
# 3031           263  Más de 50 años  Más de 100 €          Exterior
# 3032           NaN             NaN           NaN               NaN
#
#      orientacion jardin aire_acond calefaccion            cocina  \
# 3031         NaN    NaN       Frío     Central  Cocina amueblada
# 3032         NaN    NaN       Frío     Central  Cocina amueblada
#
#                 suelo piscina armarios garaje Terraza  Trastero  Ascensor  \
# 3031  Tarima flotante     NaN        1    NaN    None  Trastero  Ascensor
# 3032              NaN     NaN        1    NaN    None      None  Ascensor
#
#       Balcón
# 3031  Balcón
# 3032  Balcón

# %%
df_detalles.shape
# (3033, 34)
# Out:
# (3033, 34)

# %%
df_detalles_dupl = df_detalles.duplicated().sum()
df_detalles_dupl
# 5 filas duplicadas
# Out:
# 5

# %%
df_detalles = df_detalles.drop_duplicates()
df_detalles.shape
# (3028, 34)
# Out:
# (3028, 34)

# %%
df_detalles = df_detalles.drop(['actualizacion'], axis=1)

# %% [markdown]
# ## COLUMNAS DE DF DETALLES

# %%
df_detalles.rename(columns={'num_hab': 'habitaciones', 'num_banos': 'banos', 'metros_construidos': 'm2_constr', 'precio_por_area': 'EUR/m2', 'consumo': 'consumo_energia','fecha': 'fecha_publicacion', 'metros_utiles': 'm2_utiles', 'antiguedad': 'ano_construccion', 'comunidad': '€_comunidad_mes', 'aire_acond': 'aire_acondicionado', 'suelo': 'tipo_suelo', 'Terraza': 'terraza', 'Trastero': 'trastero', 'Ascensor': 'ascensor', 'Balcón': 'balcon'}, inplace=True)
df_detalles.columns
# Out:
# Index(['title', 'ubicacion', 'precio', 'habitaciones', 'banos', 'm2_constr',
#        'planta', 'EUR/m2', 'url', 'fecha_descarga', 'web', 'detalle',
#        'consumo_energia', 'referencia', 'fecha_publicacion', 'conservacion',
#        'm2_utiles', 'ano_construccion', '€_comunidad_mes', 'interior_exterior',
#        'orientacion', 'jardin', 'aire_acondicionado', 'calefaccion', 'cocina',
#        'tipo_suelo', 'piscina', 'armarios', 'garaje', 'terraza', 'trastero',
#        'ascensor', 'balcon'],
#       dtype='object')

# %%
df_detalles = df_detalles.reset_index(drop=True)
df_detalles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3028 entries, 0 to 3027
# Data columns (total 33 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               2773 non-null   object
#  1   ubicacion           3028 non-null   object
#  2   precio              3027 non-null   object
#  3   habitaciones        2959 non-null   object
#  4   banos               2959 non-null   object
#  5   m2_constr           2950 non-null   object
#  6   planta              2870 non-null   object
#  7   EUR/m2              1926 non-null   object
#  8   url                 3027 non-null   object
#  9   fecha_descarga      3028 non-null   datetime64[ns]
#  10  web                 3028 non-null   object
#  11  detalle             3027 non-null   object
#  12  consumo_energia     2966 non-null   object
#  13  referencia          3028 non-null   object
#  14  fecha_publicacion   2966 non-null   datetime64[ns]
#  15  conservacion        1871 non-null   object
#  16  m2_utiles           1155 non-null   object
#  17  ano_construccion    1426 non-null   object
#  18  €_comunidad_mes     808 non-null    object
#  19  interior_exterior   968 non-null    object
#  20  orientacion         1159 non-null   object
#  21  jardin              207 non-null    object
#  22  aire_acondicionado  942 non-null    object
#  23  calefaccion         1443 non-null   object
#  24  cocina              635 non-null    object
#  25  tipo_suelo          827 non-null    object
#  26  piscina             218 non-null    object
#  27  armarios            1147 non-null   object
#  28  garaje              537 non-null    object
#  29  terraza             1310 non-null   object
#  30  trastero            824 non-null    object
#  31  ascensor            1972 non-null   object
#  32  balcon              330 non-null    object
# dtypes: datetime64[ns](2), object(31)
# memory usage: 780.8+ KB

# %%
url_duplicadas = df_detalles['url'].duplicated().sum()
url_duplicadas
# Out:
# 161

# %%
df_detalles = df_detalles.drop_duplicates(subset=['url'])
df_detalles.shape
# (2867, 33)
# Out:
# (2867, 33)

# %%
df_detalles.to_csv('pisoscom_detalles_limpio.csv', index=False)
